# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings
import numpy as np

seed = 42 # for reproduction
random.seed(seed)
np.random.seed(seed)

import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = './stage1_train/'
TEST_PATH = './stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# Out:
# /home/peter/virtual_envs/tf_keras/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
from skimage.measure import regionprops
import cv2, imutils
import math

# Get and resize train images and masks
X_train = []
Y_train = []
#lsum = 0
#msum = 0
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    mark = np.zeros(img.shape[:2], dtype=np.uint8)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        cnts = cv2.findContours(mask_.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if imutils.is_cv2() else cnts[1]
        M = cv2.moments(cnts[0])
        if M["m00"] != 0:
            cX = M["m10"] / M["m00"]
            cY = M["m01"] / M["m00"]
        else:
            p = regionprops(mask_, cache=True)[0]
            cY, cX = p.centroid
        r = int(math.ceil( max( img.shape[0], img.shape[1] ) * .01 ))
        cv2.circle(mark, (int(cX), int(cY)), r, 255, -1)
        mask = np.maximum(mask, mask_)
    mark = cv2.GaussianBlur(mark, (3,3), 0)
    #lsum += np.sum(mask)
    #msum += np.sum(mark)
    Y_train.append([mask, mark])

# print(msum / (lsum+msum))

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append(img.shape[:2])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:23<00:00,  8.05it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 29.68it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]), cmap='gray')
plt.show()
x_copy = X_train[ix].copy()
x_copy[np.squeeze(Y_train[ix][1])>0, :] = 255, 0, 0
plt.imshow(x_copy)
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true_, y_pred_):
    y_true = y_true_[...,0]
    y_pred = y_pred_[...,0]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def mean_iou_marker(y_true_, y_pred_):
    y_true = y_true_[...,1]
    y_pred = y_pred_[...,1]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.*intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + intersection + smooth)

from keras.losses import binary_crossentropy

def custom_loss(y_true_, y_pred_):
    alpha = 0.83 # control amount of loss of markers
    
    y_true_hm = y_true_[...,0]
    y_true_mk = y_true_[...,1]
    
    y_pred_hm = y_pred_[...,0]
    y_pred_mk = y_pred_[...,1]
    
    s_marker_loss = .5 * binary_crossentropy(y_true_mk, y_pred_mk) - dice_coef(y_true_mk, y_pred_mk)
    s_heatmap_loss= .5 * binary_crossentropy(y_true_hm, y_pred_hm) - dice_coef(y_true_hm, y_pred_hm)
    
    losses = alpha * s_marker_loss + (1.-alpha) * s_heatmap_loss
    return losses

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout
from keras.optimizers import Adam

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = Add()([inputs, last]) # dimensions of inputs, last are same
    
    c1 = _res_conv(c1, 32, 3)
    c1 = _res_conv(c1, 32, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 64, 3)
    c2 = _res_conv(c2, 64, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 128, 3)
    c3 = _res_conv(c3, 128, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 256, 3)
    c4 = _res_conv(c4, 256, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 512, 3)
    c5 = _res_conv(c5, 512, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3)
    c6 = _res_conv(c6, 512, 3)
    
    u7 = up (c6)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 512, 3)
    c7 = _res_conv(c7, 512, 3)
    
    u8 = up (c7)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 256, 3)
    c8 = _res_conv(c8, 256, 3)
    
    u9 = up (c8)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 128, 3)
    c9 = _res_conv(c9, 128, 3)
    
    u10 = up (c9)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 64, 3)
    c10 = _res_conv(c10, 64, 3)
    
    u11 = up (c10)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 32, 3)
    c11 = _res_conv(c11, 32, 3)
    
    outputs = Conv2D(2, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss=custom_loss, metrics=[mean_iou, mean_iou_marker], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  32          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 17) 1241        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 8)  808         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 3)  12          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 128         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 8)  264         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 256, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 17) 1241        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 8)  808         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 3)  99          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 32) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 256, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 32) 0           activation_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 528         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  264         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32) 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 9)  297         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 6)  198         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 2112        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 128, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           conv2d_20[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 8)  520         activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 9)  585         activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 6)  390         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 64) 0           conv2d_21[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128, 128, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 64) 0           activation_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 64) 0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 32)   2080        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 16)   1040        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 19)   1235        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 12)   780         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_27[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  8320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 128)  0           conv2d_33[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   4128        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 16)   2064        activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 19)   2451        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 12)   1548        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 64, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           activation_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 128)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 38)   4902        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 25)   3225        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 256)  0           conv2d_40[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 256)  33024       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 256)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           conv2d_46[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 32)   8224        activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 38)   9766        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 25)   6425        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 256)  0           conv2d_47[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 256)  0           activation_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 128)  32896       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 16, 16, 256)  0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 76)   19532       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 51)   13107       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 512)  0           conv2d_53[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 512)  131584      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 512)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 512)  0           conv2d_59[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 16, 16, 128)  65664       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 16, 16, 64)   32832       activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 16, 16, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 16, 16, 76)   38988       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 512)  0           conv2d_60[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 512)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 512)  0           activation_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 8, 8, 512)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 128)    65664       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 76)     38988       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 512)    0           conv2d_66[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 512)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 512)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 8, 8, 128)    65664       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 8, 8, 64)     32832       activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 512)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 8, 8, 76)     38988       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 512)    0           conv2d_72[0][0]
#                                                                  conv2d_75[0][0]
#                                                                  conv2d_76[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 512)    0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 512)    0           activation_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 512)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 16, 16, 1024) 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 76)   77900       concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 51)   52275       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 16, 16, 512)  0           conv2d_78[0][0]
#                                                                  conv2d_81[0][0]
#                                                                  conv2d_82[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 512)  524800      concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 512)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 512)  0           conv2d_84[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 64)   32832       activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 512)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 76)   38988       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 16, 16, 512)  0           conv2d_85[0][0]
#                                                                  conv2d_88[0][0]
#                                                                  conv2d_89[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 512)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 512)  0           activation_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 512)  0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 768)  0           conv2d_transpose_2[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 64)   49216       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 32, 32, 768)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 38)   29222       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 32, 32, 25)   19225       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 32, 256)  0           conv2d_91[0][0]
#                                                                  conv2d_94[0][0]
#                                                                  conv2d_95[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 32, 32, 256)  196864      concatenate_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 256)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 256)  0           conv2d_97[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 32, 32, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 32, 32, 32)   8224        activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 32, 32, 256)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 32, 32, 38)   9766        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 32, 32, 129)  74433       conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 32, 32, 64)   51264       conv2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 32, 32, 25)   6425        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 256)  0           conv2d_98[0][0]
#                                                                  conv2d_101[0][0]
#                                                                  conv2d_102[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 256)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 256)  0           activation_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 256)  262400      activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 384)  0           conv2d_transpose_3[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 32)   12320       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 64, 64, 16)   6160        concatenate_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 64, 64, 19)   7315        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_105[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 12)   4620        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 64, 64, 128)  0           conv2d_104[0][0]
#                                                                  conv2d_107[0][0]
#                                                                  conv2d_108[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 128)  49280       concatenate_19[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 128)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 128)  0           conv2d_110[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 128)  0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 64, 64, 32)   4128        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 64, 64, 16)   2064        activation_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 64, 64, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 64, 64, 19)   2451        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 64, 64, 12)   1548        max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 64, 64, 128)  0           conv2d_111[0][0]
#                                                                  conv2d_114[0][0]
#                                                                  conv2d_115[0][0]
#                                                                  conv2d_116[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 128)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 64, 128)  0           activation_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 128)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 128 65664       activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 192 0           conv2d_transpose_4[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 128, 128, 16) 3088        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 128, 8)  1544        concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 128, 128, 9)  1737        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 128, 128, 6)  1158        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 64) 0           conv2d_117[0][0]
#                                                                  conv2d_120[0][0]
#                                                                  conv2d_121[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 128, 64) 12352       concatenate_22[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 64) 0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 128, 128, 64) 0           conv2d_123[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 64) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 128, 128, 16) 1040        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 128, 128, 8)  520         activation_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 64) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 128, 128, 9)  585         activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 128, 128, 6)  390         max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 64) 0           conv2d_124[0][0]
#                                                                  conv2d_127[0][0]
#                                                                  conv2d_128[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 128, 128, 64) 0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 128, 64) 0           activation_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 64) 0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 64) 16448       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 96) 0           conv2d_transpose_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 256, 256, 8)  776         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 8)  808         conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 3)  291         max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 256, 256, 32) 0           conv2d_130[0][0]
#                                                                  conv2d_133[0][0]
#                                                                  conv2d_134[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 32) 3104        concatenate_25[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 256, 256, 32) 0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 256, 256, 32) 0           conv2d_136[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 32) 0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 256, 256, 8)  264         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 256, 256, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 256, 256, 8)  808         conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 256, 256, 3)  99          max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 256, 256, 32) 0           conv2d_137[0][0]
#                                                                  conv2d_140[0][0]
#                                                                  conv2d_141[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 256, 256, 32) 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 256, 256, 32) 0           activation_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 32) 0           add_22[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 2)  66          activation_22[0][0]
# ==================================================================================================
# Total params: 8,442,315
# Trainable params: 8,442,315
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2
from keras.utils import Sequence

class data_generator(Sequence):
    def __init__(self, data, label, batch_size=4, training=True):
        self.data = data
        self.label= label
        self.batch_size = batch_size
        self.training = training
    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)
    def __getitem__(self, index):
        base = index*self.batch_size
        limit= min(len(self.data), (index+1)*self.batch_size)
        batch_index = range(base, limit)
        dat_que = np.empty((limit-base, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
        lab_que = np.empty((limit-base, IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.bool)
        for i, index in enumerate(batch_index):
            img, lab, marker = self.fetch_data(index)
            dat_que[i,:,:,:] = img
            lab_que[i,:,:,0] = lab
            lab_que[i,:,:,1] = marker
        return dat_que, lab_que

    def fetch_data(self, index):
        img = self.data[index] # [0,255]
        lab = self.label[index][0]
        marker = self.label[index][1]
        if self.training:
            if np.random.rand() < .5: # flip vertical
                img = np.flip(img, 0)
                lab = np.flip(lab, 0)
                marker = np.flip(marker, 0)
            if np.random.rand() < .5: # flip horizontal
                img = np.flip(img, 1)
                lab = np.flip(lab, 1)
                marker = np.flip(marker, 1)

            # rotation, shearing
            if np.random.rand() < 0.5:
                y, x, _ = img.shape
                h, w = y, x
                img = cv2.copyMakeBorder(img, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                y, x, _ = img.shape

                pts1 = np.float32([[5,5],[20,5],[5,20]])

                pt1 =    10*np.random.uniform()
                pt2 = 15+10*np.random.uniform()

                pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])
                shear_M = cv2.getAffineTransform(pts1,pts2)

                rotT = np.random.uniform(-45,45)
                M = cv2.getRotationMatrix2D((x/2, y/2), rotT, 1)

                mA, mB = (M, shear_M) if np.random.rand()<.5 else (shear_M, M)

                img = cv2.warpAffine(img, mA, (x, y))
                lab = cv2.warpAffine(lab, mA, (x, y))
                marker = cv2.warpAffine(marker, mA, (x, y))

                img = cv2.warpAffine(img, mB, (x, y))
                lab = cv2.warpAffine(lab, mB, (x, y))
                marker = cv2.warpAffine(marker, mB, (x, y))

                img = img[h//2:h//2+h,w//2:w//2+w,:]
                lab = lab[h//2:h//2+h,w//2:w//2+w]
                marker = marker[h//2:h//2+h,w//2:w//2+w]

            img = img.astype(np.float32) / 255. # normalize

            # random amplify each channel
            a = .1 # amptitude
            t  = [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t = np.array(t)

            img = img * (1. + t) # channel wise amplify
            up = np.random.uniform(0.95, 1.05) # change gamma
            img = img**up * 255. # apply gamma and convert back to range [0,255]
            img = img.astype(np.uint8) # convert back to uint8

            assert img.dtype == np.uint8 ## check type
            assert lab.dtype == np.uint8

            if np.random.rand() < .1: # randomly crop image
                s = np.random.uniform(0.8, 1.2) # random crop scale
                w, h = int(s*IMG_WIDTH), int(s*IMG_HEIGHT)
                paddx = max(0, w-img.shape[1])
                paddy = max(0, h-img.shape[0])
                img = cv2.copyMakeBorder(img, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                cropx = img.shape[1] - w + 1
                cropy = img.shape[0] - h + 1
                offx = np.random.randint(0, cropx)
                offy = np.random.randint(0, cropy)
                img = img[offy:offy+h, offx:offx+w, :]
                lab = lab[offy:offy+h, offx:offx+w]
                marker = marker[offy:offy+h, offx:offx+w]
        ### end of data augmentation ###

        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        marker = resize(marker, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

        lab[lab<130] = 0
        lab[lab>0] = 1

        marker[marker<130] = 0
        marker[marker>0] = 1

        return img, lab, marker

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# Fit model
BS=8
EPOCHS=300

os.makedirs('./models', exist_ok=True)

# earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('./models/model.{epoch:03d}.vl.{val_loss:.2f}.vi.{val_mean_iou:.2f}.vim.{val_mean_iou_marker:.2f}.h5', verbose=1, save_best_only=False)
history = model.fit_generator(data_generator(X_train, Y_train, batch_size=BS, training=True),
                              steps_per_epoch=len(X_train) // BS , epochs=EPOCHS, 
                              validation_data=data_generator(X_val, Y_val, batch_size=BS, training=False), 
                              validation_steps=len(X_val) // BS,
                             callbacks=[checkpointer], workers=5, shuffle=True)
# Out:
# Epoch 1/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.2175 - mean_iou: 0.5048 - mean_iou_marker: 0.5292
# Epoch 00001: saving model to ./models/model.001.vl.-0.33.vi.0.62.vim.0.59.h5
# 75/75 [==============================] - 120s 2s/step - loss: -0.2201 - mean_iou: 0.5063 - mean_iou_marker: 0.5300 - val_loss: -0.3317 - val_mean_iou: 0.6217 - val_mean_iou_marker: 0.5901
# Epoch 2/300
# 74/75 [============================>.] - ETA: 0s - loss: -0.3350 - mean_iou: 0.6684 - mean_iou_marker: 0.6035
# Epoch 00002: saving model to ./models/model.002.vl.-0.39.vi.0.70.vim.0.61.h5
# 75/75 [==============================] - 75s 1s/step - loss: -0.3354 - mean_iou: 0.6688 - mean_iou_marker: 0.6036 - val_loss: -0.3852 - val_mean_iou: 0.7008 - val_mean_iou_marker: 0.6150
# Epoch 3/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.3669 - mean_iou: 0.7203 - mean_iou_marker: 0.6220
# Epoch 00003: saving model to ./models/model.003.vl.-0.43.vi.0.74.vim.0.63.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.3676 - mean_iou: 0.7206 - mean_iou_marker: 0.6220 - val_loss: -0.4319 - val_mean_iou: 0.7386 - val_mean_iou_marker: 0.6291
# Epoch 4/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.3733 - mean_iou: 0.7513 - mean_iou_marker: 0.6342
# Epoch 00004: saving model to ./models/model.004.vl.-0.44.vi.0.76.vim.0.64.h5
# 75/75 [==============================] - 89s 1s/step - loss: -0.3740 - mean_iou: 0.7514 - mean_iou_marker: 0.6343 - val_loss: -0.4382 - val_mean_iou: 0.7616 - val_mean_iou_marker: 0.6377
# Epoch 5/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.3922 - mean_iou: 0.7711 - mean_iou_marker: 0.6419
# Epoch 00005: saving model to ./models/model.005.vl.-0.44.vi.0.78.vim.0.65.h5
# 75/75 [==============================] - 95s 1s/step - loss: -0.3919 - mean_iou: 0.7712 - mean_iou_marker: 0.6420 - val_loss: -0.4404 - val_mean_iou: 0.7789 - val_mean_iou_marker: 0.6452
# Epoch 6/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4032 - mean_iou: 0.7851 - mean_iou_marker: 0.6477
# Epoch 00006: saving model to ./models/model.006.vl.-0.46.vi.0.79.vim.0.65.h5
# 75/75 [==============================] - 87s 1s/step - loss: -0.4031 - mean_iou: 0.7852 - mean_iou_marker: 0.6478 - val_loss: -0.4587 - val_mean_iou: 0.7917 - val_mean_iou_marker: 0.6506
# Epoch 7/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4078 - mean_iou: 0.7967 - mean_iou_marker: 0.6532
# Epoch 00007: saving model to ./models/model.007.vl.-0.44.vi.0.80.vim.0.66.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4075 - mean_iou: 0.7967 - mean_iou_marker: 0.6532 - val_loss: -0.4404 - val_mean_iou: 0.8013 - val_mean_iou_marker: 0.6553
# Epoch 8/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4197 - mean_iou: 0.8050 - mean_iou_marker: 0.6571
# Epoch 00008: saving model to ./models/model.008.vl.-0.46.vi.0.81.vim.0.66.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4202 - mean_iou: 0.8050 - mean_iou_marker: 0.6572 - val_loss: -0.4571 - val_mean_iou: 0.8086 - val_mean_iou_marker: 0.6596
# Epoch 9/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4246 - mean_iou: 0.8115 - mean_iou_marker: 0.6618
# Epoch 00009: saving model to ./models/model.009.vl.-0.44.vi.0.81.vim.0.66.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4254 - mean_iou: 0.8115 - mean_iou_marker: 0.6618 - val_loss: -0.4377 - val_mean_iou: 0.8141 - val_mean_iou_marker: 0.6634
# Epoch 10/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4305 - mean_iou: 0.8164 - mean_iou_marker: 0.6652
# Epoch 00010: saving model to ./models/model.010.vl.-0.44.vi.0.82.vim.0.67.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4305 - mean_iou: 0.8164 - mean_iou_marker: 0.6652 - val_loss: -0.4352 - val_mean_iou: 0.8186 - val_mean_iou_marker: 0.6670
# Epoch 11/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4292 - mean_iou: 0.8207 - mean_iou_marker: 0.6683
# Epoch 00011: saving model to ./models/model.011.vl.-0.48.vi.0.82.vim.0.67.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4293 - mean_iou: 0.8208 - mean_iou_marker: 0.6683 - val_loss: -0.4829 - val_mean_iou: 0.8229 - val_mean_iou_marker: 0.6700
# Epoch 12/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4416 - mean_iou: 0.8250 - mean_iou_marker: 0.6717
# Epoch 00012: saving model to ./models/model.012.vl.-0.47.vi.0.83.vim.0.67.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4414 - mean_iou: 0.8250 - mean_iou_marker: 0.6717 - val_loss: -0.4715 - val_mean_iou: 0.8270 - val_mean_iou_marker: 0.6734
# Epoch 13/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4442 - mean_iou: 0.8287 - mean_iou_marker: 0.6746
# Epoch 00013: saving model to ./models/model.013.vl.-0.49.vi.0.83.vim.0.68.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4445 - mean_iou: 0.8287 - mean_iou_marker: 0.6746 - val_loss: -0.4890 - val_mean_iou: 0.8303 - val_mean_iou_marker: 0.6764
# Epoch 14/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4369 - mean_iou: 0.8321 - mean_iou_marker: 0.6775
# Epoch 00014: saving model to ./models/model.014.vl.-0.49.vi.0.83.vim.0.68.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4365 - mean_iou: 0.8321 - mean_iou_marker: 0.6775 - val_loss: -0.4949 - val_mean_iou: 0.8335 - val_mean_iou_marker: 0.6787
# Epoch 15/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4395 - mean_iou: 0.8349 - mean_iou_marker: 0.6798
# Epoch 00015: saving model to ./models/model.015.vl.-0.49.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 87s 1s/step - loss: -0.4398 - mean_iou: 0.8349 - mean_iou_marker: 0.6798 - val_loss: -0.4862 - val_mean_iou: 0.8362 - val_mean_iou_marker: 0.6808
# Epoch 16/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4294 - mean_iou: 0.8370 - mean_iou_marker: 0.6810
# Epoch 00016: saving model to ./models/model.016.vl.-0.48.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4284 - mean_iou: 0.8370 - mean_iou_marker: 0.6810 - val_loss: -0.4838 - val_mean_iou: 0.8379 - val_mean_iou_marker: 0.6819
# Epoch 17/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4476 - mean_iou: 0.8392 - mean_iou_marker: 0.6830
# Epoch 00017: saving model to ./models/model.017.vl.-0.50.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4474 - mean_iou: 0.8392 - mean_iou_marker: 0.6830 - val_loss: -0.4984 - val_mean_iou: 0.8403 - val_mean_iou_marker: 0.6839
# Epoch 18/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4494 - mean_iou: 0.8411 - mean_iou_marker: 0.6851
# Epoch 00018: saving model to ./models/model.018.vl.-0.49.vi.0.84.vim.0.69.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4489 - mean_iou: 0.8411 - mean_iou_marker: 0.6851 - val_loss: -0.4917 - val_mean_iou: 0.8421 - val_mean_iou_marker: 0.6858
# Epoch 19/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4511 - mean_iou: 0.8429 - mean_iou_marker: 0.6868
# Epoch 00019: saving model to ./models/model.019.vl.-0.48.vi.0.84.vim.0.69.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4502 - mean_iou: 0.8429 - mean_iou_marker: 0.6868 - val_loss: -0.4772 - val_mean_iou: 0.8438 - val_mean_iou_marker: 0.6876
# Epoch 20/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4548 - mean_iou: 0.8444 - mean_iou_marker: 0.6887
# Epoch 00020: saving model to ./models/model.020.vl.-0.44.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4548 - mean_iou: 0.8444 - mean_iou_marker: 0.6887 - val_loss: -0.4404 - val_mean_iou: 0.8452 - val_mean_iou_marker: 0.6894
# Epoch 21/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4443 - mean_iou: 0.8459 - mean_iou_marker: 0.6897
# Epoch 00021: saving model to ./models/model.021.vl.-0.47.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4450 - mean_iou: 0.8459 - mean_iou_marker: 0.6897 - val_loss: -0.4676 - val_mean_iou: 0.8466 - val_mean_iou_marker: 0.6903
# Epoch 22/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4519 - mean_iou: 0.8474 - mean_iou_marker: 0.6909
# Epoch 00022: saving model to ./models/model.022.vl.-0.48.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4506 - mean_iou: 0.8474 - mean_iou_marker: 0.6909 - val_loss: -0.4798 - val_mean_iou: 0.8482 - val_mean_iou_marker: 0.6913
# Epoch 23/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4571 - mean_iou: 0.8487 - mean_iou_marker: 0.6921
# Epoch 00023: saving model to ./models/model.023.vl.-0.48.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4568 - mean_iou: 0.8487 - mean_iou_marker: 0.6921 - val_loss: -0.4839 - val_mean_iou: 0.8495 - val_mean_iou_marker: 0.6927
# Epoch 24/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4563 - mean_iou: 0.8500 - mean_iou_marker: 0.6932
# Epoch 00024: saving model to ./models/model.024.vl.-0.48.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4556 - mean_iou: 0.8500 - mean_iou_marker: 0.6932 - val_loss: -0.4783 - val_mean_iou: 0.8507 - val_mean_iou_marker: 0.6938
# Epoch 25/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4585 - mean_iou: 0.8514 - mean_iou_marker: 0.6944
# Epoch 00025: saving model to ./models/model.025.vl.-0.48.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4590 - mean_iou: 0.8514 - mean_iou_marker: 0.6944 - val_loss: -0.4808 - val_mean_iou: 0.8521 - val_mean_iou_marker: 0.6949
# Epoch 26/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4645 - mean_iou: 0.8528 - mean_iou_marker: 0.6955
# Epoch 00026: saving model to ./models/model.026.vl.-0.50.vi.0.85.vim.0.70.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4637 - mean_iou: 0.8528 - mean_iou_marker: 0.6955 - val_loss: -0.4956 - val_mean_iou: 0.8534 - val_mean_iou_marker: 0.6962
# Epoch 27/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4246 - mean_iou: 0.8535 - mean_iou_marker: 0.6963
# Epoch 00027: saving model to ./models/model.027.vl.-0.48.vi.0.85.vim.0.70.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4255 - mean_iou: 0.8535 - mean_iou_marker: 0.6963 - val_loss: -0.4837 - val_mean_iou: 0.8536 - val_mean_iou_marker: 0.6963
# Epoch 28/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4447 - mean_iou: 0.8538 - mean_iou_marker: 0.6965
# Epoch 00028: saving model to ./models/model.028.vl.-0.48.vi.0.85.vim.0.70.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4447 - mean_iou: 0.8538 - mean_iou_marker: 0.6965 - val_loss: -0.4848 - val_mean_iou: 0.8541 - val_mean_iou_marker: 0.6969
# Epoch 29/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4509 - mean_iou: 0.8545 - mean_iou_marker: 0.6973
# Epoch 00029: saving model to ./models/model.029.vl.-0.49.vi.0.85.vim.0.70.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4506 - mean_iou: 0.8545 - mean_iou_marker: 0.6973 - val_loss: -0.4942 - val_mean_iou: 0.8549 - val_mean_iou_marker: 0.6977
# Epoch 30/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4422 - mean_iou: 0.8552 - mean_iou_marker: 0.6978
# Epoch 00030: saving model to ./models/model.030.vl.-0.48.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4431 - mean_iou: 0.8552 - mean_iou_marker: 0.6978 - val_loss: -0.4841 - val_mean_iou: 0.8557 - val_mean_iou_marker: 0.6981
# Epoch 31/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4634 - mean_iou: 0.8562 - mean_iou_marker: 0.6986
# Epoch 00031: saving model to ./models/model.031.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4635 - mean_iou: 0.8562 - mean_iou_marker: 0.6986 - val_loss: -0.5129 - val_mean_iou: 0.8567 - val_mean_iou_marker: 0.6989
# Epoch 32/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4552 - mean_iou: 0.8570 - mean_iou_marker: 0.6994
# Epoch 00032: saving model to ./models/model.032.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4539 - mean_iou: 0.8570 - mean_iou_marker: 0.6994 - val_loss: -0.5098 - val_mean_iou: 0.8573 - val_mean_iou_marker: 0.6998
# Epoch 33/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4630 - mean_iou: 0.8578 - mean_iou_marker: 0.7001
# Epoch 00033: saving model to ./models/model.033.vl.-0.52.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4629 - mean_iou: 0.8578 - mean_iou_marker: 0.7001 - val_loss: -0.5181 - val_mean_iou: 0.8582 - val_mean_iou_marker: 0.7006
# Epoch 34/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4584 - mean_iou: 0.8586 - mean_iou_marker: 0.7011
# Epoch 00034: saving model to ./models/model.034.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4579 - mean_iou: 0.8586 - mean_iou_marker: 0.7011 - val_loss: -0.5061 - val_mean_iou: 0.8589 - val_mean_iou_marker: 0.7014
# Epoch 35/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4530 - mean_iou: 0.8594 - mean_iou_marker: 0.7016
# Epoch 00035: saving model to ./models/model.035.vl.-0.53.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4532 - mean_iou: 0.8594 - mean_iou_marker: 0.7016 - val_loss: -0.5319 - val_mean_iou: 0.8596 - val_mean_iou_marker: 0.7020
# Epoch 36/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4681 - mean_iou: 0.8601 - mean_iou_marker: 0.7024
# Epoch 00036: saving model to ./models/model.036.vl.-0.52.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4681 - mean_iou: 0.8601 - mean_iou_marker: 0.7024 - val_loss: -0.5167 - val_mean_iou: 0.8605 - val_mean_iou_marker: 0.7030
# Epoch 37/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4654 - mean_iou: 0.8608 - mean_iou_marker: 0.7034
# Epoch 00037: saving model to ./models/model.037.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4659 - mean_iou: 0.8608 - mean_iou_marker: 0.7034 - val_loss: -0.5118 - val_mean_iou: 0.8611 - val_mean_iou_marker: 0.7038
# Epoch 38/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4678 - mean_iou: 0.8615 - mean_iou_marker: 0.7043
# Epoch 00038: saving model to ./models/model.038.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4679 - mean_iou: 0.8615 - mean_iou_marker: 0.7043 - val_loss: -0.5106 - val_mean_iou: 0.8618 - val_mean_iou_marker: 0.7046
# Epoch 39/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4724 - mean_iou: 0.8622 - mean_iou_marker: 0.7050
# Epoch 00039: saving model to ./models/model.039.vl.-0.51.vi.0.86.vim.0.71.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4732 - mean_iou: 0.8622 - mean_iou_marker: 0.7050 - val_loss: -0.5114 - val_mean_iou: 0.8625 - val_mean_iou_marker: 0.7054
# Epoch 40/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4720 - mean_iou: 0.8629 - mean_iou_marker: 0.7059
# Epoch 00040: saving model to ./models/model.040.vl.-0.50.vi.0.86.vim.0.71.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4726 - mean_iou: 0.8629 - mean_iou_marker: 0.7059 - val_loss: -0.5017 - val_mean_iou: 0.8632 - val_mean_iou_marker: 0.7063
# Epoch 41/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4567 - mean_iou: 0.8635 - mean_iou_marker: 0.7066
# Epoch 00041: saving model to ./models/model.041.vl.-0.52.vi.0.86.vim.0.71.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4560 - mean_iou: 0.8635 - mean_iou_marker: 0.7066 - val_loss: -0.5160 - val_mean_iou: 0.8638 - val_mean_iou_marker: 0.7067
# Epoch 42/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4731 - mean_iou: 0.8640 - mean_iou_marker: 0.7071
# Epoch 00042: saving model to ./models/model.042.vl.-0.52.vi.0.86.vim.0.71.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4729 - mean_iou: 0.8640 - mean_iou_marker: 0.7071 - val_loss: -0.5208 - val_mean_iou: 0.8643 - val_mean_iou_marker: 0.7075
# Epoch 43/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4716 - mean_iou: 0.8646 - mean_iou_marker: 0.7078
# Epoch 00043: saving model to ./models/model.043.vl.-0.51.vi.0.86.vim.0.71.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4718 - mean_iou: 0.8646 - mean_iou_marker: 0.7078 - val_loss: -0.5056 - val_mean_iou: 0.8649 - val_mean_iou_marker: 0.7081
# Epoch 44/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4643 - mean_iou: 0.8651 - mean_iou_marker: 0.7084
# Epoch 00044: saving model to ./models/model.044.vl.-0.50.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4650 - mean_iou: 0.8651 - mean_iou_marker: 0.7084 - val_loss: -0.5020 - val_mean_iou: 0.8655 - val_mean_iou_marker: 0.7086
# Epoch 45/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4740 - mean_iou: 0.8658 - mean_iou_marker: 0.7090
# Epoch 00045: saving model to ./models/model.045.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4736 - mean_iou: 0.8658 - mean_iou_marker: 0.7090 - val_loss: -0.4871 - val_mean_iou: 0.8661 - val_mean_iou_marker: 0.7093
# Epoch 46/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4635 - mean_iou: 0.8663 - mean_iou_marker: 0.7095
# Epoch 00046: saving model to ./models/model.046.vl.-0.50.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4644 - mean_iou: 0.8663 - mean_iou_marker: 0.7095 - val_loss: -0.4993 - val_mean_iou: 0.8666 - val_mean_iou_marker: 0.7098
# Epoch 47/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4615 - mean_iou: 0.8668 - mean_iou_marker: 0.7099
# Epoch 00047: saving model to ./models/model.047.vl.-0.50.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4621 - mean_iou: 0.8668 - mean_iou_marker: 0.7099 - val_loss: -0.5004 - val_mean_iou: 0.8671 - val_mean_iou_marker: 0.7101
# Epoch 48/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4716 - mean_iou: 0.8672 - mean_iou_marker: 0.7104
# Epoch 00048: saving model to ./models/model.048.vl.-0.50.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4717 - mean_iou: 0.8672 - mean_iou_marker: 0.7104 - val_loss: -0.5017 - val_mean_iou: 0.8674 - val_mean_iou_marker: 0.7107
# Epoch 49/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4703 - mean_iou: 0.8677 - mean_iou_marker: 0.7108
# Epoch 00049: saving model to ./models/model.049.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4697 - mean_iou: 0.8677 - mean_iou_marker: 0.7109 - val_loss: -0.5155 - val_mean_iou: 0.8679 - val_mean_iou_marker: 0.7111
# Epoch 50/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4666 - mean_iou: 0.8683 - mean_iou_marker: 0.7113
# Epoch 00050: saving model to ./models/model.050.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4666 - mean_iou: 0.8683 - mean_iou_marker: 0.7113 - val_loss: -0.5228 - val_mean_iou: 0.8685 - val_mean_iou_marker: 0.7116
# Epoch 51/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4656 - mean_iou: 0.8687 - mean_iou_marker: 0.7118
# Epoch 00051: saving model to ./models/model.051.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4663 - mean_iou: 0.8687 - mean_iou_marker: 0.7118 - val_loss: -0.4940 - val_mean_iou: 0.8690 - val_mean_iou_marker: 0.7120
# Epoch 52/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4754 - mean_iou: 0.8692 - mean_iou_marker: 0.7124
# Epoch 00052: saving model to ./models/model.052.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4751 - mean_iou: 0.8692 - mean_iou_marker: 0.7124 - val_loss: -0.5150 - val_mean_iou: 0.8695 - val_mean_iou_marker: 0.7126
# Epoch 53/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4759 - mean_iou: 0.8697 - mean_iou_marker: 0.7128
# Epoch 00053: saving model to ./models/model.053.vl.-0.53.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4760 - mean_iou: 0.8697 - mean_iou_marker: 0.7128 - val_loss: -0.5326 - val_mean_iou: 0.8699 - val_mean_iou_marker: 0.7131
# Epoch 54/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4773 - mean_iou: 0.8702 - mean_iou_marker: 0.7135
# Epoch 00054: saving model to ./models/model.054.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4778 - mean_iou: 0.8702 - mean_iou_marker: 0.7135 - val_loss: -0.5226 - val_mean_iou: 0.8704 - val_mean_iou_marker: 0.7138
# Epoch 55/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4757 - mean_iou: 0.8706 - mean_iou_marker: 0.7141
# Epoch 00055: saving model to ./models/model.055.vl.-0.51.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4747 - mean_iou: 0.8706 - mean_iou_marker: 0.7141 - val_loss: -0.5121 - val_mean_iou: 0.8708 - val_mean_iou_marker: 0.7142
# Epoch 56/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4741 - mean_iou: 0.8710 - mean_iou_marker: 0.7145
# Epoch 00056: saving model to ./models/model.056.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 88s 1s/step - loss: -0.4736 - mean_iou: 0.8710 - mean_iou_marker: 0.7145 - val_loss: -0.5154 - val_mean_iou: 0.8712 - val_mean_iou_marker: 0.7147
# Epoch 57/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4790 - mean_iou: 0.8715 - mean_iou_marker: 0.7150
# Epoch 00057: saving model to ./models/model.057.vl.-0.53.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4776 - mean_iou: 0.8715 - mean_iou_marker: 0.7150 - val_loss: -0.5287 - val_mean_iou: 0.8716 - val_mean_iou_marker: 0.7152
# Epoch 58/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4793 - mean_iou: 0.8719 - mean_iou_marker: 0.7155
# Epoch 00058: saving model to ./models/model.058.vl.-0.53.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4795 - mean_iou: 0.8719 - mean_iou_marker: 0.7155 - val_loss: -0.5290 - val_mean_iou: 0.8720 - val_mean_iou_marker: 0.7158
# Epoch 59/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4820 - mean_iou: 0.8723 - mean_iou_marker: 0.7161
# Epoch 00059: saving model to ./models/model.059.vl.-0.52.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4819 - mean_iou: 0.8723 - mean_iou_marker: 0.7161 - val_loss: -0.5175 - val_mean_iou: 0.8724 - val_mean_iou_marker: 0.7163
# Epoch 60/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4785 - mean_iou: 0.8726 - mean_iou_marker: 0.7165
# Epoch 00060: saving model to ./models/model.060.vl.-0.51.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4786 - mean_iou: 0.8726 - mean_iou_marker: 0.7165 - val_loss: -0.5059 - val_mean_iou: 0.8728 - val_mean_iou_marker: 0.7167
# Epoch 61/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4631 - mean_iou: 0.8730 - mean_iou_marker: 0.7168
# Epoch 00061: saving model to ./models/model.061.vl.-0.52.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4634 - mean_iou: 0.8730 - mean_iou_marker: 0.7168 - val_loss: -0.5218 - val_mean_iou: 0.8731 - val_mean_iou_marker: 0.7170
# Epoch 62/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4722 - mean_iou: 0.8733 - mean_iou_marker: 0.7171
# Epoch 00062: saving model to ./models/model.062.vl.-0.52.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4720 - mean_iou: 0.8733 - mean_iou_marker: 0.7171 - val_loss: -0.5199 - val_mean_iou: 0.8735 - val_mean_iou_marker: 0.7173
# Epoch 63/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4799 - mean_iou: 0.8736 - mean_iou_marker: 0.7176
# Epoch 00063: saving model to ./models/model.063.vl.-0.53.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4799 - mean_iou: 0.8736 - mean_iou_marker: 0.7176 - val_loss: -0.5295 - val_mean_iou: 0.8738 - val_mean_iou_marker: 0.7178
# Epoch 64/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4822 - mean_iou: 0.8739 - mean_iou_marker: 0.7181
# Epoch 00064: saving model to ./models/model.064.vl.-0.53.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4827 - mean_iou: 0.8739 - mean_iou_marker: 0.7181 - val_loss: -0.5253 - val_mean_iou: 0.8741 - val_mean_iou_marker: 0.7183
# Epoch 65/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4848 - mean_iou: 0.8742 - mean_iou_marker: 0.7186
# Epoch 00065: saving model to ./models/model.065.vl.-0.52.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4832 - mean_iou: 0.8742 - mean_iou_marker: 0.7186 - val_loss: -0.5234 - val_mean_iou: 0.8744 - val_mean_iou_marker: 0.7188
# Epoch 66/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4733 - mean_iou: 0.8746 - mean_iou_marker: 0.7190
# Epoch 00066: saving model to ./models/model.066.vl.-0.51.vi.0.87.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4729 - mean_iou: 0.8746 - mean_iou_marker: 0.7190 - val_loss: -0.5122 - val_mean_iou: 0.8747 - val_mean_iou_marker: 0.7191
# Epoch 67/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4763 - mean_iou: 0.8749 - mean_iou_marker: 0.7193
# Epoch 00067: saving model to ./models/model.067.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4771 - mean_iou: 0.8749 - mean_iou_marker: 0.7193 - val_loss: -0.4984 - val_mean_iou: 0.8751 - val_mean_iou_marker: 0.7194
# Epoch 68/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4837 - mean_iou: 0.8752 - mean_iou_marker: 0.7196
# Epoch 00068: saving model to ./models/model.068.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4836 - mean_iou: 0.8752 - mean_iou_marker: 0.7196 - val_loss: -0.5180 - val_mean_iou: 0.8754 - val_mean_iou_marker: 0.7198
# Epoch 69/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4831 - mean_iou: 0.8756 - mean_iou_marker: 0.7199
# Epoch 00069: saving model to ./models/model.069.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4830 - mean_iou: 0.8756 - mean_iou_marker: 0.7199 - val_loss: -0.5184 - val_mean_iou: 0.8757 - val_mean_iou_marker: 0.7201
# Epoch 70/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4842 - mean_iou: 0.8758 - mean_iou_marker: 0.7204
# Epoch 00070: saving model to ./models/model.070.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4852 - mean_iou: 0.8758 - mean_iou_marker: 0.7204 - val_loss: -0.5293 - val_mean_iou: 0.8760 - val_mean_iou_marker: 0.7206
# Epoch 71/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4756 - mean_iou: 0.8762 - mean_iou_marker: 0.7207
# Epoch 00071: saving model to ./models/model.071.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4742 - mean_iou: 0.8762 - mean_iou_marker: 0.7207 - val_loss: -0.5100 - val_mean_iou: 0.8763 - val_mean_iou_marker: 0.7209
# Epoch 72/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4799 - mean_iou: 0.8764 - mean_iou_marker: 0.7211
# Epoch 00072: saving model to ./models/model.072.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4785 - mean_iou: 0.8764 - mean_iou_marker: 0.7211 - val_loss: -0.5230 - val_mean_iou: 0.8765 - val_mean_iou_marker: 0.7213
# Epoch 73/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4761 - mean_iou: 0.8765 - mean_iou_marker: 0.7214
# Epoch 00073: saving model to ./models/model.073.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4755 - mean_iou: 0.8765 - mean_iou_marker: 0.7214 - val_loss: -0.5055 - val_mean_iou: 0.8766 - val_mean_iou_marker: 0.7216
# Epoch 74/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4784 - mean_iou: 0.8768 - mean_iou_marker: 0.7217
# Epoch 00074: saving model to ./models/model.074.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4790 - mean_iou: 0.8768 - mean_iou_marker: 0.7217 - val_loss: -0.5313 - val_mean_iou: 0.8769 - val_mean_iou_marker: 0.7219
# Epoch 75/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4899 - mean_iou: 0.8770 - mean_iou_marker: 0.7221
# Epoch 00075: saving model to ./models/model.075.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4893 - mean_iou: 0.8770 - mean_iou_marker: 0.7221 - val_loss: -0.5167 - val_mean_iou: 0.8772 - val_mean_iou_marker: 0.7223
# Epoch 76/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4900 - mean_iou: 0.8773 - mean_iou_marker: 0.7225
# Epoch 00076: saving model to ./models/model.076.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4901 - mean_iou: 0.8773 - mean_iou_marker: 0.7225 - val_loss: -0.5229 - val_mean_iou: 0.8775 - val_mean_iou_marker: 0.7227
# Epoch 77/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4755 - mean_iou: 0.8776 - mean_iou_marker: 0.7229
# Epoch 00077: saving model to ./models/model.077.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4769 - mean_iou: 0.8776 - mean_iou_marker: 0.7229 - val_loss: -0.5068 - val_mean_iou: 0.8777 - val_mean_iou_marker: 0.7230
# Epoch 78/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4733 - mean_iou: 0.8778 - mean_iou_marker: 0.7231
# Epoch 00078: saving model to ./models/model.078.vl.-0.55.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4733 - mean_iou: 0.8778 - mean_iou_marker: 0.7231 - val_loss: -0.5479 - val_mean_iou: 0.8779 - val_mean_iou_marker: 0.7232
# Epoch 79/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4846 - mean_iou: 0.8780 - mean_iou_marker: 0.7234
# Epoch 00079: saving model to ./models/model.079.vl.-0.54.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4846 - mean_iou: 0.8780 - mean_iou_marker: 0.7234 - val_loss: -0.5443 - val_mean_iou: 0.8782 - val_mean_iou_marker: 0.7235
# Epoch 80/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4780 - mean_iou: 0.8783 - mean_iou_marker: 0.7237
# Epoch 00080: saving model to ./models/model.080.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4775 - mean_iou: 0.8783 - mean_iou_marker: 0.7237 - val_loss: -0.5329 - val_mean_iou: 0.8784 - val_mean_iou_marker: 0.7238
# Epoch 81/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4801 - mean_iou: 0.8785 - mean_iou_marker: 0.7240
# Epoch 00081: saving model to ./models/model.081.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4798 - mean_iou: 0.8785 - mean_iou_marker: 0.7240 - val_loss: -0.5283 - val_mean_iou: 0.8786 - val_mean_iou_marker: 0.7241
# Epoch 82/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4926 - mean_iou: 0.8787 - mean_iou_marker: 0.7243
# Epoch 00082: saving model to ./models/model.082.vl.-0.54.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4920 - mean_iou: 0.8787 - mean_iou_marker: 0.7243 - val_loss: -0.5358 - val_mean_iou: 0.8788 - val_mean_iou_marker: 0.7245
# Epoch 83/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4847 - mean_iou: 0.8789 - mean_iou_marker: 0.7247
# Epoch 00083: saving model to ./models/model.083.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4844 - mean_iou: 0.8789 - mean_iou_marker: 0.7247 - val_loss: -0.5284 - val_mean_iou: 0.8790 - val_mean_iou_marker: 0.7249
# Epoch 84/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4924 - mean_iou: 0.8791 - mean_iou_marker: 0.7251
# Epoch 00084: saving model to ./models/model.084.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4927 - mean_iou: 0.8791 - mean_iou_marker: 0.7251 - val_loss: -0.5351 - val_mean_iou: 0.8792 - val_mean_iou_marker: 0.7252
# Epoch 85/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4918 - mean_iou: 0.8794 - mean_iou_marker: 0.7254
# Epoch 00085: saving model to ./models/model.085.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4919 - mean_iou: 0.8794 - mean_iou_marker: 0.7254 - val_loss: -0.5221 - val_mean_iou: 0.8795 - val_mean_iou_marker: 0.7256
# Epoch 86/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4903 - mean_iou: 0.8796 - mean_iou_marker: 0.7258
# Epoch 00086: saving model to ./models/model.086.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4902 - mean_iou: 0.8796 - mean_iou_marker: 0.7258 - val_loss: -0.5177 - val_mean_iou: 0.8797 - val_mean_iou_marker: 0.7259
# Epoch 87/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4846 - mean_iou: 0.8798 - mean_iou_marker: 0.7260
# Epoch 00087: saving model to ./models/model.087.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4847 - mean_iou: 0.8798 - mean_iou_marker: 0.7260 - val_loss: -0.5258 - val_mean_iou: 0.8799 - val_mean_iou_marker: 0.7262
# Epoch 88/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4819 - mean_iou: 0.8800 - mean_iou_marker: 0.7263
# Epoch 00088: saving model to ./models/model.088.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4813 - mean_iou: 0.8800 - mean_iou_marker: 0.7263 - val_loss: -0.5125 - val_mean_iou: 0.8801 - val_mean_iou_marker: 0.7265
# Epoch 89/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4873 - mean_iou: 0.8802 - mean_iou_marker: 0.7266
# Epoch 00089: saving model to ./models/model.089.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4870 - mean_iou: 0.8802 - mean_iou_marker: 0.7266 - val_loss: -0.5187 - val_mean_iou: 0.8803 - val_mean_iou_marker: 0.7268
# Epoch 90/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4888 - mean_iou: 0.8804 - mean_iou_marker: 0.7269
# Epoch 00090: saving model to ./models/model.090.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4886 - mean_iou: 0.8804 - mean_iou_marker: 0.7269 - val_loss: -0.5112 - val_mean_iou: 0.8805 - val_mean_iou_marker: 0.7271
# Epoch 91/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4840 - mean_iou: 0.8806 - mean_iou_marker: 0.7271
# Epoch 00091: saving model to ./models/model.091.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4838 - mean_iou: 0.8806 - mean_iou_marker: 0.7271 - val_loss: -0.5167 - val_mean_iou: 0.8807 - val_mean_iou_marker: 0.7273
# Epoch 92/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4859 - mean_iou: 0.8808 - mean_iou_marker: 0.7274
# Epoch 00092: saving model to ./models/model.092.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4856 - mean_iou: 0.8808 - mean_iou_marker: 0.7274 - val_loss: -0.5077 - val_mean_iou: 0.8809 - val_mean_iou_marker: 0.7276
# Epoch 93/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4843 - mean_iou: 0.8810 - mean_iou_marker: 0.7277
# Epoch 00093: saving model to ./models/model.093.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4837 - mean_iou: 0.8810 - mean_iou_marker: 0.7277 - val_loss: -0.5331 - val_mean_iou: 0.8811 - val_mean_iou_marker: 0.7278
# Epoch 94/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4801 - mean_iou: 0.8812 - mean_iou_marker: 0.7279
# Epoch 00094: saving model to ./models/model.094.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4801 - mean_iou: 0.8812 - mean_iou_marker: 0.7279 - val_loss: -0.5158 - val_mean_iou: 0.8812 - val_mean_iou_marker: 0.7280
# Epoch 95/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4860 - mean_iou: 0.8813 - mean_iou_marker: 0.7281
# Epoch 00095: saving model to ./models/model.095.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4864 - mean_iou: 0.8813 - mean_iou_marker: 0.7281 - val_loss: -0.5266 - val_mean_iou: 0.8814 - val_mean_iou_marker: 0.7282
# Epoch 96/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4827 - mean_iou: 0.8815 - mean_iou_marker: 0.7284
# Epoch 00096: saving model to ./models/model.096.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4826 - mean_iou: 0.8815 - mean_iou_marker: 0.7284 - val_loss: -0.5232 - val_mean_iou: 0.8816 - val_mean_iou_marker: 0.7285
# Epoch 97/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4858 - mean_iou: 0.8817 - mean_iou_marker: 0.7286
# Epoch 00097: saving model to ./models/model.097.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4853 - mean_iou: 0.8817 - mean_iou_marker: 0.7286 - val_loss: -0.5341 - val_mean_iou: 0.8818 - val_mean_iou_marker: 0.7287
# Epoch 98/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4884 - mean_iou: 0.8820 - mean_iou_marker: 0.7288
# Epoch 00098: saving model to ./models/model.098.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4887 - mean_iou: 0.8820 - mean_iou_marker: 0.7288 - val_loss: -0.5351 - val_mean_iou: 0.8821 - val_mean_iou_marker: 0.7289
# Epoch 99/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4869 - mean_iou: 0.8822 - mean_iou_marker: 0.7291
# Epoch 00099: saving model to ./models/model.099.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4878 - mean_iou: 0.8822 - mean_iou_marker: 0.7291 - val_loss: -0.5405 - val_mean_iou: 0.8823 - val_mean_iou_marker: 0.7292
# Epoch 100/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4853 - mean_iou: 0.8824 - mean_iou_marker: 0.7292
# Epoch 00100: saving model to ./models/model.100.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4857 - mean_iou: 0.8824 - mean_iou_marker: 0.7293 - val_loss: -0.5370 - val_mean_iou: 0.8824 - val_mean_iou_marker: 0.7294
# Epoch 101/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4808 - mean_iou: 0.8825 - mean_iou_marker: 0.7295
# Epoch 00101: saving model to ./models/model.101.vl.-0.55.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4808 - mean_iou: 0.8825 - mean_iou_marker: 0.7295 - val_loss: -0.5469 - val_mean_iou: 0.8826 - val_mean_iou_marker: 0.7296
# Epoch 102/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4874 - mean_iou: 0.8827 - mean_iou_marker: 0.7297
# Epoch 00102: saving model to ./models/model.102.vl.-0.55.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4866 - mean_iou: 0.8827 - mean_iou_marker: 0.7297 - val_loss: -0.5462 - val_mean_iou: 0.8828 - val_mean_iou_marker: 0.7298
# Epoch 103/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4856 - mean_iou: 0.8829 - mean_iou_marker: 0.7299
# Epoch 00103: saving model to ./models/model.103.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4866 - mean_iou: 0.8829 - mean_iou_marker: 0.7299 - val_loss: -0.5412 - val_mean_iou: 0.8829 - val_mean_iou_marker: 0.7300
# Epoch 104/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4939 - mean_iou: 0.8830 - mean_iou_marker: 0.7301
# Epoch 00104: saving model to ./models/model.104.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4946 - mean_iou: 0.8830 - mean_iou_marker: 0.7301 - val_loss: -0.5370 - val_mean_iou: 0.8831 - val_mean_iou_marker: 0.7303
# Epoch 105/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4889 - mean_iou: 0.8832 - mean_iou_marker: 0.7304
# Epoch 00105: saving model to ./models/model.105.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4880 - mean_iou: 0.8832 - mean_iou_marker: 0.7304 - val_loss: -0.5372 - val_mean_iou: 0.8833 - val_mean_iou_marker: 0.7305
# Epoch 106/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4830 - mean_iou: 0.8834 - mean_iou_marker: 0.7306
# Epoch 00106: saving model to ./models/model.106.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4824 - mean_iou: 0.8834 - mean_iou_marker: 0.7306 - val_loss: -0.5368 - val_mean_iou: 0.8835 - val_mean_iou_marker: 0.7307
# Epoch 107/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4940 - mean_iou: 0.8836 - mean_iou_marker: 0.7309
# Epoch 00107: saving model to ./models/model.107.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4944 - mean_iou: 0.8836 - mean_iou_marker: 0.7309 - val_loss: -0.5395 - val_mean_iou: 0.8836 - val_mean_iou_marker: 0.7310
# Epoch 108/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4910 - mean_iou: 0.8837 - mean_iou_marker: 0.7311
# Epoch 00108: saving model to ./models/model.108.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4907 - mean_iou: 0.8837 - mean_iou_marker: 0.7311 - val_loss: -0.5288 - val_mean_iou: 0.8838 - val_mean_iou_marker: 0.7312
# Epoch 109/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4904 - mean_iou: 0.8839 - mean_iou_marker: 0.7313
# Epoch 00109: saving model to ./models/model.109.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 86s 1s/step - loss: -0.4902 - mean_iou: 0.8839 - mean_iou_marker: 0.7313 - val_loss: -0.5220 - val_mean_iou: 0.8840 - val_mean_iou_marker: 0.7314
# Epoch 110/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4873 - mean_iou: 0.8840 - mean_iou_marker: 0.7315
# Epoch 00110: saving model to ./models/model.110.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 88s 1s/step - loss: -0.4870 - mean_iou: 0.8840 - mean_iou_marker: 0.7315 - val_loss: -0.5380 - val_mean_iou: 0.8840 - val_mean_iou_marker: 0.7316
# Epoch 111/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4862 - mean_iou: 0.8841 - mean_iou_marker: 0.7317
# Epoch 00111: saving model to ./models/model.111.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4866 - mean_iou: 0.8841 - mean_iou_marker: 0.7317 - val_loss: -0.5221 - val_mean_iou: 0.8842 - val_mean_iou_marker: 0.7318
# Epoch 112/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4849 - mean_iou: 0.8843 - mean_iou_marker: 0.7319
# Epoch 00112: saving model to ./models/model.112.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4851 - mean_iou: 0.8843 - mean_iou_marker: 0.7319 - val_loss: -0.5160 - val_mean_iou: 0.8844 - val_mean_iou_marker: 0.7319
# Epoch 113/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4907 - mean_iou: 0.8844 - mean_iou_marker: 0.7320
# Epoch 00113: saving model to ./models/model.113.vl.-0.49.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4904 - mean_iou: 0.8844 - mean_iou_marker: 0.7320 - val_loss: -0.4949 - val_mean_iou: 0.8845 - val_mean_iou_marker: 0.7321
# Epoch 114/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4868 - mean_iou: 0.8846 - mean_iou_marker: 0.7322
# Epoch 00114: saving model to ./models/model.114.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4867 - mean_iou: 0.8846 - mean_iou_marker: 0.7322 - val_loss: -0.5282 - val_mean_iou: 0.8846 - val_mean_iou_marker: 0.7323
# Epoch 115/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4909 - mean_iou: 0.8847 - mean_iou_marker: 0.7324
# Epoch 00115: saving model to ./models/model.115.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4902 - mean_iou: 0.8847 - mean_iou_marker: 0.7324 - val_loss: -0.5223 - val_mean_iou: 0.8848 - val_mean_iou_marker: 0.7325
# Epoch 116/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4797 - mean_iou: 0.8848 - mean_iou_marker: 0.7325
# Epoch 00116: saving model to ./models/model.116.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4808 - mean_iou: 0.8848 - mean_iou_marker: 0.7325 - val_loss: -0.5319 - val_mean_iou: 0.8849 - val_mean_iou_marker: 0.7326
# Epoch 117/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4823 - mean_iou: 0.8850 - mean_iou_marker: 0.7326
# Epoch 00117: saving model to ./models/model.117.vl.-0.52.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4825 - mean_iou: 0.8850 - mean_iou_marker: 0.7326 - val_loss: -0.5246 - val_mean_iou: 0.8851 - val_mean_iou_marker: 0.7327
# Epoch 118/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4914 - mean_iou: 0.8851 - mean_iou_marker: 0.7328
# Epoch 00118: saving model to ./models/model.118.vl.-0.53.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4920 - mean_iou: 0.8851 - mean_iou_marker: 0.7328 - val_loss: -0.5309 - val_mean_iou: 0.8852 - val_mean_iou_marker: 0.7329
# Epoch 119/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4882 - mean_iou: 0.8853 - mean_iou_marker: 0.7329
# Epoch 00119: saving model to ./models/model.119.vl.-0.54.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4878 - mean_iou: 0.8853 - mean_iou_marker: 0.7329 - val_loss: -0.5374 - val_mean_iou: 0.8854 - val_mean_iou_marker: 0.7330
# Epoch 120/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4907 - mean_iou: 0.8854 - mean_iou_marker: 0.7331
# Epoch 00120: saving model to ./models/model.120.vl.-0.53.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4909 - mean_iou: 0.8854 - mean_iou_marker: 0.7331 - val_loss: -0.5260 - val_mean_iou: 0.8855 - val_mean_iou_marker: 0.7332
# Epoch 121/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4858 - mean_iou: 0.8856 - mean_iou_marker: 0.7332
# Epoch 00121: saving model to ./models/model.121.vl.-0.54.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4862 - mean_iou: 0.8856 - mean_iou_marker: 0.7332 - val_loss: -0.5364 - val_mean_iou: 0.8857 - val_mean_iou_marker: 0.7333
# Epoch 122/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4911 - mean_iou: 0.8857 - mean_iou_marker: 0.7334
# Epoch 00122: saving model to ./models/model.122.vl.-0.54.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: -0.4912 - mean_iou: 0.8857 - mean_iou_marker: 0.7334 - val_loss: -0.5417 - val_mean_iou: 0.8858 - val_mean_iou_marker: 0.7335
# Epoch 123/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4990 - mean_iou: 0.8859 - mean_iou_marker: 0.7336
# Epoch 00123: saving model to ./models/model.123.vl.-0.54.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 85s 1s/step - loss: -0.4993 - mean_iou: 0.8859 - mean_iou_marker: 0.7336 - val_loss: -0.5447 - val_mean_iou: 0.8860 - val_mean_iou_marker: 0.7338
# Epoch 124/300
# 74/75 [============================>.] - ETA: 1s - loss: -0.4854 - mean_iou: 0.8860 - mean_iou_marker: 0.7339
# Epoch 00124: saving model to ./models/model.124.vl.-0.55.vi.0.89.vim.0.73.h5
# ...
# 75/75 [==============================] - 81s 1s/step - loss: 0.3049 - mean_iou: 0.8935 - mean_iou_marker: 0.7482 - val_loss: 0.2961 - val_mean_iou: 0.8926 - val_mean_iou_marker: 0.7477
# Epoch 260/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2910 - mean_iou: 0.8918 - mean_iou_marker: 0.7474
# Epoch 00260: saving model to ./models/model.260.vl.0.30.vi.0.89.vim.0.75.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2918 - mean_iou: 0.8918 - mean_iou_marker: 0.7474 - val_loss: 0.3042 - val_mean_iou: 0.8909 - val_mean_iou_marker: 0.7470
# Epoch 261/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2987 - mean_iou: 0.8901 - mean_iou_marker: 0.7466
# Epoch 00261: saving model to ./models/model.261.vl.0.27.vi.0.89.vim.0.75.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2989 - mean_iou: 0.8901 - mean_iou_marker: 0.7466 - val_loss: 0.2734 - val_mean_iou: 0.8892 - val_mean_iou_marker: 0.7462
# Epoch 262/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2842 - mean_iou: 0.8885 - mean_iou_marker: 0.7459
# Epoch 00262: saving model to ./models/model.262.vl.0.29.vi.0.89.vim.0.75.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.2868 - mean_iou: 0.8885 - mean_iou_marker: 0.7459 - val_loss: 0.2858 - val_mean_iou: 0.8876 - val_mean_iou_marker: 0.7455
# Epoch 263/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2991 - mean_iou: 0.8868 - mean_iou_marker: 0.7451
# Epoch 00263: saving model to ./models/model.263.vl.0.27.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.2978 - mean_iou: 0.8868 - mean_iou_marker: 0.7451 - val_loss: 0.2745 - val_mean_iou: 0.8860 - val_mean_iou_marker: 0.7447
# Epoch 264/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2979 - mean_iou: 0.8852 - mean_iou_marker: 0.7444
# Epoch 00264: saving model to ./models/model.264.vl.0.27.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2985 - mean_iou: 0.8852 - mean_iou_marker: 0.7444 - val_loss: 0.2719 - val_mean_iou: 0.8844 - val_mean_iou_marker: 0.7440
# Epoch 265/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3022 - mean_iou: 0.8836 - mean_iou_marker: 0.7436
# Epoch 00265: saving model to ./models/model.265.vl.0.30.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.3020 - mean_iou: 0.8836 - mean_iou_marker: 0.7436 - val_loss: 0.3028 - val_mean_iou: 0.8827 - val_mean_iou_marker: 0.7432
# Epoch 266/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2932 - mean_iou: 0.8820 - mean_iou_marker: 0.7428
# Epoch 00266: saving model to ./models/model.266.vl.0.30.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2952 - mean_iou: 0.8820 - mean_iou_marker: 0.7428 - val_loss: 0.2968 - val_mean_iou: 0.8811 - val_mean_iou_marker: 0.7425
# Epoch 267/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2850 - mean_iou: 0.8804 - mean_iou_marker: 0.7421
# Epoch 00267: saving model to ./models/model.267.vl.0.29.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2873 - mean_iou: 0.8804 - mean_iou_marker: 0.7421 - val_loss: 0.2875 - val_mean_iou: 0.8796 - val_mean_iou_marker: 0.7417
# Epoch 268/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2980 - mean_iou: 0.8788 - mean_iou_marker: 0.7413
# Epoch 00268: saving model to ./models/model.268.vl.0.29.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.2981 - mean_iou: 0.8788 - mean_iou_marker: 0.7413 - val_loss: 0.2921 - val_mean_iou: 0.8780 - val_mean_iou_marker: 0.7410
# Epoch 269/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2923 - mean_iou: 0.8772 - mean_iou_marker: 0.7406
# Epoch 00269: saving model to ./models/model.269.vl.0.29.vi.0.88.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: 0.2922 - mean_iou: 0.8772 - mean_iou_marker: 0.7406 - val_loss: 0.2928 - val_mean_iou: 0.8764 - val_mean_iou_marker: 0.7403
# Epoch 270/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2989 - mean_iou: 0.8756 - mean_iou_marker: 0.7399
# Epoch 00270: saving model to ./models/model.270.vl.0.28.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.2970 - mean_iou: 0.8756 - mean_iou_marker: 0.7399 - val_loss: 0.2843 - val_mean_iou: 0.8749 - val_mean_iou_marker: 0.7395
# Epoch 271/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2961 - mean_iou: 0.8741 - mean_iou_marker: 0.7392
# Epoch 00271: saving model to ./models/model.271.vl.0.28.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2957 - mean_iou: 0.8741 - mean_iou_marker: 0.7392 - val_loss: 0.2842 - val_mean_iou: 0.8733 - val_mean_iou_marker: 0.7388
# Epoch 272/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2931 - mean_iou: 0.8726 - mean_iou_marker: 0.7385
# Epoch 00272: saving model to ./models/model.272.vl.0.29.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.2928 - mean_iou: 0.8725 - mean_iou_marker: 0.7385 - val_loss: 0.2865 - val_mean_iou: 0.8718 - val_mean_iou_marker: 0.7381
# Epoch 273/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3124 - mean_iou: 0.8710 - mean_iou_marker: 0.7377
# Epoch 00273: saving model to ./models/model.273.vl.0.30.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 83s 1s/step - loss: 0.3103 - mean_iou: 0.8710 - mean_iou_marker: 0.7377 - val_loss: 0.2968 - val_mean_iou: 0.8702 - val_mean_iou_marker: 0.7374
# Epoch 274/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2983 - mean_iou: 0.8695 - mean_iou_marker: 0.7370
# Epoch 00274: saving model to ./models/model.274.vl.0.32.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.2985 - mean_iou: 0.8695 - mean_iou_marker: 0.7370 - val_loss: 0.3176 - val_mean_iou: 0.8687 - val_mean_iou_marker: 0.7366
# Epoch 275/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3008 - mean_iou: 0.8679 - mean_iou_marker: 0.7363
# Epoch 00275: saving model to ./models/model.275.vl.0.30.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.3018 - mean_iou: 0.8679 - mean_iou_marker: 0.7363 - val_loss: 0.3000 - val_mean_iou: 0.8671 - val_mean_iou_marker: 0.7359
# Epoch 276/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2938 - mean_iou: 0.8664 - mean_iou_marker: 0.7356
# Epoch 00276: saving model to ./models/model.276.vl.0.29.vi.0.87.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2939 - mean_iou: 0.8664 - mean_iou_marker: 0.7356 - val_loss: 0.2914 - val_mean_iou: 0.8656 - val_mean_iou_marker: 0.7352
# Epoch 277/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.3064 - mean_iou: 0.8648 - mean_iou_marker: 0.7349
# Epoch 00277: saving model to ./models/model.277.vl.0.29.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.3061 - mean_iou: 0.8648 - mean_iou_marker: 0.7349 - val_loss: 0.2936 - val_mean_iou: 0.8641 - val_mean_iou_marker: 0.7345
# Epoch 278/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.3011 - mean_iou: 0.8633 - mean_iou_marker: 0.7342
# Epoch 00278: saving model to ./models/model.278.vl.0.28.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: 0.3007 - mean_iou: 0.8633 - mean_iou_marker: 0.7342 - val_loss: 0.2822 - val_mean_iou: 0.8625 - val_mean_iou_marker: 0.7338
# Epoch 279/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2972 - mean_iou: 0.8618 - mean_iou_marker: 0.7335
# Epoch 00279: saving model to ./models/model.279.vl.0.26.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2981 - mean_iou: 0.8618 - mean_iou_marker: 0.7335 - val_loss: 0.2638 - val_mean_iou: 0.8611 - val_mean_iou_marker: 0.7332
# Epoch 280/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2942 - mean_iou: 0.8603 - mean_iou_marker: 0.7328
# Epoch 00280: saving model to ./models/model.280.vl.0.27.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.2948 - mean_iou: 0.8603 - mean_iou_marker: 0.7328 - val_loss: 0.2723 - val_mean_iou: 0.8596 - val_mean_iou_marker: 0.7325
# Epoch 281/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2993 - mean_iou: 0.8589 - mean_iou_marker: 0.7322
# Epoch 00281: saving model to ./models/model.281.vl.0.30.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.2992 - mean_iou: 0.8589 - mean_iou_marker: 0.7322 - val_loss: 0.3009 - val_mean_iou: 0.8581 - val_mean_iou_marker: 0.7318
# Epoch 282/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2966 - mean_iou: 0.8574 - mean_iou_marker: 0.7315
# Epoch 00282: saving model to ./models/model.282.vl.0.30.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2944 - mean_iou: 0.8574 - mean_iou_marker: 0.7315 - val_loss: 0.3030 - val_mean_iou: 0.8567 - val_mean_iou_marker: 0.7311
# Epoch 283/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.3088 - mean_iou: 0.8560 - mean_iou_marker: 0.7308
# Epoch 00283: saving model to ./models/model.283.vl.0.29.vi.0.86.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.3076 - mean_iou: 0.8560 - mean_iou_marker: 0.7308 - val_loss: 0.2872 - val_mean_iou: 0.8552 - val_mean_iou_marker: 0.7304
# Epoch 284/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2919 - mean_iou: 0.8545 - mean_iou_marker: 0.7301
# Epoch 00284: saving model to ./models/model.284.vl.0.30.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2928 - mean_iou: 0.8545 - mean_iou_marker: 0.7301 - val_loss: 0.2993 - val_mean_iou: 0.8538 - val_mean_iou_marker: 0.7298
# Epoch 285/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3025 - mean_iou: 0.8531 - mean_iou_marker: 0.7294
# Epoch 00285: saving model to ./models/model.285.vl.0.30.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 84s 1s/step - loss: 0.3010 - mean_iou: 0.8531 - mean_iou_marker: 0.7294 - val_loss: 0.2967 - val_mean_iou: 0.8524 - val_mean_iou_marker: 0.7291
# Epoch 286/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2896 - mean_iou: 0.8517 - mean_iou_marker: 0.7287
# Epoch 00286: saving model to ./models/model.286.vl.0.28.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.2903 - mean_iou: 0.8517 - mean_iou_marker: 0.7287 - val_loss: 0.2830 - val_mean_iou: 0.8510 - val_mean_iou_marker: 0.7284
# Epoch 287/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2948 - mean_iou: 0.8504 - mean_iou_marker: 0.7281
# Epoch 00287: saving model to ./models/model.287.vl.0.28.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2954 - mean_iou: 0.8504 - mean_iou_marker: 0.7281 - val_loss: 0.2786 - val_mean_iou: 0.8497 - val_mean_iou_marker: 0.7278
# Epoch 288/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3068 - mean_iou: 0.8490 - mean_iou_marker: 0.7274
# Epoch 00288: saving model to ./models/model.288.vl.0.29.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 82s 1s/step - loss: 0.3065 - mean_iou: 0.8489 - mean_iou_marker: 0.7274 - val_loss: 0.2879 - val_mean_iou: 0.8482 - val_mean_iou_marker: 0.7271
# Epoch 289/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2894 - mean_iou: 0.8476 - mean_iou_marker: 0.7268
# Epoch 00289: saving model to ./models/model.289.vl.0.30.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2911 - mean_iou: 0.8476 - mean_iou_marker: 0.7268 - val_loss: 0.2979 - val_mean_iou: 0.8469 - val_mean_iou_marker: 0.7265
# Epoch 290/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2970 - mean_iou: 0.8462 - mean_iou_marker: 0.7261
# Epoch 00290: saving model to ./models/model.290.vl.0.26.vi.0.85.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2976 - mean_iou: 0.8462 - mean_iou_marker: 0.7261 - val_loss: 0.2566 - val_mean_iou: 0.8456 - val_mean_iou_marker: 0.7258
# Epoch 291/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3028 - mean_iou: 0.8449 - mean_iou_marker: 0.7255
# Epoch 00291: saving model to ./models/model.291.vl.0.26.vi.0.84.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.3037 - mean_iou: 0.8449 - mean_iou_marker: 0.7255 - val_loss: 0.2589 - val_mean_iou: 0.8442 - val_mean_iou_marker: 0.7251
# Epoch 292/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2876 - mean_iou: 0.8436 - mean_iou_marker: 0.7248
# Epoch 00292: saving model to ./models/model.292.vl.0.26.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2886 - mean_iou: 0.8436 - mean_iou_marker: 0.7248 - val_loss: 0.2567 - val_mean_iou: 0.8429 - val_mean_iou_marker: 0.7245
# Epoch 293/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.3043 - mean_iou: 0.8422 - mean_iou_marker: 0.7242
# Epoch 00293: saving model to ./models/model.293.vl.0.28.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.3033 - mean_iou: 0.8422 - mean_iou_marker: 0.7242 - val_loss: 0.2816 - val_mean_iou: 0.8415 - val_mean_iou_marker: 0.7239
# Epoch 294/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.2912 - mean_iou: 0.8409 - mean_iou_marker: 0.7236
# Epoch 00294: saving model to ./models/model.294.vl.0.31.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.2912 - mean_iou: 0.8409 - mean_iou_marker: 0.7236 - val_loss: 0.3053 - val_mean_iou: 0.8402 - val_mean_iou_marker: 0.7233
# Epoch 295/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3021 - mean_iou: 0.8396 - mean_iou_marker: 0.7229
# Epoch 00295: saving model to ./models/model.295.vl.0.33.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.3033 - mean_iou: 0.8395 - mean_iou_marker: 0.7229 - val_loss: 0.3251 - val_mean_iou: 0.8389 - val_mean_iou_marker: 0.7226
# Epoch 296/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.2929 - mean_iou: 0.8382 - mean_iou_marker: 0.7223
# Epoch 00296: saving model to ./models/model.296.vl.0.29.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: 0.2942 - mean_iou: 0.8382 - mean_iou_marker: 0.7223 - val_loss: 0.2879 - val_mean_iou: 0.8376 - val_mean_iou_marker: 0.7220
# Epoch 297/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3019 - mean_iou: 0.8369 - mean_iou_marker: 0.7217
# Epoch 00297: saving model to ./models/model.297.vl.0.32.vi.0.84.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.3006 - mean_iou: 0.8369 - mean_iou_marker: 0.7217 - val_loss: 0.3194 - val_mean_iou: 0.8363 - val_mean_iou_marker: 0.7213
# Epoch 298/300
# 74/75 [============================>.] - ETA: 0s - loss: 0.3031 - mean_iou: 0.8356 - mean_iou_marker: 0.7210
# Epoch 00298: saving model to ./models/model.298.vl.0.30.vi.0.83.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: 0.3014 - mean_iou: 0.8356 - mean_iou_marker: 0.7210 - val_loss: 0.3001 - val_mean_iou: 0.8349 - val_mean_iou_marker: 0.7207
# Epoch 299/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3047 - mean_iou: 0.8342 - mean_iou_marker: 0.7204
# Epoch 00299: saving model to ./models/model.299.vl.0.29.vi.0.83.vim.0.72.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.3040 - mean_iou: 0.8342 - mean_iou_marker: 0.7204 - val_loss: 0.2901 - val_mean_iou: 0.8336 - val_mean_iou_marker: 0.7201
# Epoch 300/300
# 74/75 [============================>.] - ETA: 1s - loss: 0.3115 - mean_iou: 0.8329 - mean_iou_marker: 0.7198
# Epoch 00300: saving model to ./models/model.300.vl.0.28.vi.0.83.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: 0.3088 - mean_iou: 0.8329 - mean_iou_marker: 0.7198 - val_loss: 0.2773 - val_mean_iou: 0.8322 - val_mean_iou_marker: 0.7195

# %%
model.save('model.h5')

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_marker'])
plt.plot(history.history['val_mean_iou_marker'])
plt.title('model mean_iou_marker')
plt.ylabel('mean_iou_marker')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
model = load_model('./models/model.250.vl.-0.54.vi.0.90.vim.0.75.h5', custom_objects={'mean_iou': mean_iou, 'custom_loss': custom_loss, 'mean_iou_marker': mean_iou_marker, 'dice_coef': dice_coef})
preds_train = model.predict_generator(data_generator(X_train, Y_train, batch_size=1, training=False), steps=len(X_train), verbose=1)
preds_val = model.predict_generator(data_generator(X_val, Y_val, batch_size=1, training=False), steps=len(X_val), verbose=1)
preds_test = model.predict(X_test, verbose=1, batch_size=BS)

preds_train, preds_train_marker = preds_train[...,0], preds_train[...,1]
preds_val, preds_val_marker = preds_val[...,0], preds_val[...,1]
preds_test, preds_test_marker = preds_test[...,0], preds_test[...,1]

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_train_marker_t = (preds_train_marker > 0.5).astype(np.uint8)
preds_val_marker_t = (preds_val_marker > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append((resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_marker[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True)
                                ))
# Out:
# 603/603 [==============================] - 48s 80ms/step
# 67/67 [==============================] - 5s 77ms/step
# 65/65 [==============================] - 2s 25ms/step

# %%
from scipy import ndimage as ndi
from skimage.morphology import watershed

# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def lb(image, marker):
    if np.sum(image) < np.sum(marker):
        image = marker
    else:
        marker = np.array((marker==1) & (image==1))
    distance = ndi.distance_transform_edt(image)
    markers = ndi.label(marker)[0]
    labels = watershed(-distance, markers, mask=image)
    if np.sum(labels) == 0:
        labels[0,0] = 1
    return labels

def prob_to_rles(x, marker, cutoff=0.5, cutoff_marker=0.5):
    lab_img = lb(x > cutoff, marker > cutoff_marker)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix][0].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_train[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_marker_t[ix]), shape))
plt.show()
lab = lb(preds_train_t[ix], preds_train_marker_t[ix])
plt.imshow(lab, cmap=plt.get_cmap('tab20_r'))
plt.show()
# Out:
# 281

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix][0].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_val[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_marker_t[ix]), shape))
plt.show()
lab = lb(preds_val_t[ix], preds_val_marker_t[ix])
plt.imshow(lab, cmap=plt.get_cmap('tab20_r'))
plt.show()
# Out:
# 31

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n][0], preds_test_upsampled[n][1]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
