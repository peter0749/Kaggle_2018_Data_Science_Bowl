# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings
import numpy as np

seed = 42 # for reproduction
random.seed(seed)
np.random.seed(seed)

import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = './stage1_train/'
TEST_PATH = './stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# Out:
# /home/peter/virtual_envs/tf_keras/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
from skimage.measure import regionprops
import cv2, imutils
import math

# Get and resize train images and masks
X_train = []
Y_train = []
#lsum = 0
#msum = 0
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    mark = np.zeros(img.shape[:2], dtype=np.uint8)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        cnts = cv2.findContours(mask_.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if imutils.is_cv2() else cnts[1]
        M = cv2.moments(cnts[0])
        if M["m00"] != 0:
            cX = M["m10"] / M["m00"]
            cY = M["m01"] / M["m00"]
        else:
            p = regionprops(mask_, cache=True)[0]
            cY, cX = p.centroid
        r = int(math.ceil( max( img.shape[0], img.shape[1] ) * .01 ))
        cv2.circle(mark, (int(cX), int(cY)), r, 255, -1)
        mask = np.maximum(mask, mask_)
    mark = cv2.GaussianBlur(mark, (3,3), 0)
    #lsum += np.sum(mask)
    #msum += np.sum(mark)
    Y_train.append([mask, mark])

# print(msum / (lsum+msum))

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append(img.shape[:2])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:25<00:00,  7.79it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 29.60it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]), cmap='gray')
plt.show()
x_copy = X_train[ix].copy()
x_copy[np.squeeze(Y_train[ix][1])>0, :] = 255, 0, 0
plt.imshow(x_copy)
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true_, y_pred_):
    y_true = y_true_[...,0]
    y_pred = y_pred_[...,0]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def mean_iou_marker(y_true_, y_pred_):
    y_true = y_true_[...,1]
    y_pred = y_pred_[...,1]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.*intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + intersection + smooth)

from keras.losses import binary_crossentropy

def custom_loss(y_true_, y_pred_):
    alpha = 0.8 # control amount of loss of markers
    
    y_true_hm = y_true_[...,0]
    y_true_mk = y_true_[...,1]
    
    y_pred_hm = y_pred_[...,0]
    y_pred_mk = y_pred_[...,1]
    
    s_marker_loss = .5 * binary_crossentropy(y_true_mk, y_pred_mk) - dice_coef(y_true_mk, y_pred_mk)
    s_heatmap_loss= .5 * binary_crossentropy(y_true_hm, y_pred_hm) - dice_coef(y_true_hm, y_pred_hm)
    
    losses = alpha * s_marker_loss + (1.-alpha) * s_heatmap_loss
    return losses

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout
from keras.optimizers import Adam

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = Add()([inputs, last]) # dimensions of inputs, last are same
    
    c1 = _res_conv(c1, 32, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 64, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 128, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 256, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 512, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3, dropout=0.3)
    
    u7 = up (c6, dropout=0.3)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 512, 3)
    
    u8 = up (c7, dropout=0.25)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 256, 3)
    
    u9 = up (c8, dropout=0.2)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 128, 3)
    
    u10 = up (c9, dropout=0.14)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 64, 3)
    
    u11 = up (c10, dropout=0.1)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 32, 3)
    
    outputs = Conv2D(2, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss=custom_loss, metrics=[mean_iou, mean_iou_marker], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  32          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 17) 1241        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 8)  808         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 3)  12          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 128         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 16) 528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 8)  264         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 9)  297         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 6)  198         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 2112        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 64) 0           conv2d_14[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 16)   1040        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 19)   1235        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 12)   780         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  8320        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 128)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 128)  0           conv2d_21[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 38)   4902        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 25)   3225        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  33024       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 256)  0           conv2d_28[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  32896       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 256)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 76)   19532       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 51)   13107       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 512)  0           conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 512)  131584      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 512)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           conv2d_35[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 512)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    65664       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 8, 8, 512)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 76)     38988       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 512)    0           conv2d_36[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 512)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 512)    0           max_pooling2d_10[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 512)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 1024) 0           dropout_7[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 1024) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 76)   77900       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 51)   52275       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 512)  0           conv2d_42[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 512)  524800      concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 512)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 512)  0           conv2d_48[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 512)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 768)  0           dropout_9[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 64)   49216       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 32, 32, 768)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 38)   29222       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 25)   19225       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 256)  0           conv2d_49[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 256)  196864      concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 256)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 256)  0           conv2d_55[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 256)  262400      activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 256)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 384)  0           dropout_11[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 32)   12320       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 16)   6160        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 19)   7315        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 12)   4620        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 128)  0           conv2d_56[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 128)  49280       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 128)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 128)  0           conv2d_62[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 128)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 128 65664       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128, 128, 128 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 192 0           dropout_13[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 128, 128, 16) 3088        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 128, 128, 8)  1544        concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 128, 128, 9)  1737        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 6)  1158        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 64) 0           conv2d_63[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 128, 128, 64) 12352       concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 64) 0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 128, 128, 64) 0           conv2d_69[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 64) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 64) 16448       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256, 256, 64) 0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 96) 0           dropout_15[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 256, 256, 8)  776         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 256, 256, 4)  388         concatenate_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 256, 256, 4)  388         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 256, 256, 17) 1241        conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 256, 256, 8)  808         conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 256, 256, 3)  291         max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 256, 256, 32) 0           conv2d_70[0][0]
#                                                                  conv2d_73[0][0]
#                                                                  conv2d_74[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 256, 256, 32) 3104        concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256, 256, 32) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 256, 256, 32) 0           conv2d_76[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 256, 32) 0           add_11[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 2)  66          activation_11[0][0]
# ==================================================================================================
# Total params: 6,004,467
# Trainable params: 6,004,467
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2

from sklearn.utils import shuffle
def data_generator(data, label, batch_size=4, training=True):
    index = 0
    dat_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    lab_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.bool)
    while True:
        img = data[index%len(data)] # [0,255]
        lab = label[index%len(data)][0]
        marker = label[index%len(data)][1]
        if training:
            if np.random.rand() < .5: # flip vertical
                img = np.flip(img, 0)
                lab = np.flip(lab, 0)
                marker = np.flip(marker, 0)
            if np.random.rand() < .5: # flip horizontal
                img = np.flip(img, 1)
                lab = np.flip(lab, 1)
                marker = np.flip(marker, 1)

            # rotation, shearing
            if np.random.rand() < 0.5:
                y, x, _ = img.shape
                h, w = y, x
                img = cv2.copyMakeBorder(img, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                y, x, _ = img.shape
                
                pts1 = np.float32([[5,5],[20,5],[5,20]])

                pt1 =    10*np.random.uniform()
                pt2 = 15+10*np.random.uniform()

                pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])
                shear_M = cv2.getAffineTransform(pts1,pts2)
                
                rotT = np.random.uniform(-45,45)
                M = cv2.getRotationMatrix2D((x/2, y/2), rotT, 1)
                
                mA, mB = (M, shear_M) if np.random.rand()<.5 else (shear_M, M)
                
                img = cv2.warpAffine(img, mA, (x, y))
                lab = cv2.warpAffine(lab, mA, (x, y))
                marker = cv2.warpAffine(marker, mA, (x, y))
                
                img = cv2.warpAffine(img, mB, (x, y))
                lab = cv2.warpAffine(lab, mB, (x, y))
                marker = cv2.warpAffine(marker, mB, (x, y))
                
                img = img[h//2:h//2+h,w//2:w//2+w,:]
                lab = lab[h//2:h//2+h,w//2:w//2+w]
                marker = marker[h//2:h//2+h,w//2:w//2+w]

            img = img.astype(np.float32) / 255. # normalize

            # random amplify each channel
            a = .1 # amptitude
            t  = [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t = np.array(t)

            img = img * (1. + t) # channel wise amplify
            up = np.random.uniform(0.95, 1.05) # change gamma
            img = img**up * 255. # apply gamma and convert back to range [0,255]
            img = img.astype(np.uint8) # convert back to uint8

            assert img.dtype == np.uint8 ## check type
            assert lab.dtype == np.uint8

            if np.random.rand() < .1: # randomly crop image
                s = np.random.uniform(0.8, 1.2) # random crop scale
                w, h = int(s*IMG_WIDTH), int(s*IMG_HEIGHT)
                paddx = max(0, w-img.shape[1])
                paddy = max(0, h-img.shape[0])
                img = cv2.copyMakeBorder(img, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                cropx = img.shape[1] - w + 1
                cropy = img.shape[0] - h + 1
                offx = np.random.randint(0, cropx)
                offy = np.random.randint(0, cropy)
                img = img[offy:offy+h, offx:offx+w, :]
                lab = lab[offy:offy+h, offx:offx+w]
                marker = marker[offy:offy+h, offx:offx+w]
        ### end of data augmentation ###
        
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        marker = resize(marker, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        
        lab[lab<130] = 0
        lab[lab>0] = 1
        
        marker[marker<130] = 0
        marker[marker>0] = 1
        
        dat_que[index%batch_size,:,:,:] = img
        lab_que[index%batch_size,:,:,0] = lab
        lab_que[index%batch_size,:,:,1] = marker
        index = index + 1
        if index%batch_size==0:
            index = 0 if index%len(data)==0 else index
            yield (dat_que, lab_que)
        if training and index%len(data)==0:
            data, label = shuffle(data, label)

# %%
batch_X, batch_Y = next(data_generator(X_train, Y_train, training=True, batch_size=1))
plt.imshow(np.squeeze(batch_X[0]))
plt.show()
plt.imshow(np.squeeze(batch_Y[0,...,0]))
plt.show()
plt.imshow(np.squeeze(batch_Y[0,...,1]))
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# Fit model
BS=8
EPOCHS=200

os.makedirs('./models', exist_ok=True)

# earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('./models/model.{epoch:03d}.vl.{val_loss:.2f}.vi.{val_mean_iou:.2f}.vim.{val_mean_iou_marker:.2f}.h5', verbose=1, save_best_only=False)
history = model.fit_generator(data_generator(X_train, Y_train, batch_size=BS, training=True),
                              steps_per_epoch=len(X_train) // BS , epochs=EPOCHS, 
                              validation_data=data_generator(X_val, Y_val, batch_size=BS, training=False), 
                              validation_steps=len(X_val) // BS,
                             callbacks=[checkpointer])
# Out:
# Epoch 1/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.1815 - mean_iou: 0.4984 - mean_iou_marker: 0.5137
# Epoch 00001: saving model to ./models/model.001.vl.-0.36.vi.0.61.vim.0.58.h5
# 75/75 [==============================] - 104s 1s/step - loss: -0.1840 - mean_iou: 0.4998 - mean_iou_marker: 0.5145 - val_loss: -0.3642 - val_mean_iou: 0.6122 - val_mean_iou_marker: 0.5766
# Epoch 2/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.3493 - mean_iou: 0.6614 - mean_iou_marker: 0.5957
# Epoch 00002: saving model to ./models/model.002.vl.-0.42.vi.0.70.vim.0.61.h5
# 75/75 [==============================] - 72s 958ms/step - loss: -0.3488 - mean_iou: 0.6618 - mean_iou_marker: 0.5959 - val_loss: -0.4222 - val_mean_iou: 0.6957 - val_mean_iou_marker: 0.6097
# Epoch 3/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.3639 - mean_iou: 0.7187 - mean_iou_marker: 0.6178
# Epoch 00003: saving model to ./models/model.003.vl.-0.41.vi.0.74.vim.0.62.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.3631 - mean_iou: 0.7189 - mean_iou_marker: 0.6178 - val_loss: -0.4073 - val_mean_iou: 0.7364 - val_mean_iou_marker: 0.6241
# Epoch 4/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.3779 - mean_iou: 0.7493 - mean_iou_marker: 0.6290
# Epoch 00004: saving model to ./models/model.004.vl.-0.43.vi.0.76.vim.0.63.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.3792 - mean_iou: 0.7495 - mean_iou_marker: 0.6290 - val_loss: -0.4330 - val_mean_iou: 0.7620 - val_mean_iou_marker: 0.6338
# Epoch 5/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.3841 - mean_iou: 0.7710 - mean_iou_marker: 0.6371
# Epoch 00005: saving model to ./models/model.005.vl.-0.43.vi.0.78.vim.0.64.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.3848 - mean_iou: 0.7711 - mean_iou_marker: 0.6371 - val_loss: -0.4314 - val_mean_iou: 0.7794 - val_mean_iou_marker: 0.6395
# Epoch 6/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.3684 - mean_iou: 0.7841 - mean_iou_marker: 0.6408
# Epoch 00006: saving model to ./models/model.006.vl.-0.38.vi.0.79.vim.0.64.h5
# 75/75 [==============================] - 88s 1s/step - loss: -0.3692 - mean_iou: 0.7841 - mean_iou_marker: 0.6408 - val_loss: -0.3788 - val_mean_iou: 0.7869 - val_mean_iou_marker: 0.6417
# Epoch 7/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.3941 - mean_iou: 0.7903 - mean_iou_marker: 0.6436
# Epoch 00007: saving model to ./models/model.007.vl.-0.42.vi.0.79.vim.0.65.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.3933 - mean_iou: 0.7903 - mean_iou_marker: 0.6436 - val_loss: -0.4164 - val_mean_iou: 0.7943 - val_mean_iou_marker: 0.6454
# Epoch 8/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.3973 - mean_iou: 0.7974 - mean_iou_marker: 0.6468
# Epoch 00008: saving model to ./models/model.008.vl.-0.40.vi.0.80.vim.0.65.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.3984 - mean_iou: 0.7974 - mean_iou_marker: 0.6468 - val_loss: -0.3965 - val_mean_iou: 0.8007 - val_mean_iou_marker: 0.6485
# Epoch 9/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4137 - mean_iou: 0.8036 - mean_iou_marker: 0.6502
# Epoch 00009: saving model to ./models/model.009.vl.-0.39.vi.0.81.vim.0.65.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4135 - mean_iou: 0.8036 - mean_iou_marker: 0.6502 - val_loss: -0.3929 - val_mean_iou: 0.8065 - val_mean_iou_marker: 0.6521
# Epoch 10/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4168 - mean_iou: 0.8087 - mean_iou_marker: 0.6537
# Epoch 00010: saving model to ./models/model.010.vl.-0.42.vi.0.81.vim.0.66.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4171 - mean_iou: 0.8088 - mean_iou_marker: 0.6538 - val_loss: -0.4241 - val_mean_iou: 0.8116 - val_mean_iou_marker: 0.6554
# Epoch 11/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4261 - mean_iou: 0.8142 - mean_iou_marker: 0.6566
# Epoch 00011: saving model to ./models/model.011.vl.-0.42.vi.0.82.vim.0.66.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4263 - mean_iou: 0.8142 - mean_iou_marker: 0.6566 - val_loss: -0.4238 - val_mean_iou: 0.8162 - val_mean_iou_marker: 0.6582
# Epoch 12/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4402 - mean_iou: 0.8183 - mean_iou_marker: 0.6600
# Epoch 00012: saving model to ./models/model.012.vl.-0.43.vi.0.82.vim.0.66.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4395 - mean_iou: 0.8183 - mean_iou_marker: 0.6600 - val_loss: -0.4291 - val_mean_iou: 0.8201 - val_mean_iou_marker: 0.6617
# Epoch 13/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4430 - mean_iou: 0.8218 - mean_iou_marker: 0.6633
# Epoch 00013: saving model to ./models/model.013.vl.-0.43.vi.0.82.vim.0.66.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4431 - mean_iou: 0.8218 - mean_iou_marker: 0.6633 - val_loss: -0.4324 - val_mean_iou: 0.8235 - val_mean_iou_marker: 0.6648
# Epoch 14/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4324 - mean_iou: 0.8250 - mean_iou_marker: 0.6658
# Epoch 00014: saving model to ./models/model.014.vl.-0.44.vi.0.83.vim.0.67.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4328 - mean_iou: 0.8251 - mean_iou_marker: 0.6658 - val_loss: -0.4411 - val_mean_iou: 0.8266 - val_mean_iou_marker: 0.6670
# Epoch 15/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4513 - mean_iou: 0.8283 - mean_iou_marker: 0.6682
# Epoch 00015: saving model to ./models/model.015.vl.-0.45.vi.0.83.vim.0.67.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4518 - mean_iou: 0.8283 - mean_iou_marker: 0.6682 - val_loss: -0.4547 - val_mean_iou: 0.8296 - val_mean_iou_marker: 0.6698
# Epoch 16/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4454 - mean_iou: 0.8307 - mean_iou_marker: 0.6709
# Epoch 00016: saving model to ./models/model.016.vl.-0.45.vi.0.83.vim.0.67.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4455 - mean_iou: 0.8308 - mean_iou_marker: 0.6709 - val_loss: -0.4531 - val_mean_iou: 0.8322 - val_mean_iou_marker: 0.6723
# Epoch 17/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4475 - mean_iou: 0.8336 - mean_iou_marker: 0.6733
# Epoch 00017: saving model to ./models/model.017.vl.-0.47.vi.0.83.vim.0.67.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4469 - mean_iou: 0.8336 - mean_iou_marker: 0.6733 - val_loss: -0.4687 - val_mean_iou: 0.8347 - val_mean_iou_marker: 0.6743
# Epoch 18/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4447 - mean_iou: 0.8359 - mean_iou_marker: 0.6750
# Epoch 00018: saving model to ./models/model.018.vl.-0.47.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4452 - mean_iou: 0.8359 - mean_iou_marker: 0.6750 - val_loss: -0.4657 - val_mean_iou: 0.8369 - val_mean_iou_marker: 0.6760
# Epoch 19/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4542 - mean_iou: 0.8379 - mean_iou_marker: 0.6770
# Epoch 00019: saving model to ./models/model.019.vl.-0.49.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4520 - mean_iou: 0.8379 - mean_iou_marker: 0.6770 - val_loss: -0.4891 - val_mean_iou: 0.8387 - val_mean_iou_marker: 0.6779
# Epoch 20/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4495 - mean_iou: 0.8396 - mean_iou_marker: 0.6786
# Epoch 00020: saving model to ./models/model.020.vl.-0.49.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4487 - mean_iou: 0.8396 - mean_iou_marker: 0.6786 - val_loss: -0.4892 - val_mean_iou: 0.8404 - val_mean_iou_marker: 0.6795
# Epoch 21/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4382 - mean_iou: 0.8412 - mean_iou_marker: 0.6800
# Epoch 00021: saving model to ./models/model.021.vl.-0.48.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4389 - mean_iou: 0.8412 - mean_iou_marker: 0.6800 - val_loss: -0.4840 - val_mean_iou: 0.8420 - val_mean_iou_marker: 0.6809
# Epoch 22/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4556 - mean_iou: 0.8427 - mean_iou_marker: 0.6817
# Epoch 00022: saving model to ./models/model.022.vl.-0.50.vi.0.84.vim.0.68.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4556 - mean_iou: 0.8427 - mean_iou_marker: 0.6817 - val_loss: -0.4981 - val_mean_iou: 0.8435 - val_mean_iou_marker: 0.6825
# Epoch 23/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4586 - mean_iou: 0.8444 - mean_iou_marker: 0.6833
# Epoch 00023: saving model to ./models/model.023.vl.-0.49.vi.0.85.vim.0.68.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4590 - mean_iou: 0.8445 - mean_iou_marker: 0.6833 - val_loss: -0.4946 - val_mean_iou: 0.8452 - val_mean_iou_marker: 0.6841
# Epoch 24/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4570 - mean_iou: 0.8460 - mean_iou_marker: 0.6848
# Epoch 00024: saving model to ./models/model.024.vl.-0.50.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4565 - mean_iou: 0.8460 - mean_iou_marker: 0.6848 - val_loss: -0.5022 - val_mean_iou: 0.8467 - val_mean_iou_marker: 0.6854
# Epoch 25/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4614 - mean_iou: 0.8476 - mean_iou_marker: 0.6861
# Epoch 00025: saving model to ./models/model.025.vl.-0.47.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4599 - mean_iou: 0.8476 - mean_iou_marker: 0.6861 - val_loss: -0.4679 - val_mean_iou: 0.8482 - val_mean_iou_marker: 0.6867
# Epoch 26/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4568 - mean_iou: 0.8486 - mean_iou_marker: 0.6873
# Epoch 00026: saving model to ./models/model.026.vl.-0.48.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4558 - mean_iou: 0.8487 - mean_iou_marker: 0.6873 - val_loss: -0.4848 - val_mean_iou: 0.8492 - val_mean_iou_marker: 0.6878
# Epoch 27/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4597 - mean_iou: 0.8499 - mean_iou_marker: 0.6884
# Epoch 00027: saving model to ./models/model.027.vl.-0.50.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4598 - mean_iou: 0.8499 - mean_iou_marker: 0.6884 - val_loss: -0.5020 - val_mean_iou: 0.8504 - val_mean_iou_marker: 0.6891
# Epoch 28/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4568 - mean_iou: 0.8511 - mean_iou_marker: 0.6897
# Epoch 00028: saving model to ./models/model.028.vl.-0.44.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4572 - mean_iou: 0.8511 - mean_iou_marker: 0.6897 - val_loss: -0.4426 - val_mean_iou: 0.8515 - val_mean_iou_marker: 0.6901
# Epoch 29/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4586 - mean_iou: 0.8519 - mean_iou_marker: 0.6905
# Epoch 00029: saving model to ./models/model.029.vl.-0.47.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4587 - mean_iou: 0.8519 - mean_iou_marker: 0.6905 - val_loss: -0.4734 - val_mean_iou: 0.8525 - val_mean_iou_marker: 0.6910
# Epoch 30/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4641 - mean_iou: 0.8531 - mean_iou_marker: 0.6915
# Epoch 00030: saving model to ./models/model.030.vl.-0.46.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4649 - mean_iou: 0.8531 - mean_iou_marker: 0.6915 - val_loss: -0.4629 - val_mean_iou: 0.8536 - val_mean_iou_marker: 0.6919
# Epoch 31/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4668 - mean_iou: 0.8541 - mean_iou_marker: 0.6925
# Epoch 00031: saving model to ./models/model.031.vl.-0.45.vi.0.85.vim.0.69.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4664 - mean_iou: 0.8541 - mean_iou_marker: 0.6925 - val_loss: -0.4465 - val_mean_iou: 0.8546 - val_mean_iou_marker: 0.6929
# Epoch 32/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4619 - mean_iou: 0.8551 - mean_iou_marker: 0.6932
# Epoch 00032: saving model to ./models/model.032.vl.-0.45.vi.0.86.vim.0.69.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4626 - mean_iou: 0.8551 - mean_iou_marker: 0.6932 - val_loss: -0.4465 - val_mean_iou: 0.8555 - val_mean_iou_marker: 0.6936
# Epoch 33/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4596 - mean_iou: 0.8560 - mean_iou_marker: 0.6939
# Epoch 00033: saving model to ./models/model.033.vl.-0.46.vi.0.86.vim.0.69.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4592 - mean_iou: 0.8560 - mean_iou_marker: 0.6939 - val_loss: -0.4617 - val_mean_iou: 0.8564 - val_mean_iou_marker: 0.6944
# Epoch 34/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4703 - mean_iou: 0.8569 - mean_iou_marker: 0.6950
# Epoch 00034: saving model to ./models/model.034.vl.-0.48.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4705 - mean_iou: 0.8569 - mean_iou_marker: 0.6950 - val_loss: -0.4813 - val_mean_iou: 0.8573 - val_mean_iou_marker: 0.6955
# Epoch 35/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4624 - mean_iou: 0.8577 - mean_iou_marker: 0.6958
# Epoch 00035: saving model to ./models/model.035.vl.-0.45.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4612 - mean_iou: 0.8577 - mean_iou_marker: 0.6958 - val_loss: -0.4535 - val_mean_iou: 0.8581 - val_mean_iou_marker: 0.6962
# Epoch 36/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4625 - mean_iou: 0.8584 - mean_iou_marker: 0.6964
# Epoch 00036: saving model to ./models/model.036.vl.-0.48.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4629 - mean_iou: 0.8584 - mean_iou_marker: 0.6964 - val_loss: -0.4757 - val_mean_iou: 0.8588 - val_mean_iou_marker: 0.6969
# Epoch 37/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4616 - mean_iou: 0.8591 - mean_iou_marker: 0.6972
# Epoch 00037: saving model to ./models/model.037.vl.-0.47.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4620 - mean_iou: 0.8591 - mean_iou_marker: 0.6972 - val_loss: -0.4700 - val_mean_iou: 0.8595 - val_mean_iou_marker: 0.6975
# Epoch 38/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4692 - mean_iou: 0.8599 - mean_iou_marker: 0.6979
# Epoch 00038: saving model to ./models/model.038.vl.-0.48.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4689 - mean_iou: 0.8599 - mean_iou_marker: 0.6979 - val_loss: -0.4766 - val_mean_iou: 0.8602 - val_mean_iou_marker: 0.6982
# Epoch 39/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4760 - mean_iou: 0.8606 - mean_iou_marker: 0.6986
# Epoch 00039: saving model to ./models/model.039.vl.-0.48.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4763 - mean_iou: 0.8607 - mean_iou_marker: 0.6986 - val_loss: -0.4815 - val_mean_iou: 0.8611 - val_mean_iou_marker: 0.6990
# Epoch 40/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4703 - mean_iou: 0.8614 - mean_iou_marker: 0.6994
# Epoch 00040: saving model to ./models/model.040.vl.-0.50.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4708 - mean_iou: 0.8614 - mean_iou_marker: 0.6994 - val_loss: -0.4970 - val_mean_iou: 0.8617 - val_mean_iou_marker: 0.6998
# Epoch 41/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4777 - mean_iou: 0.8621 - mean_iou_marker: 0.7002
# Epoch 00041: saving model to ./models/model.041.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4784 - mean_iou: 0.8622 - mean_iou_marker: 0.7002 - val_loss: -0.5064 - val_mean_iou: 0.8625 - val_mean_iou_marker: 0.7006
# Epoch 42/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4664 - mean_iou: 0.8628 - mean_iou_marker: 0.7010
# Epoch 00042: saving model to ./models/model.042.vl.-0.50.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4663 - mean_iou: 0.8628 - mean_iou_marker: 0.7010 - val_loss: -0.4956 - val_mean_iou: 0.8631 - val_mean_iou_marker: 0.7014
# Epoch 43/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4694 - mean_iou: 0.8634 - mean_iou_marker: 0.7018
# Epoch 00043: saving model to ./models/model.043.vl.-0.50.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4693 - mean_iou: 0.8634 - mean_iou_marker: 0.7018 - val_loss: -0.5002 - val_mean_iou: 0.8638 - val_mean_iou_marker: 0.7021
# Epoch 44/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4783 - mean_iou: 0.8640 - mean_iou_marker: 0.7025
# Epoch 00044: saving model to ./models/model.044.vl.-0.53.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4780 - mean_iou: 0.8640 - mean_iou_marker: 0.7025 - val_loss: -0.5256 - val_mean_iou: 0.8643 - val_mean_iou_marker: 0.7029
# Epoch 45/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4588 - mean_iou: 0.8646 - mean_iou_marker: 0.7031
# Epoch 00045: saving model to ./models/model.045.vl.-0.51.vi.0.86.vim.0.70.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4592 - mean_iou: 0.8646 - mean_iou_marker: 0.7031 - val_loss: -0.5144 - val_mean_iou: 0.8648 - val_mean_iou_marker: 0.7032
# Epoch 46/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4663 - mean_iou: 0.8652 - mean_iou_marker: 0.7035
# Epoch 00046: saving model to ./models/model.046.vl.-0.51.vi.0.87.vim.0.70.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4664 - mean_iou: 0.8652 - mean_iou_marker: 0.7035 - val_loss: -0.5050 - val_mean_iou: 0.8654 - val_mean_iou_marker: 0.7037
# Epoch 47/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4741 - mean_iou: 0.8657 - mean_iou_marker: 0.7040
# Epoch 00047: saving model to ./models/model.047.vl.-0.52.vi.0.87.vim.0.70.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4743 - mean_iou: 0.8657 - mean_iou_marker: 0.7040 - val_loss: -0.5208 - val_mean_iou: 0.8660 - val_mean_iou_marker: 0.7043
# Epoch 48/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4751 - mean_iou: 0.8663 - mean_iou_marker: 0.7047
# Epoch 00048: saving model to ./models/model.048.vl.-0.53.vi.0.87.vim.0.70.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4751 - mean_iou: 0.8663 - mean_iou_marker: 0.7047 - val_loss: -0.5307 - val_mean_iou: 0.8665 - val_mean_iou_marker: 0.7049
# Epoch 49/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4607 - mean_iou: 0.8668 - mean_iou_marker: 0.7052
# Epoch 00049: saving model to ./models/model.049.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 75s 1s/step - loss: -0.4603 - mean_iou: 0.8668 - mean_iou_marker: 0.7052 - val_loss: -0.4833 - val_mean_iou: 0.8669 - val_mean_iou_marker: 0.7053
# Epoch 50/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4689 - mean_iou: 0.8672 - mean_iou_marker: 0.7056
# Epoch 00050: saving model to ./models/model.050.vl.-0.50.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4690 - mean_iou: 0.8672 - mean_iou_marker: 0.7056 - val_loss: -0.5025 - val_mean_iou: 0.8674 - val_mean_iou_marker: 0.7058
# Epoch 51/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4798 - mean_iou: 0.8677 - mean_iou_marker: 0.7061
# Epoch 00051: saving model to ./models/model.051.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 75s 1s/step - loss: -0.4804 - mean_iou: 0.8677 - mean_iou_marker: 0.7061 - val_loss: -0.4943 - val_mean_iou: 0.8680 - val_mean_iou_marker: 0.7064
# Epoch 52/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4773 - mean_iou: 0.8682 - mean_iou_marker: 0.7067
# Epoch 00052: saving model to ./models/model.052.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4766 - mean_iou: 0.8682 - mean_iou_marker: 0.7067 - val_loss: -0.4891 - val_mean_iou: 0.8684 - val_mean_iou_marker: 0.7070
# Epoch 53/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4824 - mean_iou: 0.8685 - mean_iou_marker: 0.7072
# Epoch 00053: saving model to ./models/model.053.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4826 - mean_iou: 0.8685 - mean_iou_marker: 0.7072 - val_loss: -0.4807 - val_mean_iou: 0.8688 - val_mean_iou_marker: 0.7076
# Epoch 54/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4815 - mean_iou: 0.8690 - mean_iou_marker: 0.7079
# Epoch 00054: saving model to ./models/model.054.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4817 - mean_iou: 0.8690 - mean_iou_marker: 0.7079 - val_loss: -0.4873 - val_mean_iou: 0.8693 - val_mean_iou_marker: 0.7081
# Epoch 55/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4715 - mean_iou: 0.8695 - mean_iou_marker: 0.7084
# Epoch 00055: saving model to ./models/model.055.vl.-0.47.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4720 - mean_iou: 0.8695 - mean_iou_marker: 0.7084 - val_loss: -0.4697 - val_mean_iou: 0.8697 - val_mean_iou_marker: 0.7085
# Epoch 56/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4829 - mean_iou: 0.8698 - mean_iou_marker: 0.7089
# Epoch 00056: saving model to ./models/model.056.vl.-0.47.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4823 - mean_iou: 0.8698 - mean_iou_marker: 0.7089 - val_loss: -0.4689 - val_mean_iou: 0.8701 - val_mean_iou_marker: 0.7091
# Epoch 57/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4723 - mean_iou: 0.8702 - mean_iou_marker: 0.7093
# Epoch 00057: saving model to ./models/model.057.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4732 - mean_iou: 0.8702 - mean_iou_marker: 0.7093 - val_loss: -0.4834 - val_mean_iou: 0.8704 - val_mean_iou_marker: 0.7095
# Epoch 58/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4703 - mean_iou: 0.8706 - mean_iou_marker: 0.7096
# Epoch 00058: saving model to ./models/model.058.vl.-0.46.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4706 - mean_iou: 0.8706 - mean_iou_marker: 0.7096 - val_loss: -0.4647 - val_mean_iou: 0.8709 - val_mean_iou_marker: 0.7098
# Epoch 59/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4801 - mean_iou: 0.8710 - mean_iou_marker: 0.7099
# Epoch 00059: saving model to ./models/model.059.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4804 - mean_iou: 0.8710 - mean_iou_marker: 0.7099 - val_loss: -0.4808 - val_mean_iou: 0.8713 - val_mean_iou_marker: 0.7102
# Epoch 60/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4760 - mean_iou: 0.8715 - mean_iou_marker: 0.7103
# Epoch 00060: saving model to ./models/model.060.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4750 - mean_iou: 0.8715 - mean_iou_marker: 0.7103 - val_loss: -0.4822 - val_mean_iou: 0.8717 - val_mean_iou_marker: 0.7105
# Epoch 61/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4845 - mean_iou: 0.8719 - mean_iou_marker: 0.7107
# Epoch 00061: saving model to ./models/model.061.vl.-0.45.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4828 - mean_iou: 0.8719 - mean_iou_marker: 0.7107 - val_loss: -0.4547 - val_mean_iou: 0.8721 - val_mean_iou_marker: 0.7110
# Epoch 62/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4771 - mean_iou: 0.8722 - mean_iou_marker: 0.7111
# Epoch 00062: saving model to ./models/model.062.vl.-0.48.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4774 - mean_iou: 0.8722 - mean_iou_marker: 0.7111 - val_loss: -0.4844 - val_mean_iou: 0.8724 - val_mean_iou_marker: 0.7113
# Epoch 63/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4845 - mean_iou: 0.8726 - mean_iou_marker: 0.7116
# Epoch 00063: saving model to ./models/model.063.vl.-0.49.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4852 - mean_iou: 0.8726 - mean_iou_marker: 0.7116 - val_loss: -0.4910 - val_mean_iou: 0.8728 - val_mean_iou_marker: 0.7118
# Epoch 64/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4727 - mean_iou: 0.8730 - mean_iou_marker: 0.7119
# Epoch 00064: saving model to ./models/model.064.vl.-0.51.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4725 - mean_iou: 0.8730 - mean_iou_marker: 0.7119 - val_loss: -0.5084 - val_mean_iou: 0.8732 - val_mean_iou_marker: 0.7121
# Epoch 65/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4858 - mean_iou: 0.8733 - mean_iou_marker: 0.7123
# Epoch 00065: saving model to ./models/model.065.vl.-0.51.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4863 - mean_iou: 0.8733 - mean_iou_marker: 0.7123 - val_loss: -0.5051 - val_mean_iou: 0.8735 - val_mean_iou_marker: 0.7126
# Epoch 66/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4801 - mean_iou: 0.8737 - mean_iou_marker: 0.7127
# Epoch 00066: saving model to ./models/model.066.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4793 - mean_iou: 0.8737 - mean_iou_marker: 0.7127 - val_loss: -0.5225 - val_mean_iou: 0.8739 - val_mean_iou_marker: 0.7129
# Epoch 67/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4817 - mean_iou: 0.8741 - mean_iou_marker: 0.7131
# Epoch 00067: saving model to ./models/model.067.vl.-0.52.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4814 - mean_iou: 0.8741 - mean_iou_marker: 0.7131 - val_loss: -0.5242 - val_mean_iou: 0.8742 - val_mean_iou_marker: 0.7133
# Epoch 68/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4791 - mean_iou: 0.8744 - mean_iou_marker: 0.7136
# Epoch 00068: saving model to ./models/model.068.vl.-0.51.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4793 - mean_iou: 0.8744 - mean_iou_marker: 0.7136 - val_loss: -0.5097 - val_mean_iou: 0.8745 - val_mean_iou_marker: 0.7138
# Epoch 69/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4830 - mean_iou: 0.8747 - mean_iou_marker: 0.7140
# Epoch 00069: saving model to ./models/model.069.vl.-0.53.vi.0.87.vim.0.71.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4826 - mean_iou: 0.8747 - mean_iou_marker: 0.7140 - val_loss: -0.5260 - val_mean_iou: 0.8749 - val_mean_iou_marker: 0.7142
# Epoch 70/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4903 - mean_iou: 0.8750 - mean_iou_marker: 0.7144
# Epoch 00070: saving model to ./models/model.070.vl.-0.53.vi.0.88.vim.0.71.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4905 - mean_iou: 0.8750 - mean_iou_marker: 0.7144 - val_loss: -0.5283 - val_mean_iou: 0.8752 - val_mean_iou_marker: 0.7147
# Epoch 71/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4823 - mean_iou: 0.8753 - mean_iou_marker: 0.7149
# Epoch 00071: saving model to ./models/model.071.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4826 - mean_iou: 0.8753 - mean_iou_marker: 0.7149 - val_loss: -0.5233 - val_mean_iou: 0.8755 - val_mean_iou_marker: 0.7151
# Epoch 72/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4766 - mean_iou: 0.8756 - mean_iou_marker: 0.7152
# Epoch 00072: saving model to ./models/model.072.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4772 - mean_iou: 0.8756 - mean_iou_marker: 0.7152 - val_loss: -0.5120 - val_mean_iou: 0.8757 - val_mean_iou_marker: 0.7154
# Epoch 73/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4840 - mean_iou: 0.8759 - mean_iou_marker: 0.7156
# Epoch 00073: saving model to ./models/model.073.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4847 - mean_iou: 0.8759 - mean_iou_marker: 0.7156 - val_loss: -0.5031 - val_mean_iou: 0.8761 - val_mean_iou_marker: 0.7158
# Epoch 74/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4634 - mean_iou: 0.8762 - mean_iou_marker: 0.7158
# Epoch 00074: saving model to ./models/model.074.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4640 - mean_iou: 0.8762 - mean_iou_marker: 0.7158 - val_loss: -0.4874 - val_mean_iou: 0.8763 - val_mean_iou_marker: 0.7158
# Epoch 75/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4880 - mean_iou: 0.8764 - mean_iou_marker: 0.7161
# Epoch 00075: saving model to ./models/model.075.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4885 - mean_iou: 0.8764 - mean_iou_marker: 0.7161 - val_loss: -0.4916 - val_mean_iou: 0.8765 - val_mean_iou_marker: 0.7163
# Epoch 76/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4866 - mean_iou: 0.8767 - mean_iou_marker: 0.7164
# Epoch 00076: saving model to ./models/model.076.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4862 - mean_iou: 0.8767 - mean_iou_marker: 0.7164 - val_loss: -0.4838 - val_mean_iou: 0.8768 - val_mean_iou_marker: 0.7166
# Epoch 77/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4836 - mean_iou: 0.8769 - mean_iou_marker: 0.7168
# Epoch 00077: saving model to ./models/model.077.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 71s 948ms/step - loss: -0.4844 - mean_iou: 0.8769 - mean_iou_marker: 0.7168 - val_loss: -0.4812 - val_mean_iou: 0.8771 - val_mean_iou_marker: 0.7169
# Epoch 78/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4848 - mean_iou: 0.8772 - mean_iou_marker: 0.7170
# Epoch 00078: saving model to ./models/model.078.vl.-0.47.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4846 - mean_iou: 0.8772 - mean_iou_marker: 0.7170 - val_loss: -0.4712 - val_mean_iou: 0.8773 - val_mean_iou_marker: 0.7172
# Epoch 79/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4887 - mean_iou: 0.8774 - mean_iou_marker: 0.7174
# Epoch 00079: saving model to ./models/model.079.vl.-0.46.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4895 - mean_iou: 0.8774 - mean_iou_marker: 0.7174 - val_loss: -0.4591 - val_mean_iou: 0.8776 - val_mean_iou_marker: 0.7176
# Epoch 80/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4868 - mean_iou: 0.8777 - mean_iou_marker: 0.7177
# Epoch 00080: saving model to ./models/model.080.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4865 - mean_iou: 0.8777 - mean_iou_marker: 0.7177 - val_loss: -0.4769 - val_mean_iou: 0.8779 - val_mean_iou_marker: 0.7179
# Epoch 81/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4914 - mean_iou: 0.8780 - mean_iou_marker: 0.7181
# Epoch 00081: saving model to ./models/model.081.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4915 - mean_iou: 0.8780 - mean_iou_marker: 0.7181 - val_loss: -0.4823 - val_mean_iou: 0.8781 - val_mean_iou_marker: 0.7182
# Epoch 82/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4807 - mean_iou: 0.8782 - mean_iou_marker: 0.7183
# Epoch 00082: saving model to ./models/model.082.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4813 - mean_iou: 0.8782 - mean_iou_marker: 0.7183 - val_loss: -0.4808 - val_mean_iou: 0.8783 - val_mean_iou_marker: 0.7185
# Epoch 83/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4798 - mean_iou: 0.8785 - mean_iou_marker: 0.7186
# Epoch 00083: saving model to ./models/model.083.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4801 - mean_iou: 0.8785 - mean_iou_marker: 0.7186 - val_loss: -0.4848 - val_mean_iou: 0.8786 - val_mean_iou_marker: 0.7187
# Epoch 84/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4865 - mean_iou: 0.8787 - mean_iou_marker: 0.7188
# Epoch 00084: saving model to ./models/model.084.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4861 - mean_iou: 0.8787 - mean_iou_marker: 0.7188 - val_loss: -0.4791 - val_mean_iou: 0.8787 - val_mean_iou_marker: 0.7189
# Epoch 85/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4902 - mean_iou: 0.8789 - mean_iou_marker: 0.7191
# Epoch 00085: saving model to ./models/model.085.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4897 - mean_iou: 0.8789 - mean_iou_marker: 0.7191 - val_loss: -0.5006 - val_mean_iou: 0.8790 - val_mean_iou_marker: 0.7193
# Epoch 86/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4914 - mean_iou: 0.8792 - mean_iou_marker: 0.7194
# Epoch 00086: saving model to ./models/model.086.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.4904 - mean_iou: 0.8792 - mean_iou_marker: 0.7194 - val_loss: -0.5016 - val_mean_iou: 0.8793 - val_mean_iou_marker: 0.7196
# Epoch 87/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4909 - mean_iou: 0.8794 - mean_iou_marker: 0.7197
# Epoch 00087: saving model to ./models/model.087.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4896 - mean_iou: 0.8794 - mean_iou_marker: 0.7197 - val_loss: -0.5054 - val_mean_iou: 0.8795 - val_mean_iou_marker: 0.7199
# Epoch 88/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4886 - mean_iou: 0.8796 - mean_iou_marker: 0.7201
# Epoch 00088: saving model to ./models/model.088.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4886 - mean_iou: 0.8796 - mean_iou_marker: 0.7201 - val_loss: -0.5192 - val_mean_iou: 0.8797 - val_mean_iou_marker: 0.7202
# Epoch 89/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4915 - mean_iou: 0.8799 - mean_iou_marker: 0.7204
# Epoch 00089: saving model to ./models/model.089.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4910 - mean_iou: 0.8799 - mean_iou_marker: 0.7204 - val_loss: -0.5134 - val_mean_iou: 0.8800 - val_mean_iou_marker: 0.7206
# Epoch 90/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4855 - mean_iou: 0.8801 - mean_iou_marker: 0.7206
# Epoch 00090: saving model to ./models/model.090.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4851 - mean_iou: 0.8801 - mean_iou_marker: 0.7206 - val_loss: -0.5249 - val_mean_iou: 0.8802 - val_mean_iou_marker: 0.7208
# Epoch 91/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4966 - mean_iou: 0.8803 - mean_iou_marker: 0.7210
# Epoch 00091: saving model to ./models/model.091.vl.-0.54.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4966 - mean_iou: 0.8803 - mean_iou_marker: 0.7210 - val_loss: -0.5371 - val_mean_iou: 0.8804 - val_mean_iou_marker: 0.7212
# Epoch 92/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4936 - mean_iou: 0.8805 - mean_iou_marker: 0.7214
# Epoch 00092: saving model to ./models/model.092.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4936 - mean_iou: 0.8805 - mean_iou_marker: 0.7214 - val_loss: -0.5090 - val_mean_iou: 0.8806 - val_mean_iou_marker: 0.7215
# Epoch 93/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4832 - mean_iou: 0.8807 - mean_iou_marker: 0.7217
# Epoch 00093: saving model to ./models/model.093.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4848 - mean_iou: 0.8807 - mean_iou_marker: 0.7217 - val_loss: -0.5286 - val_mean_iou: 0.8808 - val_mean_iou_marker: 0.7218
# Epoch 94/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4907 - mean_iou: 0.8809 - mean_iou_marker: 0.7220
# Epoch 00094: saving model to ./models/model.094.vl.-0.53.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 83s 1s/step - loss: -0.4902 - mean_iou: 0.8809 - mean_iou_marker: 0.7220 - val_loss: -0.5347 - val_mean_iou: 0.8810 - val_mean_iou_marker: 0.7221
# Epoch 95/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4737 - mean_iou: 0.8811 - mean_iou_marker: 0.7221
# Epoch 00095: saving model to ./models/model.095.vl.-0.51.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4739 - mean_iou: 0.8811 - mean_iou_marker: 0.7221 - val_loss: -0.5148 - val_mean_iou: 0.8811 - val_mean_iou_marker: 0.7223
# Epoch 96/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4898 - mean_iou: 0.8812 - mean_iou_marker: 0.7224
# Epoch 00096: saving model to ./models/model.096.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4899 - mean_iou: 0.8812 - mean_iou_marker: 0.7224 - val_loss: -0.4976 - val_mean_iou: 0.8813 - val_mean_iou_marker: 0.7225
# Epoch 97/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4942 - mean_iou: 0.8814 - mean_iou_marker: 0.7227
# Epoch 00097: saving model to ./models/model.097.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4938 - mean_iou: 0.8814 - mean_iou_marker: 0.7227 - val_loss: -0.4880 - val_mean_iou: 0.8815 - val_mean_iou_marker: 0.7228
# Epoch 98/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4893 - mean_iou: 0.8815 - mean_iou_marker: 0.7230
# Epoch 00098: saving model to ./models/model.098.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4897 - mean_iou: 0.8815 - mean_iou_marker: 0.7230 - val_loss: -0.4883 - val_mean_iou: 0.8816 - val_mean_iou_marker: 0.7231
# Epoch 99/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4870 - mean_iou: 0.8817 - mean_iou_marker: 0.7232
# Epoch 00099: saving model to ./models/model.099.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4875 - mean_iou: 0.8817 - mean_iou_marker: 0.7232 - val_loss: -0.4804 - val_mean_iou: 0.8817 - val_mean_iou_marker: 0.7233
# Epoch 100/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4894 - mean_iou: 0.8818 - mean_iou_marker: 0.7234
# Epoch 00100: saving model to ./models/model.100.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4889 - mean_iou: 0.8818 - mean_iou_marker: 0.7234 - val_loss: -0.4807 - val_mean_iou: 0.8819 - val_mean_iou_marker: 0.7235
# Epoch 101/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4848 - mean_iou: 0.8820 - mean_iou_marker: 0.7236
# Epoch 00101: saving model to ./models/model.101.vl.-0.47.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4852 - mean_iou: 0.8820 - mean_iou_marker: 0.7236 - val_loss: -0.4741 - val_mean_iou: 0.8821 - val_mean_iou_marker: 0.7237
# Epoch 102/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4971 - mean_iou: 0.8822 - mean_iou_marker: 0.7238
# Epoch 00102: saving model to ./models/model.102.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4958 - mean_iou: 0.8822 - mean_iou_marker: 0.7238 - val_loss: -0.4895 - val_mean_iou: 0.8823 - val_mean_iou_marker: 0.7240
# Epoch 103/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4947 - mean_iou: 0.8824 - mean_iou_marker: 0.7241
# Epoch 00103: saving model to ./models/model.103.vl.-0.49.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4952 - mean_iou: 0.8824 - mean_iou_marker: 0.7241 - val_loss: -0.4882 - val_mean_iou: 0.8825 - val_mean_iou_marker: 0.7242
# Epoch 104/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4864 - mean_iou: 0.8825 - mean_iou_marker: 0.7243
# Epoch 00104: saving model to ./models/model.104.vl.-0.48.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4862 - mean_iou: 0.8825 - mean_iou_marker: 0.7243 - val_loss: -0.4850 - val_mean_iou: 0.8827 - val_mean_iou_marker: 0.7244
# Epoch 105/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4889 - mean_iou: 0.8827 - mean_iou_marker: 0.7245
# Epoch 00105: saving model to ./models/model.105.vl.-0.50.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4887 - mean_iou: 0.8827 - mean_iou_marker: 0.7245 - val_loss: -0.5010 - val_mean_iou: 0.8828 - val_mean_iou_marker: 0.7246
# Epoch 106/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4884 - mean_iou: 0.8829 - mean_iou_marker: 0.7247
# Epoch 00106: saving model to ./models/model.106.vl.-0.52.vi.0.88.vim.0.72.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4893 - mean_iou: 0.8829 - mean_iou_marker: 0.7247 - val_loss: -0.5200 - val_mean_iou: 0.8830 - val_mean_iou_marker: 0.7248
# Epoch 107/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4998 - mean_iou: 0.8831 - mean_iou_marker: 0.7249
# Epoch 00107: saving model to ./models/model.107.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4996 - mean_iou: 0.8831 - mean_iou_marker: 0.7249 - val_loss: -0.5055 - val_mean_iou: 0.8832 - val_mean_iou_marker: 0.7251
# Epoch 108/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4920 - mean_iou: 0.8833 - mean_iou_marker: 0.7252
# Epoch 00108: saving model to ./models/model.108.vl.-0.50.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4923 - mean_iou: 0.8833 - mean_iou_marker: 0.7252 - val_loss: -0.5013 - val_mean_iou: 0.8834 - val_mean_iou_marker: 0.7253
# Epoch 109/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4905 - mean_iou: 0.8834 - mean_iou_marker: 0.7254
# Epoch 00109: saving model to ./models/model.109.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4901 - mean_iou: 0.8834 - mean_iou_marker: 0.7254 - val_loss: -0.5173 - val_mean_iou: 0.8835 - val_mean_iou_marker: 0.7255
# Epoch 110/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4856 - mean_iou: 0.8836 - mean_iou_marker: 0.7256
# Epoch 00110: saving model to ./models/model.110.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4854 - mean_iou: 0.8836 - mean_iou_marker: 0.7256 - val_loss: -0.5263 - val_mean_iou: 0.8837 - val_mean_iou_marker: 0.7257
# Epoch 111/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4847 - mean_iou: 0.8838 - mean_iou_marker: 0.7258
# Epoch 00111: saving model to ./models/model.111.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4849 - mean_iou: 0.8838 - mean_iou_marker: 0.7258 - val_loss: -0.5168 - val_mean_iou: 0.8838 - val_mean_iou_marker: 0.7258
# Epoch 112/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4804 - mean_iou: 0.8839 - mean_iou_marker: 0.7259
# Epoch 00112: saving model to ./models/model.112.vl.-0.52.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4806 - mean_iou: 0.8839 - mean_iou_marker: 0.7259 - val_loss: -0.5193 - val_mean_iou: 0.8839 - val_mean_iou_marker: 0.7260
# Epoch 113/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4854 - mean_iou: 0.8840 - mean_iou_marker: 0.7261
# Epoch 00113: saving model to ./models/model.113.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 81s 1s/step - loss: -0.4860 - mean_iou: 0.8840 - mean_iou_marker: 0.7261 - val_loss: -0.5292 - val_mean_iou: 0.8840 - val_mean_iou_marker: 0.7262
# Epoch 114/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4979 - mean_iou: 0.8841 - mean_iou_marker: 0.7263
# Epoch 00114: saving model to ./models/model.114.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4969 - mean_iou: 0.8841 - mean_iou_marker: 0.7263 - val_loss: -0.5348 - val_mean_iou: 0.8842 - val_mean_iou_marker: 0.7264
# Epoch 115/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4979 - mean_iou: 0.8843 - mean_iou_marker: 0.7266
# Epoch 00115: saving model to ./models/model.115.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4984 - mean_iou: 0.8843 - mean_iou_marker: 0.7266 - val_loss: -0.5251 - val_mean_iou: 0.8843 - val_mean_iou_marker: 0.7267
# Epoch 116/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4891 - mean_iou: 0.8844 - mean_iou_marker: 0.7268
# Epoch 00116: saving model to ./models/model.116.vl.-0.54.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4895 - mean_iou: 0.8844 - mean_iou_marker: 0.7268 - val_loss: -0.5357 - val_mean_iou: 0.8845 - val_mean_iou_marker: 0.7269
# Epoch 117/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4954 - mean_iou: 0.8845 - mean_iou_marker: 0.7271
# Epoch 00117: saving model to ./models/model.117.vl.-0.53.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4944 - mean_iou: 0.8845 - mean_iou_marker: 0.7271 - val_loss: -0.5309 - val_mean_iou: 0.8846 - val_mean_iou_marker: 0.7272
# Epoch 118/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4878 - mean_iou: 0.8847 - mean_iou_marker: 0.7273
# Epoch 00118: saving model to ./models/model.118.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4885 - mean_iou: 0.8847 - mean_iou_marker: 0.7273 - val_loss: -0.5103 - val_mean_iou: 0.8847 - val_mean_iou_marker: 0.7273
# Epoch 119/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4911 - mean_iou: 0.8848 - mean_iou_marker: 0.7274
# Epoch 00119: saving model to ./models/model.119.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4913 - mean_iou: 0.8848 - mean_iou_marker: 0.7274 - val_loss: -0.5085 - val_mean_iou: 0.8848 - val_mean_iou_marker: 0.7275
# Epoch 120/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4956 - mean_iou: 0.8849 - mean_iou_marker: 0.7276
# Epoch 00120: saving model to ./models/model.120.vl.-0.51.vi.0.88.vim.0.73.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4958 - mean_iou: 0.8849 - mean_iou_marker: 0.7276 - val_loss: -0.5081 - val_mean_iou: 0.8849 - val_mean_iou_marker: 0.7277
# Epoch 121/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4915 - mean_iou: 0.8850 - mean_iou_marker: 0.7278
# Epoch 00121: saving model to ./models/model.121.vl.-0.51.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4921 - mean_iou: 0.8850 - mean_iou_marker: 0.7278 - val_loss: -0.5118 - val_mean_iou: 0.8851 - val_mean_iou_marker: 0.7279
# Epoch 122/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4951 - mean_iou: 0.8851 - mean_iou_marker: 0.7281
# Epoch 00122: saving model to ./models/model.122.vl.-0.50.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4957 - mean_iou: 0.8852 - mean_iou_marker: 0.7281 - val_loss: -0.4983 - val_mean_iou: 0.8852 - val_mean_iou_marker: 0.7281
# Epoch 123/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4984 - mean_iou: 0.8853 - mean_iou_marker: 0.7283
# Epoch 00123: saving model to ./models/model.123.vl.-0.49.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4989 - mean_iou: 0.8853 - mean_iou_marker: 0.7283 - val_loss: -0.4929 - val_mean_iou: 0.8854 - val_mean_iou_marker: 0.7284
# Epoch 124/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4930 - mean_iou: 0.8854 - mean_iou_marker: 0.7284
# Epoch 00124: saving model to ./models/model.124.vl.-0.49.vi.0.89.vim.0.73.h5
# ...
# Epoch 160/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5004 - mean_iou: 0.8894 - mean_iou_marker: 0.7347
# Epoch 00160: saving model to ./models/model.160.vl.-0.55.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5004 - mean_iou: 0.8894 - mean_iou_marker: 0.7347 - val_loss: -0.5487 - val_mean_iou: 0.8895 - val_mean_iou_marker: 0.7348
# Epoch 161/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4992 - mean_iou: 0.8895 - mean_iou_marker: 0.7349
# Epoch 00161: saving model to ./models/model.161.vl.-0.55.vi.0.89.vim.0.73.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4979 - mean_iou: 0.8895 - mean_iou_marker: 0.7349 - val_loss: -0.5470 - val_mean_iou: 0.8896 - val_mean_iou_marker: 0.7350
# Epoch 162/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4993 - mean_iou: 0.8896 - mean_iou_marker: 0.7351
# Epoch 00162: saving model to ./models/model.162.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.4995 - mean_iou: 0.8896 - mean_iou_marker: 0.7351 - val_loss: -0.5181 - val_mean_iou: 0.8897 - val_mean_iou_marker: 0.7351
# Epoch 163/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4945 - mean_iou: 0.8897 - mean_iou_marker: 0.7352
# Epoch 00163: saving model to ./models/model.163.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4941 - mean_iou: 0.8897 - mean_iou_marker: 0.7352 - val_loss: -0.5165 - val_mean_iou: 0.8898 - val_mean_iou_marker: 0.7352
# Epoch 164/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4994 - mean_iou: 0.8898 - mean_iou_marker: 0.7353
# Epoch 00164: saving model to ./models/model.164.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5001 - mean_iou: 0.8898 - mean_iou_marker: 0.7353 - val_loss: -0.5071 - val_mean_iou: 0.8899 - val_mean_iou_marker: 0.7354
# Epoch 165/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4979 - mean_iou: 0.8899 - mean_iou_marker: 0.7355
# Epoch 00165: saving model to ./models/model.165.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4983 - mean_iou: 0.8899 - mean_iou_marker: 0.7355 - val_loss: -0.5022 - val_mean_iou: 0.8899 - val_mean_iou_marker: 0.7355
# Epoch 166/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5082 - mean_iou: 0.8900 - mean_iou_marker: 0.7356
# Epoch 00166: saving model to ./models/model.166.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.5082 - mean_iou: 0.8900 - mean_iou_marker: 0.7356 - val_loss: -0.5152 - val_mean_iou: 0.8900 - val_mean_iou_marker: 0.7357
# Epoch 167/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5071 - mean_iou: 0.8901 - mean_iou_marker: 0.7358
# Epoch 00167: saving model to ./models/model.167.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5069 - mean_iou: 0.8901 - mean_iou_marker: 0.7358 - val_loss: -0.5059 - val_mean_iou: 0.8901 - val_mean_iou_marker: 0.7359
# Epoch 168/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4970 - mean_iou: 0.8902 - mean_iou_marker: 0.7359
# Epoch 00168: saving model to ./models/model.168.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4967 - mean_iou: 0.8902 - mean_iou_marker: 0.7359 - val_loss: -0.5024 - val_mean_iou: 0.8902 - val_mean_iou_marker: 0.7359
# Epoch 169/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5014 - mean_iou: 0.8903 - mean_iou_marker: 0.7360
# Epoch 00169: saving model to ./models/model.169.vl.-0.49.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5018 - mean_iou: 0.8903 - mean_iou_marker: 0.7360 - val_loss: -0.4924 - val_mean_iou: 0.8903 - val_mean_iou_marker: 0.7361
# Epoch 170/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4993 - mean_iou: 0.8903 - mean_iou_marker: 0.7361
# Epoch 00170: saving model to ./models/model.170.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4990 - mean_iou: 0.8903 - mean_iou_marker: 0.7361 - val_loss: -0.5008 - val_mean_iou: 0.8904 - val_mean_iou_marker: 0.7362
# Epoch 171/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5129 - mean_iou: 0.8904 - mean_iou_marker: 0.7363
# Epoch 00171: saving model to ./models/model.171.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5128 - mean_iou: 0.8904 - mean_iou_marker: 0.7363 - val_loss: -0.5083 - val_mean_iou: 0.8905 - val_mean_iou_marker: 0.7364
# Epoch 172/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5056 - mean_iou: 0.8905 - mean_iou_marker: 0.7364
# Epoch 00172: saving model to ./models/model.172.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.5063 - mean_iou: 0.8905 - mean_iou_marker: 0.7364 - val_loss: -0.4970 - val_mean_iou: 0.8906 - val_mean_iou_marker: 0.7365
# Epoch 173/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5004 - mean_iou: 0.8906 - mean_iou_marker: 0.7365
# Epoch 00173: saving model to ./models/model.173.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.5011 - mean_iou: 0.8906 - mean_iou_marker: 0.7365 - val_loss: -0.5094 - val_mean_iou: 0.8907 - val_mean_iou_marker: 0.7366
# Epoch 174/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5033 - mean_iou: 0.8907 - mean_iou_marker: 0.7367
# Epoch 00174: saving model to ./models/model.174.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5031 - mean_iou: 0.8907 - mean_iou_marker: 0.7367 - val_loss: -0.5120 - val_mean_iou: 0.8907 - val_mean_iou_marker: 0.7368
# Epoch 175/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5018 - mean_iou: 0.8908 - mean_iou_marker: 0.7368
# Epoch 00175: saving model to ./models/model.175.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5019 - mean_iou: 0.8908 - mean_iou_marker: 0.7368 - val_loss: -0.5158 - val_mean_iou: 0.8908 - val_mean_iou_marker: 0.7369
# Epoch 176/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4981 - mean_iou: 0.8909 - mean_iou_marker: 0.7369
# Epoch 00176: saving model to ./models/model.176.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4985 - mean_iou: 0.8909 - mean_iou_marker: 0.7369 - val_loss: -0.5195 - val_mean_iou: 0.8909 - val_mean_iou_marker: 0.7370
# Epoch 177/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4920 - mean_iou: 0.8909 - mean_iou_marker: 0.7371
# Epoch 00177: saving model to ./models/model.177.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4917 - mean_iou: 0.8909 - mean_iou_marker: 0.7371 - val_loss: -0.5328 - val_mean_iou: 0.8909 - val_mean_iou_marker: 0.7371
# Epoch 178/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5058 - mean_iou: 0.8910 - mean_iou_marker: 0.7372
# Epoch 00178: saving model to ./models/model.178.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.5058 - mean_iou: 0.8910 - mean_iou_marker: 0.7372 - val_loss: -0.5341 - val_mean_iou: 0.8910 - val_mean_iou_marker: 0.7373
# Epoch 179/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5048 - mean_iou: 0.8911 - mean_iou_marker: 0.7373
# Epoch 00179: saving model to ./models/model.179.vl.-0.54.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5051 - mean_iou: 0.8911 - mean_iou_marker: 0.7373 - val_loss: -0.5375 - val_mean_iou: 0.8911 - val_mean_iou_marker: 0.7374
# Epoch 180/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5080 - mean_iou: 0.8912 - mean_iou_marker: 0.7375
# Epoch 00180: saving model to ./models/model.180.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5081 - mean_iou: 0.8912 - mean_iou_marker: 0.7375 - val_loss: -0.5279 - val_mean_iou: 0.8912 - val_mean_iou_marker: 0.7376
# Epoch 181/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5074 - mean_iou: 0.8912 - mean_iou_marker: 0.7377
# Epoch 00181: saving model to ./models/model.181.vl.-0.54.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5074 - mean_iou: 0.8912 - mean_iou_marker: 0.7377 - val_loss: -0.5382 - val_mean_iou: 0.8913 - val_mean_iou_marker: 0.7378
# Epoch 182/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4994 - mean_iou: 0.8913 - mean_iou_marker: 0.7378
# Epoch 00182: saving model to ./models/model.182.vl.-0.55.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.4994 - mean_iou: 0.8913 - mean_iou_marker: 0.7378 - val_loss: -0.5504 - val_mean_iou: 0.8914 - val_mean_iou_marker: 0.7379
# Epoch 183/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5032 - mean_iou: 0.8914 - mean_iou_marker: 0.7380
# Epoch 00183: saving model to ./models/model.183.vl.-0.54.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5036 - mean_iou: 0.8914 - mean_iou_marker: 0.7380 - val_loss: -0.5428 - val_mean_iou: 0.8915 - val_mean_iou_marker: 0.7381
# Epoch 184/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5053 - mean_iou: 0.8915 - mean_iou_marker: 0.7381
# Epoch 00184: saving model to ./models/model.184.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.5058 - mean_iou: 0.8915 - mean_iou_marker: 0.7381 - val_loss: -0.5332 - val_mean_iou: 0.8915 - val_mean_iou_marker: 0.7382
# Epoch 185/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5038 - mean_iou: 0.8916 - mean_iou_marker: 0.7383
# Epoch 00185: saving model to ./models/model.185.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 82s 1s/step - loss: -0.5040 - mean_iou: 0.8916 - mean_iou_marker: 0.7383 - val_loss: -0.5201 - val_mean_iou: 0.8916 - val_mean_iou_marker: 0.7384
# Epoch 186/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4966 - mean_iou: 0.8917 - mean_iou_marker: 0.7384
# Epoch 00186: saving model to ./models/model.186.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.4963 - mean_iou: 0.8917 - mean_iou_marker: 0.7384 - val_loss: -0.5072 - val_mean_iou: 0.8917 - val_mean_iou_marker: 0.7385
# Epoch 187/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5047 - mean_iou: 0.8917 - mean_iou_marker: 0.7385
# Epoch 00187: saving model to ./models/model.187.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.5039 - mean_iou: 0.8917 - mean_iou_marker: 0.7385 - val_loss: -0.5095 - val_mean_iou: 0.8918 - val_mean_iou_marker: 0.7386
# Epoch 188/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.4959 - mean_iou: 0.8918 - mean_iou_marker: 0.7386
# Epoch 00188: saving model to ./models/model.188.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.4955 - mean_iou: 0.8918 - mean_iou_marker: 0.7386 - val_loss: -0.5153 - val_mean_iou: 0.8918 - val_mean_iou_marker: 0.7387
# Epoch 189/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5086 - mean_iou: 0.8919 - mean_iou_marker: 0.7388
# Epoch 00189: saving model to ./models/model.189.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.5086 - mean_iou: 0.8919 - mean_iou_marker: 0.7388 - val_loss: -0.5123 - val_mean_iou: 0.8919 - val_mean_iou_marker: 0.7388
# Epoch 190/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.4900 - mean_iou: 0.8919 - mean_iou_marker: 0.7389
# Epoch 00190: saving model to ./models/model.190.vl.-0.49.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.4904 - mean_iou: 0.8919 - mean_iou_marker: 0.7389 - val_loss: -0.4922 - val_mean_iou: 0.8920 - val_mean_iou_marker: 0.7388
# Epoch 191/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5102 - mean_iou: 0.8920 - mean_iou_marker: 0.7389
# Epoch 00191: saving model to ./models/model.191.vl.-0.49.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 76s 1s/step - loss: -0.5098 - mean_iou: 0.8920 - mean_iou_marker: 0.7389 - val_loss: -0.4949 - val_mean_iou: 0.8921 - val_mean_iou_marker: 0.7390
# Epoch 192/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5020 - mean_iou: 0.8921 - mean_iou_marker: 0.7390
# Epoch 00192: saving model to ./models/model.192.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5023 - mean_iou: 0.8921 - mean_iou_marker: 0.7390 - val_loss: -0.4988 - val_mean_iou: 0.8921 - val_mean_iou_marker: 0.7391
# Epoch 193/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5090 - mean_iou: 0.8921 - mean_iou_marker: 0.7391
# Epoch 00193: saving model to ./models/model.193.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5093 - mean_iou: 0.8921 - mean_iou_marker: 0.7391 - val_loss: -0.4989 - val_mean_iou: 0.8922 - val_mean_iou_marker: 0.7392
# Epoch 194/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5075 - mean_iou: 0.8922 - mean_iou_marker: 0.7393
# Epoch 00194: saving model to ./models/model.194.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 79s 1s/step - loss: -0.5074 - mean_iou: 0.8922 - mean_iou_marker: 0.7393 - val_loss: -0.5076 - val_mean_iou: 0.8923 - val_mean_iou_marker: 0.7393
# Epoch 195/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5080 - mean_iou: 0.8923 - mean_iou_marker: 0.7394
# Epoch 00195: saving model to ./models/model.195.vl.-0.50.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5081 - mean_iou: 0.8923 - mean_iou_marker: 0.7394 - val_loss: -0.5001 - val_mean_iou: 0.8923 - val_mean_iou_marker: 0.7394
# Epoch 196/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5046 - mean_iou: 0.8924 - mean_iou_marker: 0.7395
# Epoch 00196: saving model to ./models/model.196.vl.-0.51.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.5047 - mean_iou: 0.8924 - mean_iou_marker: 0.7395 - val_loss: -0.5146 - val_mean_iou: 0.8924 - val_mean_iou_marker: 0.7396
# Epoch 197/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5055 - mean_iou: 0.8924 - mean_iou_marker: 0.7396
# Epoch 00197: saving model to ./models/model.197.vl.-0.52.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.5046 - mean_iou: 0.8924 - mean_iou_marker: 0.7396 - val_loss: -0.5150 - val_mean_iou: 0.8925 - val_mean_iou_marker: 0.7397
# Epoch 198/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5086 - mean_iou: 0.8925 - mean_iou_marker: 0.7398
# Epoch 00198: saving model to ./models/model.198.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 77s 1s/step - loss: -0.5089 - mean_iou: 0.8925 - mean_iou_marker: 0.7398 - val_loss: -0.5277 - val_mean_iou: 0.8925 - val_mean_iou_marker: 0.7398
# Epoch 199/200
# 74/75 [============================>.] - ETA: 0s - loss: -0.5010 - mean_iou: 0.8926 - mean_iou_marker: 0.7399
# Epoch 00199: saving model to ./models/model.199.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 78s 1s/step - loss: -0.5009 - mean_iou: 0.8926 - mean_iou_marker: 0.7399 - val_loss: -0.5275 - val_mean_iou: 0.8926 - val_mean_iou_marker: 0.7399
# Epoch 200/200
# 74/75 [============================>.] - ETA: 1s - loss: -0.5005 - mean_iou: 0.8926 - mean_iou_marker: 0.7400
# Epoch 00200: saving model to ./models/model.200.vl.-0.53.vi.0.89.vim.0.74.h5
# 75/75 [==============================] - 80s 1s/step - loss: -0.5004 - mean_iou: 0.8926 - mean_iou_marker: 0.7400 - val_loss: -0.5314 - val_mean_iou: 0.8927 - val_mean_iou_marker: 0.7400

# %%
model.save('model.h5')

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_marker'])
plt.plot(history.history['val_mean_iou_marker'])
plt.title('model mean_iou_marker')
plt.ylabel('mean_iou_marker')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
# model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou, 'custom_loss': custom_loss, 'mean_iou_marker': mean_iou_marker, 'dice_coef': dice_coef})
preds_train = model.predict_generator(data_generator(X_train, Y_train, batch_size=1, training=False), steps=len(X_train), verbose=1)
preds_val = model.predict_generator(data_generator(X_val, Y_val, batch_size=1, training=False), steps=len(X_val), verbose=1)
preds_test = model.predict(X_test, verbose=1)

preds_train, preds_train_marker = preds_train[...,0], preds_train[...,1]
preds_val, preds_val_marker = preds_val[...,0], preds_val[...,1]
preds_test, preds_test_marker = preds_test[...,0], preds_test[...,1]

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_train_marker_t = (preds_train_marker > 0.5).astype(np.uint8)
preds_val_marker_t = (preds_val_marker > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append((resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_marker[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True)
                                ))
# Out:
# 603/603 [==============================] - 35s 59ms/step
# 67/67 [==============================] - 4s 61ms/step
# 65/65 [==============================] - 2s 24ms/step

# %%
from scipy import ndimage as ndi
from skimage.morphology import watershed

# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def lb(image, marker):
    if np.sum(image) < np.sum(marker):
        image = marker
    else:
        marker = np.array((marker==1) & (image==1))
    distance = ndi.distance_transform_edt(image)
    markers = ndi.label(marker)[0]
    labels = watershed(-distance, markers, mask=image)
    if np.sum(labels) == 0:
        labels[0,0] = 1
    return labels

def prob_to_rles(x, marker, cutoff=0.5, cutoff_marker=0.5):
    lab_img = lb(x > cutoff, marker > cutoff_marker)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix][0].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_train[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_marker_t[ix]), shape))
plt.show()
lab = lb(preds_train_t[ix], preds_train_marker_t[ix])
plt.imshow(lab)
plt.show()
# Out:
# 114

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix][0].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_val[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_marker_t[ix]), shape))
plt.show()
lab = lb(preds_val_t[ix], preds_val_marker_t[ix])
plt.imshow(lab)
plt.show()
# Out:
# 3

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n][0], preds_test_upsampled[n][1]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
