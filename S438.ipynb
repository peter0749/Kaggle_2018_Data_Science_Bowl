# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from scipy import ndimage as ndi

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
K.set_session(session)

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = '/home/peter/dataset/stage1_train/'
TEST_PATH = '/home/peter/dataset/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# Out:
# /home/peter/anaconda3/envs/dnn/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
from skimage.draw import circle
import math

# Get and resize train images and masks
X_train = []
Y_train = [] 

print('Getting train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    mark = np.zeros(img.shape[:2], dtype=np.float32)
    dt   = np.zeros(img.shape[:2], dtype=np.float32)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = (imread(path + '/masks/' + mask_file)>0).astype(np.float32)
        dt_   = ndi.distance_transform_edt(mask_).astype(np.float32)
        r = max( img.shape[0], img.shape[1] ) * .01
        cY, cX = np.unravel_index(np.argmax(dt_, axis=None), dt_.shape) # find local maximum of edt image
        cY = np.clip(cY, r, img.shape[0]-r)
        cX = np.clip(cX, r, img.shape[1]-r)
        # dt_   = dt_ - np.min(dt_)
        dt_   = dt_ / np.max(dt_) # get a distance transform of an instance
        dt    = np.maximum(dt, dt_)
        rr, cc = circle(cY, cX, r, shape=img.shape[:2])
        mark[rr,cc] = 1
        mask = np.maximum(mask, mask_)
    Y_train.append([mask, mark, dt])

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append(img.shape[:2])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting train images and masks ...
# 100%|██████████| 670/670 [09:18<00:00,  1.20it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:00<00:00, 93.65it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]), cmap='gray')
plt.show()
x_copy = X_train[ix].copy()
x_copy[np.squeeze(Y_train[ix][1])>0, :] = 255, 0, 0
plt.imshow(x_copy)
plt.show()
plt.imshow(np.squeeze(Y_train[ix][2]), cmap='gray')
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
from keras.losses import mean_squared_error
# Define IoU metric
def mean_iou(y_true_, y_pred_):
    y_true = y_true_[...,0]
    y_pred = y_pred_[...,0]
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def mean_iou_marker(y_true_, y_pred_):
    y_true = y_true_[...,1]
    y_pred = y_pred_[...,1]
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def custom_loss(y_true_, y_pred_):
    
    def dice_coef(y_true, y_pred, intersection): # (batch_size, h, w)
        sum_intersection = K.sum(intersection)
        return (2.*sum_intersection + K.epsilon()) / (K.sum(y_true) + K.sum(y_pred) + sum_intersection + K.epsilon()) # scaler
    
    obj_scale = 5
    
    y_true_hm = y_true_[...,0] # (batch_size, h, w)
    y_true_mk = y_true_[...,1] # (batch_size, h, w)
    y_true_dt = y_true_[...,2] # (batch_size, h, w)
    
    y_pred_hm = y_pred_[...,0] # (batch_size, h, w)
    y_pred_mk = y_pred_[...,1] # (batch_size, h, w)
    y_pred_dt = y_pred_[...,2] # (batch_size, h, w)
    
    true_mask_scale = y_true_hm * obj_scale
    s_dt_regression_loss = K.sum(K.abs(y_true_dt - y_pred_dt) * true_mask_scale, axis=None) / (K.sum(true_mask_scale, axis=None) + K.epsilon()) # scaler
    
    intersection_scale =  (1 - y_true_dt) * y_true_hm + 1
    
    mk_intersection = y_true_mk * y_pred_mk
    hm_intersection = y_true_hm * y_pred_hm
    
    s_marker_dice_coef = dice_coef(y_true_mk * intersection_scale, y_pred_mk * intersection_scale, mk_intersection * intersection_scale) # scaler
    s_heatmap_dice_coef= dice_coef(y_true_hm * intersection_scale, y_pred_hm * intersection_scale, hm_intersection * intersection_scale) # scaler
    s_marker_entropy   = K.sum(K.binary_crossentropy(y_true_mk, y_pred_mk) * intersection_scale, axis=None) / (K.sum(intersection_scale, axis=None) + K.epsilon()) # scaler
    s_heatmap_entropy  = K.sum(K.binary_crossentropy(y_true_hm, y_pred_hm) * intersection_scale, axis=None) / (K.sum(intersection_scale, axis=None) + K.epsilon()) # scaler
    s_marker_loss = .5 * s_marker_entropy - s_marker_dice_coef + 1. # scaler [0, inf)
    s_heatmap_loss= .5 * s_heatmap_entropy - s_heatmap_dice_coef + 1. # scaler [0, inf)
    
    loss = s_marker_loss + s_heatmap_loss + s_dt_regression_loss # scaler [0, inf)
    loss = tf.Print(loss, [s_marker_dice_coef], message='\nMarker DC:\t', summarize=10)
    loss = tf.Print(loss, [s_marker_entropy], message='\nMarker ET:\t', summarize=10)
    loss = tf.Print(loss, [s_heatmap_dice_coef], message='\nHeatmap DC:\t', summarize=10)
    loss = tf.Print(loss, [s_heatmap_entropy], message='\nHeatmap ET:\t', summarize=10)
    loss = tf.Print(loss, [s_dt_regression_loss], message='\nDT MAE:\t', summarize=10)
    
    return loss # scaler [0, inf)

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout
from keras.optimizers import Adam

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = concatenate()([inputs, last])
    
    c1 = _res_conv(c1, 32, 3)
    c1 = _res_conv(c1, 32, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 64, 3)
    c2 = _res_conv(c2, 64, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 128, 3)
    c3 = _res_conv(c3, 128, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 256, 3)
    c4 = _res_conv(c4, 256, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 512, 3)
    c5 = _res_conv(c5, 512, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3)
    c6 = _res_conv(c6, 512, 3)
    
    u7 = up (c6)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 512, 3)
    c7 = _res_conv(c7, 512, 3)
    
    u8 = up (c7)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 256, 3)
    c8 = _res_conv(c8, 256, 3)
    
    u9 = up (c8)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 128, 3)
    c9 = _res_conv(c9, 128, 3)
    
    u10 = up (c9)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 64, 3)
    c10 = _res_conv(c10, 64, 3)
    
    u11 = up (c10)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 32, 3)
    c11 = _res_conv(c11, 32, 3)
    
    outputs = Conv2D(3, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss=custom_loss, metrics=[mean_iou, mean_iou_marker], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  32          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 17) 1241        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 8)  808         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 3)  12          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 128         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 8)  264         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 256, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 17) 1241        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 8)  808         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 3)  99          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 32) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 256, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 32) 0           activation_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 528         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  264         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32) 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 9)  297         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 6)  198         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 2112        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 128, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           conv2d_20[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 8)  520         activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 9)  585         activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 6)  390         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 64) 0           conv2d_21[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128, 128, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 64) 0           activation_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 64) 0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 32)   2080        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 16)   1040        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 19)   1235        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 12)   780         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_27[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  8320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 128)  0           conv2d_33[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   4128        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 16)   2064        activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 19)   2451        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 12)   1548        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 64, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           activation_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 128)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 38)   4902        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 25)   3225        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 256)  0           conv2d_40[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 256)  33024       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 256)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           conv2d_46[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 32)   8224        activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 38)   9766        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 25)   6425        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 256)  0           conv2d_47[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 256)  0           activation_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 128)  32896       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 16, 16, 256)  0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 76)   19532       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 51)   13107       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 512)  0           conv2d_53[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 512)  131584      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 512)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 512)  0           conv2d_59[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 16, 16, 128)  65664       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 16, 16, 64)   32832       activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 16, 16, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 16, 16, 76)   38988       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 512)  0           conv2d_60[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 512)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 512)  0           activation_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 8, 8, 512)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 128)    65664       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 76)     38988       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 512)    0           conv2d_66[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 512)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 512)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 8, 8, 128)    65664       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 8, 8, 64)     32832       activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 512)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 8, 8, 76)     38988       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 512)    0           conv2d_72[0][0]
#                                                                  conv2d_75[0][0]
#                                                                  conv2d_76[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 512)    0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 512)    0           activation_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 512)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 16, 16, 1024) 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 76)   77900       concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 51)   52275       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 16, 16, 512)  0           conv2d_78[0][0]
#                                                                  conv2d_81[0][0]
#                                                                  conv2d_82[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 512)  524800      concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 512)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 512)  0           conv2d_84[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 64)   32832       activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 512)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 76)   38988       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 16, 16, 512)  0           conv2d_85[0][0]
#                                                                  conv2d_88[0][0]
#                                                                  conv2d_89[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 512)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 512)  0           activation_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 512)  0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 768)  0           conv2d_transpose_2[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 64)   49216       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 32, 32, 768)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 38)   29222       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 32, 32, 25)   19225       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 32, 256)  0           conv2d_91[0][0]
#                                                                  conv2d_94[0][0]
#                                                                  conv2d_95[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 32, 32, 256)  196864      concatenate_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 256)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 256)  0           conv2d_97[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 32, 32, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 32, 32, 32)   8224        activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 32, 32, 256)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 32, 32, 38)   9766        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 32, 32, 129)  74433       conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 32, 32, 64)   51264       conv2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 32, 32, 25)   6425        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 256)  0           conv2d_98[0][0]
#                                                                  conv2d_101[0][0]
#                                                                  conv2d_102[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 256)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 256)  0           activation_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 256)  262400      activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 384)  0           conv2d_transpose_3[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 32)   12320       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 64, 64, 16)   6160        concatenate_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 64, 64, 19)   7315        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_105[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 12)   4620        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 64, 64, 128)  0           conv2d_104[0][0]
#                                                                  conv2d_107[0][0]
#                                                                  conv2d_108[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 128)  49280       concatenate_19[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 128)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 128)  0           conv2d_110[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 128)  0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 64, 64, 32)   4128        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 64, 64, 16)   2064        activation_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 64, 64, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 64, 64, 19)   2451        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 64, 64, 12)   1548        max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 64, 64, 128)  0           conv2d_111[0][0]
#                                                                  conv2d_114[0][0]
#                                                                  conv2d_115[0][0]
#                                                                  conv2d_116[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 128)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 64, 128)  0           activation_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 128)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 128 65664       activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 192 0           conv2d_transpose_4[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 128, 128, 16) 3088        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 128, 8)  1544        concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 128, 128, 9)  1737        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 128, 128, 6)  1158        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 64) 0           conv2d_117[0][0]
#                                                                  conv2d_120[0][0]
#                                                                  conv2d_121[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 128, 64) 12352       concatenate_22[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 64) 0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 128, 128, 64) 0           conv2d_123[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 64) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 128, 128, 16) 1040        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 128, 128, 8)  520         activation_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 64) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 128, 128, 9)  585         activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 128, 128, 6)  390         max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 64) 0           conv2d_124[0][0]
#                                                                  conv2d_127[0][0]
#                                                                  conv2d_128[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 128, 128, 64) 0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 128, 64) 0           activation_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 64) 0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 64) 16448       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 96) 0           conv2d_transpose_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 256, 256, 8)  776         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 8)  808         conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 3)  291         max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 256, 256, 32) 0           conv2d_130[0][0]
#                                                                  conv2d_133[0][0]
#                                                                  conv2d_134[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 32) 3104        concatenate_25[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 256, 256, 32) 0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 256, 256, 32) 0           conv2d_136[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 32) 0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 256, 256, 8)  264         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 256, 256, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 256, 256, 8)  808         conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 256, 256, 3)  99          max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 256, 256, 32) 0           conv2d_137[0][0]
#                                                                  conv2d_140[0][0]
#                                                                  conv2d_141[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 256, 256, 32) 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 256, 256, 32) 0           activation_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 32) 0           add_22[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 3)  99          activation_22[0][0]
# ==================================================================================================
# Total params: 8,442,348
# Trainable params: 8,442,348
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils import Sequence
import cv2
from sklearn.utils import shuffle
from skimage.transform import AffineTransform, warp
import copy

class data_generator(Sequence):
    def __init__(self, data, label, batch_size=4, training=True):
        self.data = data
        self.label= label
        self.batch_size = batch_size
        self.training = training
    def __len__(self):
        return int(np.ceil(float(len(self.data))/self.batch_size))
    def on_epoch_end(self):
        if self.training: self.data, self.label = shuffle(self.data, self.label)
    def __getitem__(self, i):
        l_bound =  i    * self.batch_size
        r_bound = (i+1) * self.batch_size
        if r_bound>len(self.data): # ensure every iteration has the same batch size
            r_bound = len(self.data)
            l_bound = r_bound - self.batch_size
        dat_que = np.empty((self.batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
        lab_que = np.empty((self.batch_size, IMG_HEIGHT, IMG_WIDTH, 3), dtype=np.float32)
        for n, index in enumerate(range(l_bound, r_bound)):
            img = copy.deepcopy(self.data[index]).astype(np.float32) / 255.
            lab = copy.deepcopy(self.label[index][0])
            marker = copy.deepcopy(self.label[index][1])
            dt = copy.deepcopy(self.label[index][2])
            if self.training:
                if np.random.rand() < .5: # flip vertical
                    img = np.flip(img, 0)
                    lab = np.flip(lab, 0)
                    marker = np.flip(marker, 0)
                    dt = np.flip(dt, 0)
                if np.random.rand() < .5: # flip horizontal
                    img = np.flip(img, 1)
                    lab = np.flip(lab, 1)
                    marker = np.flip(marker, 1)
                    dt = np.flip(dt, 1)

                # rotation, shearing
                if np.random.rand() < 0.5:
                    y, x, _ = img.shape
                    h, w = y, x
                    img = np.pad(img, ((y//2, y//2), (x//2, x//2), (0, 0)), 'reflect')
                    lab = np.pad(lab, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    marker = np.pad(marker, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    dt = np.pad(dt, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    
                    rotT = np.random.uniform(-45,45)
                    shearT = np.random.uniform(-5,5)
                    translationX = np.random.uniform(-w,w) * .1
                    translationY = np.random.uniform(-h,h) * .1
                    atmtx = AffineTransform(rotation=rotT, shear=shearT, translation=(translationX, translationY))

                    img = warp(img, atmtx)
                    lab = warp(lab, atmtx)
                    marker = warp(marker, atmtx)
                    dt = warp(dt, atmtx)

                    img = img[h//2:h//2+h,w//2:w//2+w,:]
                    lab = lab[h//2:h//2+h,w//2:w//2+w]
                    marker = marker[h//2:h//2+h,w//2:w//2+w]
                    dt = dt[h//2:h//2+h,w//2:w//2+w]

                # random amplify each channel
                a = .1 # amptitude
                t  = [np.random.uniform(-a,a)]
                t += [np.random.uniform(-a,a)]
                t += [np.random.uniform(-a,a)]
                t = np.array(t)

                img = np.clip(img * (1. + t), 0, 1) # channel wise amplify
                up = np.random.uniform(0.95, 1.05) # change gamma
                img = np.clip(img**up, 0, 1) # apply gamma and convert back to range [0,255]

            ### end of data augmentation ###

            img = (resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)*255.).astype(np.uint8)
            lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
            marker = resize(marker, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
            dt = resize(dt, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

            dat_que[n,:,:,:] = img
            lab_que[n,:,:,0] = lab > .5
            lab_que[n,:,:,1] = marker > .5
            lab_que[n,:,:,2] = dt
        return dat_que, lab_que

# %%
from sklearn.model_selection import train_test_split
if not os.path.exists('./models'):
    os.makedirs('./models')

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=65, shuffle=True)

BS=8
EPOCHS=200
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=True)
val_generator = data_generator(X_val, Y_val, batch_size=BS, training=False)

# earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('./models/model.{epoch:03d}.vl.{val_loss:.2f}.vi.{val_mean_iou:.2f}.vim.{val_mean_iou_marker:.2f}.h5', verbose=0, save_best_only=False)
checkpointer_best = ModelCheckpoint('./models/best.h5', verbose=1, save_best_only=True)
history = model.fit_generator(train_generator,
                              steps_per_epoch=len(train_generator), epochs=EPOCHS, 
                              validation_data=val_generator, 
                              validation_steps=len(val_generator),
                              callbacks=[checkpointer, checkpointer_best],
                              workers=5,
                              use_multiprocessing=True
                              )
# Out:
# Epoch 1/200
# 76/76 [==============================] - 74s 976ms/step - loss: 1.8526 - mean_iou: 0.5600 - mean_iou_marker: 0.4656 - val_loss: 1.5580 - val_mean_iou: 0.6606 - val_mean_iou_marker: 0.5201
#
# Epoch 00001: val_loss improved from inf to 1.55796, saving model to ./models/best.h5
# Epoch 2/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.3824 - mean_iou: 0.7070 - mean_iou_marker: 0.5425 - val_loss: 1.3874 - val_mean_iou: 0.7355 - val_mean_iou_marker: 0.5563
#
# Epoch 00002: val_loss improved from 1.55796 to 1.38741, saving model to ./models/best.h5
# Epoch 3/200
# 76/76 [==============================] - 67s 881ms/step - loss: 1.3191 - mean_iou: 0.7545 - mean_iou_marker: 0.5683 - val_loss: 1.3438 - val_mean_iou: 0.7697 - val_mean_iou_marker: 0.5767
#
# Epoch 00003: val_loss improved from 1.38741 to 1.34376, saving model to ./models/best.h5
# Epoch 4/200
# 76/76 [==============================] - 67s 880ms/step - loss: 1.2768 - mean_iou: 0.7824 - mean_iou_marker: 0.5836 - val_loss: 1.2739 - val_mean_iou: 0.7915 - val_mean_iou_marker: 0.5914
#
# Epoch 00004: val_loss improved from 1.34376 to 1.27392, saving model to ./models/best.h5
# Epoch 5/200
# 76/76 [==============================] - 67s 881ms/step - loss: 1.2299 - mean_iou: 0.7997 - mean_iou_marker: 0.5970 - val_loss: 1.2104 - val_mean_iou: 0.8072 - val_mean_iou_marker: 0.6036
#
# Epoch 00005: val_loss improved from 1.27392 to 1.21038, saving model to ./models/best.h5
# Epoch 6/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.2218 - mean_iou: 0.8136 - mean_iou_marker: 0.6092 - val_loss: 1.1914 - val_mean_iou: 0.8180 - val_mean_iou_marker: 0.6138
#
# Epoch 00006: val_loss improved from 1.21038 to 1.19140, saving model to ./models/best.h5
# Epoch 7/200
# 76/76 [==============================] - 67s 888ms/step - loss: 1.2103 - mean_iou: 0.8220 - mean_iou_marker: 0.6178 - val_loss: 1.1734 - val_mean_iou: 0.8254 - val_mean_iou_marker: 0.6217
#
# Epoch 00007: val_loss improved from 1.19140 to 1.17340, saving model to ./models/best.h5
# Epoch 8/200
# 76/76 [==============================] - 67s 877ms/step - loss: 1.1700 - mean_iou: 0.8294 - mean_iou_marker: 0.6251 - val_loss: 1.1518 - val_mean_iou: 0.8328 - val_mean_iou_marker: 0.6293
#
# Epoch 00008: val_loss improved from 1.17340 to 1.15180, saving model to ./models/best.h5
# Epoch 9/200
# 76/76 [==============================] - 67s 880ms/step - loss: 1.1338 - mean_iou: 0.8362 - mean_iou_marker: 0.6334 - val_loss: 1.1448 - val_mean_iou: 0.8390 - val_mean_iou_marker: 0.6365
#
# Epoch 00009: val_loss improved from 1.15180 to 1.14477, saving model to ./models/best.h5
# Epoch 10/200
# 76/76 [==============================] - 67s 878ms/step - loss: 1.1446 - mean_iou: 0.8416 - mean_iou_marker: 0.6396 - val_loss: 1.1474 - val_mean_iou: 0.8437 - val_mean_iou_marker: 0.6422
#
# Epoch 00010: val_loss did not improve
# Epoch 11/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.1240 - mean_iou: 0.8459 - mean_iou_marker: 0.6446 - val_loss: 1.1244 - val_mean_iou: 0.8475 - val_mean_iou_marker: 0.6465
#
# Epoch 00011: val_loss improved from 1.14477 to 1.12440, saving model to ./models/best.h5
# Epoch 12/200
# 76/76 [==============================] - 67s 880ms/step - loss: 1.1504 - mean_iou: 0.8489 - mean_iou_marker: 0.6482 - val_loss: 1.1465 - val_mean_iou: 0.8499 - val_mean_iou_marker: 0.6497
#
# Epoch 00012: val_loss did not improve
# Epoch 13/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.1775 - mean_iou: 0.8511 - mean_iou_marker: 0.6512 - val_loss: 1.1348 - val_mean_iou: 0.8524 - val_mean_iou_marker: 0.6530
#
# Epoch 00013: val_loss did not improve
# Epoch 14/200
# 76/76 [==============================] - 67s 880ms/step - loss: 1.1403 - mean_iou: 0.8539 - mean_iou_marker: 0.6551 - val_loss: 1.1289 - val_mean_iou: 0.8548 - val_mean_iou_marker: 0.6567
#
# Epoch 00014: val_loss did not improve
# Epoch 15/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.1152 - mean_iou: 0.8562 - mean_iou_marker: 0.6582 - val_loss: 1.1105 - val_mean_iou: 0.8573 - val_mean_iou_marker: 0.6595
#
# Epoch 00015: val_loss improved from 1.12440 to 1.11048, saving model to ./models/best.h5
# Epoch 16/200
# 76/76 [==============================] - 67s 875ms/step - loss: 1.1134 - mean_iou: 0.8584 - mean_iou_marker: 0.6611 - val_loss: 1.0924 - val_mean_iou: 0.8595 - val_mean_iou_marker: 0.6626
#
# Epoch 00016: val_loss improved from 1.11048 to 1.09239, saving model to ./models/best.h5
# Epoch 17/200
# 76/76 [==============================] - 67s 883ms/step - loss: 1.0991 - mean_iou: 0.8607 - mean_iou_marker: 0.6642 - val_loss: 1.1222 - val_mean_iou: 0.8616 - val_mean_iou_marker: 0.6660
#
# Epoch 00017: val_loss did not improve
# Epoch 18/200
# 76/76 [==============================] - 67s 877ms/step - loss: 1.0904 - mean_iou: 0.8623 - mean_iou_marker: 0.6676 - val_loss: 1.0931 - val_mean_iou: 0.8633 - val_mean_iou_marker: 0.6690
#
# Epoch 00018: val_loss did not improve
# Epoch 19/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.1070 - mean_iou: 0.8641 - mean_iou_marker: 0.6701 - val_loss: 1.1102 - val_mean_iou: 0.8649 - val_mean_iou_marker: 0.6713
#
# Epoch 00019: val_loss did not improve
# Epoch 20/200
# 76/76 [==============================] - 67s 875ms/step - loss: 1.1010 - mean_iou: 0.8656 - mean_iou_marker: 0.6721 - val_loss: 1.0922 - val_mean_iou: 0.8662 - val_mean_iou_marker: 0.6732
#
# Epoch 00020: val_loss improved from 1.09239 to 1.09218, saving model to ./models/best.h5
# Epoch 21/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.0891 - mean_iou: 0.8669 - mean_iou_marker: 0.6741 - val_loss: 1.1046 - val_mean_iou: 0.8677 - val_mean_iou_marker: 0.6750
#
# Epoch 00021: val_loss did not improve
# Epoch 22/200
# 76/76 [==============================] - 67s 881ms/step - loss: 1.1036 - mean_iou: 0.8683 - mean_iou_marker: 0.6758 - val_loss: 1.1125 - val_mean_iou: 0.8688 - val_mean_iou_marker: 0.6764
#
# Epoch 00022: val_loss did not improve
# Epoch 23/200
# 76/76 [==============================] - 67s 881ms/step - loss: 1.1157 - mean_iou: 0.8694 - mean_iou_marker: 0.6773 - val_loss: 1.0842 - val_mean_iou: 0.8698 - val_mean_iou_marker: 0.6782
#
# Epoch 00023: val_loss improved from 1.09218 to 1.08416, saving model to ./models/best.h5
# Epoch 24/200
# 76/76 [==============================] - 67s 875ms/step - loss: 1.1025 - mean_iou: 0.8702 - mean_iou_marker: 0.6788 - val_loss: 1.0953 - val_mean_iou: 0.8706 - val_mean_iou_marker: 0.6796
#
# Epoch 00024: val_loss did not improve
# Epoch 25/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0803 - mean_iou: 0.8712 - mean_iou_marker: 0.6805 - val_loss: 1.0894 - val_mean_iou: 0.8717 - val_mean_iou_marker: 0.6811
#
# Epoch 00025: val_loss did not improve
# Epoch 26/200
# 76/76 [==============================] - 66s 875ms/step - loss: 1.0845 - mean_iou: 0.8721 - mean_iou_marker: 0.6816 - val_loss: 1.1065 - val_mean_iou: 0.8725 - val_mean_iou_marker: 0.6822
#
# Epoch 00026: val_loss did not improve
# Epoch 27/200
# 76/76 [==============================] - 66s 873ms/step - loss: 1.0951 - mean_iou: 0.8728 - mean_iou_marker: 0.6827 - val_loss: 1.0837 - val_mean_iou: 0.8732 - val_mean_iou_marker: 0.6834
#
# Epoch 00027: val_loss improved from 1.08416 to 1.08373, saving model to ./models/best.h5
# Epoch 28/200
# 76/76 [==============================] - 67s 882ms/step - loss: 1.0900 - mean_iou: 0.8737 - mean_iou_marker: 0.6841 - val_loss: 1.0905 - val_mean_iou: 0.8741 - val_mean_iou_marker: 0.6848
#
# Epoch 00028: val_loss did not improve
# Epoch 29/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0885 - mean_iou: 0.8746 - mean_iou_marker: 0.6853 - val_loss: 1.0963 - val_mean_iou: 0.8749 - val_mean_iou_marker: 0.6858
#
# Epoch 00029: val_loss did not improve
# Epoch 30/200
# 76/76 [==============================] - 67s 876ms/step - loss: 1.0910 - mean_iou: 0.8752 - mean_iou_marker: 0.6863 - val_loss: 1.0890 - val_mean_iou: 0.8755 - val_mean_iou_marker: 0.6871
#
# Epoch 00030: val_loss did not improve
# Epoch 31/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.0559 - mean_iou: 0.8759 - mean_iou_marker: 0.6878 - val_loss: 1.0825 - val_mean_iou: 0.8763 - val_mean_iou_marker: 0.6883
#
# Epoch 00031: val_loss improved from 1.08373 to 1.08248, saving model to ./models/best.h5
# Epoch 32/200
# 76/76 [==============================] - 67s 878ms/step - loss: 1.0519 - mean_iou: 0.8768 - mean_iou_marker: 0.6891 - val_loss: 1.0714 - val_mean_iou: 0.8772 - val_mean_iou_marker: 0.6899
#
# Epoch 00032: val_loss improved from 1.08248 to 1.07136, saving model to ./models/best.h5
# Epoch 33/200
# 76/76 [==============================] - 67s 876ms/step - loss: 1.0958 - mean_iou: 0.8775 - mean_iou_marker: 0.6903 - val_loss: 1.0795 - val_mean_iou: 0.8778 - val_mean_iou_marker: 0.6906
#
# Epoch 00033: val_loss did not improve
# Epoch 34/200
# 76/76 [==============================] - 66s 873ms/step - loss: 1.0646 - mean_iou: 0.8783 - mean_iou_marker: 0.6912 - val_loss: 1.0753 - val_mean_iou: 0.8786 - val_mean_iou_marker: 0.6917
#
# Epoch 00034: val_loss did not improve
# Epoch 35/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0624 - mean_iou: 0.8790 - mean_iou_marker: 0.6922 - val_loss: 1.0760 - val_mean_iou: 0.8793 - val_mean_iou_marker: 0.6927
#
# Epoch 00035: val_loss did not improve
# Epoch 36/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0543 - mean_iou: 0.8796 - mean_iou_marker: 0.6933 - val_loss: 1.0721 - val_mean_iou: 0.8800 - val_mean_iou_marker: 0.6938
#
# Epoch 00036: val_loss did not improve
# Epoch 37/200
# 76/76 [==============================] - 67s 876ms/step - loss: 1.0619 - mean_iou: 0.8803 - mean_iou_marker: 0.6944 - val_loss: 1.0899 - val_mean_iou: 0.8806 - val_mean_iou_marker: 0.6948
#
# Epoch 00037: val_loss did not improve
# Epoch 38/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0630 - mean_iou: 0.8810 - mean_iou_marker: 0.6952 - val_loss: 1.0797 - val_mean_iou: 0.8812 - val_mean_iou_marker: 0.6958
#
# Epoch 00038: val_loss did not improve
# Epoch 39/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0492 - mean_iou: 0.8815 - mean_iou_marker: 0.6963 - val_loss: 1.0761 - val_mean_iou: 0.8818 - val_mean_iou_marker: 0.6967
#
# Epoch 00039: val_loss did not improve
# Epoch 40/200
# 76/76 [==============================] - 66s 868ms/step - loss: 1.0539 - mean_iou: 0.8821 - mean_iou_marker: 0.6972 - val_loss: 1.0703 - val_mean_iou: 0.8823 - val_mean_iou_marker: 0.6976
#
# Epoch 00040: val_loss improved from 1.07136 to 1.07026, saving model to ./models/best.h5
# Epoch 41/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0570 - mean_iou: 0.8826 - mean_iou_marker: 0.6982 - val_loss: 1.0722 - val_mean_iou: 0.8828 - val_mean_iou_marker: 0.6987
#
# Epoch 00041: val_loss did not improve
# Epoch 42/200
# 76/76 [==============================] - 66s 870ms/step - loss: 1.0705 - mean_iou: 0.8831 - mean_iou_marker: 0.6990 - val_loss: 1.0731 - val_mean_iou: 0.8833 - val_mean_iou_marker: 0.6995
#
# Epoch 00042: val_loss did not improve
# Epoch 43/200
# 76/76 [==============================] - 67s 879ms/step - loss: 1.0714 - mean_iou: 0.8835 - mean_iou_marker: 0.6998 - val_loss: 1.0827 - val_mean_iou: 0.8837 - val_mean_iou_marker: 0.7001
#
# Epoch 00043: val_loss did not improve
# Epoch 44/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0609 - mean_iou: 0.8840 - mean_iou_marker: 0.7004 - val_loss: 1.0692 - val_mean_iou: 0.8843 - val_mean_iou_marker: 0.7007
#
# Epoch 00044: val_loss improved from 1.07026 to 1.06924, saving model to ./models/best.h5
# Epoch 45/200
# 76/76 [==============================] - 66s 868ms/step - loss: 1.0531 - mean_iou: 0.8845 - mean_iou_marker: 0.7011 - val_loss: 1.1234 - val_mean_iou: 0.8846 - val_mean_iou_marker: 0.7015
#
# Epoch 00045: val_loss did not improve
# Epoch 46/200
# 76/76 [==============================] - 66s 873ms/step - loss: 1.0595 - mean_iou: 0.8848 - mean_iou_marker: 0.7017 - val_loss: 1.0613 - val_mean_iou: 0.8850 - val_mean_iou_marker: 0.7020
#
# Epoch 00046: val_loss improved from 1.06924 to 1.06131, saving model to ./models/best.h5
# Epoch 47/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0400 - mean_iou: 0.8852 - mean_iou_marker: 0.7023 - val_loss: 1.0577 - val_mean_iou: 0.8854 - val_mean_iou_marker: 0.7026
#
# Epoch 00047: val_loss improved from 1.06131 to 1.05768, saving model to ./models/best.h5
# Epoch 48/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0298 - mean_iou: 0.8857 - mean_iou_marker: 0.7031 - val_loss: 1.0599 - val_mean_iou: 0.8859 - val_mean_iou_marker: 0.7035
#
# Epoch 00048: val_loss did not improve
# Epoch 49/200
# 76/76 [==============================] - 67s 877ms/step - loss: 1.0588 - mean_iou: 0.8861 - mean_iou_marker: 0.7038 - val_loss: 1.0646 - val_mean_iou: 0.8863 - val_mean_iou_marker: 0.7041
#
# Epoch 00049: val_loss did not improve
# Epoch 50/200
# 76/76 [==============================] - 66s 870ms/step - loss: 1.0736 - mean_iou: 0.8864 - mean_iou_marker: 0.7042 - val_loss: 1.0523 - val_mean_iou: 0.8866 - val_mean_iou_marker: 0.7044
#
# Epoch 00050: val_loss improved from 1.05768 to 1.05235, saving model to ./models/best.h5
# Epoch 51/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0541 - mean_iou: 0.8868 - mean_iou_marker: 0.7047 - val_loss: 1.0547 - val_mean_iou: 0.8870 - val_mean_iou_marker: 0.7050
#
# Epoch 00051: val_loss did not improve
# Epoch 52/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0477 - mean_iou: 0.8872 - mean_iou_marker: 0.7054 - val_loss: 1.0756 - val_mean_iou: 0.8874 - val_mean_iou_marker: 0.7057
#
# Epoch 00052: val_loss did not improve
# Epoch 53/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0213 - mean_iou: 0.8875 - mean_iou_marker: 0.7061 - val_loss: 1.0556 - val_mean_iou: 0.8878 - val_mean_iou_marker: 0.7066
#
# Epoch 00053: val_loss did not improve
# Epoch 54/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0372 - mean_iou: 0.8880 - mean_iou_marker: 0.7069 - val_loss: 1.0615 - val_mean_iou: 0.8882 - val_mean_iou_marker: 0.7071
#
# Epoch 00054: val_loss did not improve
# Epoch 55/200
# 76/76 [==============================] - 66s 870ms/step - loss: 1.0361 - mean_iou: 0.8884 - mean_iou_marker: 0.7074 - val_loss: 1.0448 - val_mean_iou: 0.8885 - val_mean_iou_marker: 0.7077
#
# Epoch 00055: val_loss improved from 1.05235 to 1.04485, saving model to ./models/best.h5
# Epoch 56/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0494 - mean_iou: 0.8887 - mean_iou_marker: 0.7080 - val_loss: 1.0612 - val_mean_iou: 0.8889 - val_mean_iou_marker: 0.7082
#
# Epoch 00056: val_loss did not improve
# Epoch 57/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0277 - mean_iou: 0.8891 - mean_iou_marker: 0.7084 - val_loss: 1.0647 - val_mean_iou: 0.8893 - val_mean_iou_marker: 0.7087
#
# Epoch 00057: val_loss did not improve
# Epoch 58/200
# 76/76 [==============================] - 66s 866ms/step - loss: 1.0706 - mean_iou: 0.8894 - mean_iou_marker: 0.7088 - val_loss: 1.0622 - val_mean_iou: 0.8895 - val_mean_iou_marker: 0.7089
#
# Epoch 00058: val_loss did not improve
# Epoch 59/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0558 - mean_iou: 0.8897 - mean_iou_marker: 0.7091 - val_loss: 1.0698 - val_mean_iou: 0.8898 - val_mean_iou_marker: 0.7093
#
# Epoch 00059: val_loss did not improve
# Epoch 60/200
# 76/76 [==============================] - 65s 851ms/step - loss: 1.0286 - mean_iou: 0.8900 - mean_iou_marker: 0.7096 - val_loss: 1.0579 - val_mean_iou: 0.8902 - val_mean_iou_marker: 0.7098
#
# Epoch 00060: val_loss did not improve
# Epoch 61/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0341 - mean_iou: 0.8904 - mean_iou_marker: 0.7103 - val_loss: 1.0608 - val_mean_iou: 0.8905 - val_mean_iou_marker: 0.7105
#
# Epoch 00061: val_loss did not improve
# Epoch 62/200
# 76/76 [==============================] - 67s 876ms/step - loss: 1.0304 - mean_iou: 0.8907 - mean_iou_marker: 0.7109 - val_loss: 1.0471 - val_mean_iou: 0.8908 - val_mean_iou_marker: 0.7112
#
# Epoch 00062: val_loss did not improve
# Epoch 63/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0406 - mean_iou: 0.8910 - mean_iou_marker: 0.7114 - val_loss: 1.0389 - val_mean_iou: 0.8911 - val_mean_iou_marker: 0.7117
#
# Epoch 00063: val_loss improved from 1.04485 to 1.03886, saving model to ./models/best.h5
# Epoch 64/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0681 - mean_iou: 0.8912 - mean_iou_marker: 0.7119 - val_loss: 1.0743 - val_mean_iou: 0.8913 - val_mean_iou_marker: 0.7120
#
# Epoch 00064: val_loss did not improve
# Epoch 65/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0307 - mean_iou: 0.8914 - mean_iou_marker: 0.7122 - val_loss: 1.0673 - val_mean_iou: 0.8915 - val_mean_iou_marker: 0.7124
#
# Epoch 00065: val_loss did not improve
# Epoch 66/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0363 - mean_iou: 0.8916 - mean_iou_marker: 0.7126 - val_loss: 1.0634 - val_mean_iou: 0.8917 - val_mean_iou_marker: 0.7128
#
# Epoch 00066: val_loss did not improve
# Epoch 67/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0308 - mean_iou: 0.8919 - mean_iou_marker: 0.7129 - val_loss: 1.0477 - val_mean_iou: 0.8920 - val_mean_iou_marker: 0.7132
#
# Epoch 00067: val_loss did not improve
# Epoch 68/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0300 - mean_iou: 0.8922 - mean_iou_marker: 0.7135 - val_loss: 1.0443 - val_mean_iou: 0.8923 - val_mean_iou_marker: 0.7137
#
# Epoch 00068: val_loss did not improve
# Epoch 69/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0763 - mean_iou: 0.8924 - mean_iou_marker: 0.7138 - val_loss: 1.0565 - val_mean_iou: 0.8925 - val_mean_iou_marker: 0.7138
#
# Epoch 00069: val_loss did not improve
# Epoch 70/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0641 - mean_iou: 0.8926 - mean_iou_marker: 0.7139 - val_loss: 1.0729 - val_mean_iou: 0.8927 - val_mean_iou_marker: 0.7141
#
# Epoch 00070: val_loss did not improve
# Epoch 71/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0550 - mean_iou: 0.8928 - mean_iou_marker: 0.7142 - val_loss: 1.0437 - val_mean_iou: 0.8929 - val_mean_iou_marker: 0.7143
#
# Epoch 00071: val_loss did not improve
# Epoch 72/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0464 - mean_iou: 0.8930 - mean_iou_marker: 0.7145 - val_loss: 1.0390 - val_mean_iou: 0.8931 - val_mean_iou_marker: 0.7147
#
# Epoch 00072: val_loss did not improve
# Epoch 73/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0200 - mean_iou: 0.8932 - mean_iou_marker: 0.7149 - val_loss: 1.0285 - val_mean_iou: 0.8934 - val_mean_iou_marker: 0.7152
#
# Epoch 00073: val_loss improved from 1.03886 to 1.02852, saving model to ./models/best.h5
# Epoch 74/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0379 - mean_iou: 0.8935 - mean_iou_marker: 0.7154 - val_loss: 1.0429 - val_mean_iou: 0.8936 - val_mean_iou_marker: 0.7155
#
# Epoch 00074: val_loss did not improve
# Epoch 75/200
# 76/76 [==============================] - 66s 873ms/step - loss: 1.0166 - mean_iou: 0.8937 - mean_iou_marker: 0.7157 - val_loss: 1.0383 - val_mean_iou: 0.8938 - val_mean_iou_marker: 0.7159
#
# Epoch 00075: val_loss did not improve
# Epoch 76/200
# 76/76 [==============================] - 66s 868ms/step - loss: 1.0180 - mean_iou: 0.8940 - mean_iou_marker: 0.7162 - val_loss: 1.0542 - val_mean_iou: 0.8940 - val_mean_iou_marker: 0.7164
#
# Epoch 00076: val_loss did not improve
# Epoch 77/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0535 - mean_iou: 0.8941 - mean_iou_marker: 0.7166 - val_loss: 1.0484 - val_mean_iou: 0.8942 - val_mean_iou_marker: 0.7168
#
# Epoch 00077: val_loss did not improve
# Epoch 78/200
# 76/76 [==============================] - 66s 875ms/step - loss: 1.0470 - mean_iou: 0.8943 - mean_iou_marker: 0.7169 - val_loss: 1.0700 - val_mean_iou: 0.8944 - val_mean_iou_marker: 0.7170
#
# Epoch 00078: val_loss did not improve
# Epoch 79/200
# 76/76 [==============================] - 66s 870ms/step - loss: 1.0414 - mean_iou: 0.8944 - mean_iou_marker: 0.7171 - val_loss: 1.0463 - val_mean_iou: 0.8946 - val_mean_iou_marker: 0.7172
#
# Epoch 00079: val_loss did not improve
# Epoch 80/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0297 - mean_iou: 0.8947 - mean_iou_marker: 0.7175 - val_loss: 1.0489 - val_mean_iou: 0.8948 - val_mean_iou_marker: 0.7176
#
# Epoch 00080: val_loss did not improve
# Epoch 81/200
# 76/76 [==============================] - 66s 868ms/step - loss: 1.0403 - mean_iou: 0.8948 - mean_iou_marker: 0.7178 - val_loss: 1.0440 - val_mean_iou: 0.8949 - val_mean_iou_marker: 0.7179
#
# Epoch 00081: val_loss did not improve
# Epoch 82/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0580 - mean_iou: 0.8950 - mean_iou_marker: 0.7180 - val_loss: 1.0379 - val_mean_iou: 0.8951 - val_mean_iou_marker: 0.7181
#
# Epoch 00082: val_loss did not improve
# Epoch 83/200
# 76/76 [==============================] - 66s 868ms/step - loss: 1.0357 - mean_iou: 0.8952 - mean_iou_marker: 0.7183 - val_loss: 1.0691 - val_mean_iou: 0.8952 - val_mean_iou_marker: 0.7185
#
# Epoch 00083: val_loss did not improve
# Epoch 84/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0223 - mean_iou: 0.8953 - mean_iou_marker: 0.7187 - val_loss: 1.0372 - val_mean_iou: 0.8954 - val_mean_iou_marker: 0.7188
#
# Epoch 00084: val_loss did not improve
# Epoch 85/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0371 - mean_iou: 0.8955 - mean_iou_marker: 0.7189 - val_loss: 1.0431 - val_mean_iou: 0.8956 - val_mean_iou_marker: 0.7191
#
# Epoch 00085: val_loss did not improve
# Epoch 86/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0315 - mean_iou: 0.8957 - mean_iou_marker: 0.7192 - val_loss: 1.0284 - val_mean_iou: 0.8958 - val_mean_iou_marker: 0.7194
#
# Epoch 00086: val_loss improved from 1.02852 to 1.02841, saving model to ./models/best.h5
# Epoch 87/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0199 - mean_iou: 0.8959 - mean_iou_marker: 0.7196 - val_loss: 1.0421 - val_mean_iou: 0.8959 - val_mean_iou_marker: 0.7198
#
# Epoch 00087: val_loss did not improve
# Epoch 88/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0117 - mean_iou: 0.8960 - mean_iou_marker: 0.7200 - val_loss: 1.0359 - val_mean_iou: 0.8962 - val_mean_iou_marker: 0.7201
#
# Epoch 00088: val_loss did not improve
# Epoch 89/200
# 76/76 [==============================] - 65s 862ms/step - loss: 1.0312 - mean_iou: 0.8962 - mean_iou_marker: 0.7203 - val_loss: 1.0359 - val_mean_iou: 0.8963 - val_mean_iou_marker: 0.7204
#
# Epoch 00089: val_loss did not improve
# Epoch 90/200
# 76/76 [==============================] - 66s 862ms/step - loss: 1.0310 - mean_iou: 0.8964 - mean_iou_marker: 0.7206 - val_loss: 1.0322 - val_mean_iou: 0.8964 - val_mean_iou_marker: 0.7207
#
# Epoch 00090: val_loss did not improve
# Epoch 91/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0181 - mean_iou: 0.8965 - mean_iou_marker: 0.7208 - val_loss: 1.0400 - val_mean_iou: 0.8966 - val_mean_iou_marker: 0.7209
#
# Epoch 00091: val_loss did not improve
# Epoch 92/200
# 76/76 [==============================] - 66s 869ms/step - loss: 1.0290 - mean_iou: 0.8967 - mean_iou_marker: 0.7211 - val_loss: 1.0284 - val_mean_iou: 0.8968 - val_mean_iou_marker: 0.7212
#
# Epoch 00092: val_loss did not improve
# Epoch 93/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0255 - mean_iou: 0.8968 - mean_iou_marker: 0.7214 - val_loss: 1.0444 - val_mean_iou: 0.8969 - val_mean_iou_marker: 0.7215
#
# Epoch 00093: val_loss did not improve
# Epoch 94/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0320 - mean_iou: 0.8970 - mean_iou_marker: 0.7217 - val_loss: 1.0368 - val_mean_iou: 0.8971 - val_mean_iou_marker: 0.7218
#
# Epoch 00094: val_loss did not improve
# Epoch 95/200
# 76/76 [==============================] - 66s 866ms/step - loss: 1.0347 - mean_iou: 0.8972 - mean_iou_marker: 0.7219 - val_loss: 1.0448 - val_mean_iou: 0.8972 - val_mean_iou_marker: 0.7220
#
# Epoch 00095: val_loss did not improve
# Epoch 96/200
# 76/76 [==============================] - 65s 861ms/step - loss: 1.0137 - mean_iou: 0.8973 - mean_iou_marker: 0.7222 - val_loss: 1.0398 - val_mean_iou: 0.8974 - val_mean_iou_marker: 0.7222
#
# Epoch 00096: val_loss did not improve
# Epoch 97/200
# 76/76 [==============================] - 66s 874ms/step - loss: 1.0334 - mean_iou: 0.8974 - mean_iou_marker: 0.7223 - val_loss: 1.0308 - val_mean_iou: 0.8975 - val_mean_iou_marker: 0.7225
# Epoch 00097: val_loss did not improve
# Epoch 98/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0421 - mean_iou: 0.8976 - mean_iou_marker: 0.7226 - val_loss: 1.0402 - val_mean_iou: 0.8976 - val_mean_iou_marker: 0.7228
#
# Epoch 00098: val_loss did not improve
# Epoch 99/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0096 - mean_iou: 0.8977 - mean_iou_marker: 0.7229 - val_loss: 1.0357 - val_mean_iou: 0.8978 - val_mean_iou_marker: 0.7231
#
# Epoch 00099: val_loss did not improve
# Epoch 100/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0042 - mean_iou: 0.8978 - mean_iou_marker: 0.7233 - val_loss: 1.0332 - val_mean_iou: 0.8979 - val_mean_iou_marker: 0.7234
#
# Epoch 00100: val_loss did not improve
# Epoch 101/200
# 76/76 [==============================] - 65s 858ms/step - loss: 1.0229 - mean_iou: 0.8980 - mean_iou_marker: 0.7236 - val_loss: 1.0457 - val_mean_iou: 0.8980 - val_mean_iou_marker: 0.7237
#
# Epoch 00101: val_loss did not improve
# Epoch 102/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0301 - mean_iou: 0.8981 - mean_iou_marker: 0.7238 - val_loss: 1.0485 - val_mean_iou: 0.8982 - val_mean_iou_marker: 0.7238
#
# Epoch 00102: val_loss did not improve
# Epoch 103/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0375 - mean_iou: 0.8982 - mean_iou_marker: 0.7239 - val_loss: 1.0370 - val_mean_iou: 0.8982 - val_mean_iou_marker: 0.7240
#
# Epoch 00103: val_loss did not improve
# Epoch 104/200
# 76/76 [==============================] - 66s 866ms/step - loss: 1.0153 - mean_iou: 0.8983 - mean_iou_marker: 0.7241 - val_loss: 1.0486 - val_mean_iou: 0.8984 - val_mean_iou_marker: 0.7243
#
# Epoch 00104: val_loss did not improve
# Epoch 105/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0200 - mean_iou: 0.8984 - mean_iou_marker: 0.7244 - val_loss: 1.0388 - val_mean_iou: 0.8985 - val_mean_iou_marker: 0.7245
#
# Epoch 00105: val_loss did not improve
# Epoch 106/200
# 76/76 [==============================] - 66s 872ms/step - loss: 1.0192 - mean_iou: 0.8986 - mean_iou_marker: 0.7246 - val_loss: 1.0314 - val_mean_iou: 0.8986 - val_mean_iou_marker: 0.7248
#
# Epoch 00106: val_loss did not improve
# Epoch 107/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0211 - mean_iou: 0.8987 - mean_iou_marker: 0.7249 - val_loss: 1.0343 - val_mean_iou: 0.8987 - val_mean_iou_marker: 0.7250
#
# Epoch 00107: val_loss did not improve
# Epoch 108/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0199 - mean_iou: 0.8988 - mean_iou_marker: 0.7251 - val_loss: 1.0360 - val_mean_iou: 0.8989 - val_mean_iou_marker: 0.7252
#
# Epoch 00108: val_loss did not improve
# Epoch 109/200
# 76/76 [==============================] - 65s 861ms/step - loss: 1.0067 - mean_iou: 0.8990 - mean_iou_marker: 0.7254 - val_loss: 1.0358 - val_mean_iou: 0.8990 - val_mean_iou_marker: 0.7255
#
# Epoch 00109: val_loss did not improve
# Epoch 110/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0202 - mean_iou: 0.8991 - mean_iou_marker: 0.7256 - val_loss: 1.0339 - val_mean_iou: 0.8992 - val_mean_iou_marker: 0.7257
#
# Epoch 00110: val_loss did not improve
# Epoch 111/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0124 - mean_iou: 0.8992 - mean_iou_marker: 0.7258 - val_loss: 1.0324 - val_mean_iou: 0.8993 - val_mean_iou_marker: 0.7259
#
# Epoch 00111: val_loss did not improve
# Epoch 112/200
# 76/76 [==============================] - 66s 871ms/step - loss: 1.0218 - mean_iou: 0.8994 - mean_iou_marker: 0.7260 - val_loss: 1.0386 - val_mean_iou: 0.8994 - val_mean_iou_marker: 0.7261
#
# Epoch 00112: val_loss did not improve
# Epoch 113/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0126 - mean_iou: 0.8995 - mean_iou_marker: 0.7262 - val_loss: 1.0298 - val_mean_iou: 0.8995 - val_mean_iou_marker: 0.7263
#
# Epoch 00113: val_loss did not improve
# Epoch 114/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0158 - mean_iou: 0.8996 - mean_iou_marker: 0.7263 - val_loss: 1.0564 - val_mean_iou: 0.8996 - val_mean_iou_marker: 0.7264
#
# Epoch 00114: val_loss did not improve
# Epoch 115/200
# 76/76 [==============================] - 65s 858ms/step - loss: 1.0337 - mean_iou: 0.8997 - mean_iou_marker: 0.7265 - val_loss: 1.0359 - val_mean_iou: 0.8997 - val_mean_iou_marker: 0.7266
#
# Epoch 00115: val_loss did not improve
# Epoch 116/200
# 76/76 [==============================] - 65s 860ms/step - loss: 1.0258 - mean_iou: 0.8998 - mean_iou_marker: 0.7266 - val_loss: 1.0276 - val_mean_iou: 0.8998 - val_mean_iou_marker: 0.7267
#
# Epoch 00116: val_loss improved from 1.02841 to 1.02762, saving model to ./models/best.h5
# Epoch 117/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0262 - mean_iou: 0.8999 - mean_iou_marker: 0.7268 - val_loss: 1.0356 - val_mean_iou: 0.8999 - val_mean_iou_marker: 0.7269
#
# Epoch 00117: val_loss did not improve
# Epoch 118/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0136 - mean_iou: 0.9000 - mean_iou_marker: 0.7270 - val_loss: 1.0242 - val_mean_iou: 0.9000 - val_mean_iou_marker: 0.7271
#
# Epoch 00118: val_loss improved from 1.02762 to 1.02421, saving model to ./models/best.h5
# Epoch 119/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0519 - mean_iou: 0.9001 - mean_iou_marker: 0.7271 - val_loss: 1.0453 - val_mean_iou: 0.9001 - val_mean_iou_marker: 0.7272
#
# Epoch 00119: val_loss did not improve
# Epoch 120/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0259 - mean_iou: 0.9002 - mean_iou_marker: 0.7273 - val_loss: 1.0427 - val_mean_iou: 0.9003 - val_mean_iou_marker: 0.7274
#
# Epoch 00120: val_loss did not improve
# Epoch 121/200
# 76/76 [==============================] - 65s 860ms/step - loss: 1.0315 - mean_iou: 0.9003 - mean_iou_marker: 0.7274 - val_loss: 1.0330 - val_mean_iou: 0.9003 - val_mean_iou_marker: 0.7275
#
# Epoch 00121: val_loss did not improve
# Epoch 122/200
# 76/76 [==============================] - 65s 856ms/step - loss: 1.0194 - mean_iou: 0.9004 - mean_iou_marker: 0.7276 - val_loss: 1.0413 - val_mean_iou: 0.9005 - val_mean_iou_marker: 0.7277
#
# Epoch 00122: val_loss did not improve
# Epoch 123/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0217 - mean_iou: 0.9005 - mean_iou_marker: 0.7278 - val_loss: 1.0353 - val_mean_iou: 0.9006 - val_mean_iou_marker: 0.7278
#
# Epoch 00123: val_loss did not improve
# Epoch 124/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0103 - mean_iou: 0.9006 - mean_iou_marker: 0.7279 - val_loss: 1.0250 - val_mean_iou: 0.9007 - val_mean_iou_marker: 0.7280
#
# Epoch 00124: val_loss did not improve
# Epoch 125/200
# 76/76 [==============================] - 65s 861ms/step - loss: 1.0089 - mean_iou: 0.9007 - mean_iou_marker: 0.7282 - val_loss: 1.0356 - val_mean_iou: 0.9008 - val_mean_iou_marker: 0.7283
#
# Epoch 00125: val_loss did not improve
# Epoch 126/200
# 76/76 [==============================] - 65s 855ms/step - loss: 1.0129 - mean_iou: 0.9008 - mean_iou_marker: 0.7284 - val_loss: 1.0323 - val_mean_iou: 0.9008 - val_mean_iou_marker: 0.7285
#
# Epoch 00126: val_loss did not improve
# Epoch 127/200
# 76/76 [==============================] - 66s 863ms/step - loss: 1.0247 - mean_iou: 0.9009 - mean_iou_marker: 0.7286 - val_loss: 1.0347 - val_mean_iou: 0.9009 - val_mean_iou_marker: 0.7287
#
# Epoch 00127: val_loss did not improve
# Epoch 128/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0326 - mean_iou: 0.9010 - mean_iou_marker: 0.7287 - val_loss: 1.0302 - val_mean_iou: 0.9010 - val_mean_iou_marker: 0.7288
#
# Epoch 00128: val_loss did not improve
# Epoch 129/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0004 - mean_iou: 0.9010 - mean_iou_marker: 0.7289 - val_loss: 1.0315 - val_mean_iou: 0.9011 - val_mean_iou_marker: 0.7290
#
# Epoch 00129: val_loss did not improve
# Epoch 130/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0043 - mean_iou: 0.9011 - mean_iou_marker: 0.7291 - val_loss: 1.0216 - val_mean_iou: 0.9012 - val_mean_iou_marker: 0.7292
#
# Epoch 00130: val_loss improved from 1.02421 to 1.02164, saving model to ./models/best.h5
# Epoch 131/200
# 76/76 [==============================] - 65s 860ms/step - loss: 1.0062 - mean_iou: 0.9013 - mean_iou_marker: 0.7293 - val_loss: 1.0283 - val_mean_iou: 0.9013 - val_mean_iou_marker: 0.7294
#
# Epoch 00131: val_loss did not improve
# Epoch 132/200
# 76/76 [==============================] - 65s 861ms/step - loss: 1.0043 - mean_iou: 0.9014 - mean_iou_marker: 0.7295 - val_loss: 1.0204 - val_mean_iou: 0.9014 - val_mean_iou_marker: 0.7296
#
# Epoch 00132: val_loss improved from 1.02164 to 1.02036, saving model to ./models/best.h5
# Epoch 133/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0103 - mean_iou: 0.9015 - mean_iou_marker: 0.7297 - val_loss: 1.0192 - val_mean_iou: 0.9015 - val_mean_iou_marker: 0.7297
#
# Epoch 00133: val_loss improved from 1.02036 to 1.01924, saving model to ./models/best.h5
# Epoch 134/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0151 - mean_iou: 0.9016 - mean_iou_marker: 0.7299 - val_loss: 1.0248 - val_mean_iou: 0.9016 - val_mean_iou_marker: 0.7300
#
# Epoch 00134: val_loss did not improve
# Epoch 135/200
# 76/76 [==============================] - 65s 856ms/step - loss: 1.0176 - mean_iou: 0.9016 - mean_iou_marker: 0.7300 - val_loss: 1.0257 - val_mean_iou: 0.9017 - val_mean_iou_marker: 0.7301
#
# Epoch 00135: val_loss did not improve
# Epoch 136/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0188 - mean_iou: 0.9017 - mean_iou_marker: 0.7302 - val_loss: 1.0339 - val_mean_iou: 0.9018 - val_mean_iou_marker: 0.7302
#
# Epoch 00136: val_loss did not improve
# Epoch 137/200
# 76/76 [==============================] - 66s 867ms/step - loss: 1.0285 - mean_iou: 0.9018 - mean_iou_marker: 0.7303 - val_loss: 1.0390 - val_mean_iou: 0.9018 - val_mean_iou_marker: 0.7304
#
# Epoch 00137: val_loss did not improve
# Epoch 138/200
# 76/76 [==============================] - 65s 862ms/step - loss: 1.0194 - mean_iou: 0.9019 - mean_iou_marker: 0.7304 - val_loss: 1.0297 - val_mean_iou: 0.9019 - val_mean_iou_marker: 0.7305
#
# Epoch 00138: val_loss did not improve
# Epoch 139/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0115 - mean_iou: 0.9019 - mean_iou_marker: 0.7306 - val_loss: 1.0309 - val_mean_iou: 0.9020 - val_mean_iou_marker: 0.7306
#
# Epoch 00139: val_loss did not improve
# Epoch 140/200
# 76/76 [==============================] - 66s 862ms/step - loss: 1.0023 - mean_iou: 0.9020 - mean_iou_marker: 0.7307 - val_loss: 1.0234 - val_mean_iou: 0.9021 - val_mean_iou_marker: 0.7308
#
# Epoch 00140: val_loss did not improve
# Epoch 141/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0145 - mean_iou: 0.9021 - mean_iou_marker: 0.7309 - val_loss: 1.0250 - val_mean_iou: 0.9022 - val_mean_iou_marker: 0.7309
#
# Epoch 00141: val_loss did not improve
# Epoch 142/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0095 - mean_iou: 0.9022 - mean_iou_marker: 0.7310 - val_loss: 1.0287 - val_mean_iou: 0.9023 - val_mean_iou_marker: 0.7311
#
# Epoch 00142: val_loss did not improve
# Epoch 143/200
# 76/76 [==============================] - 66s 862ms/step - loss: 1.0087 - mean_iou: 0.9023 - mean_iou_marker: 0.7312 - val_loss: 1.0229 - val_mean_iou: 0.9023 - val_mean_iou_marker: 0.7313
#
# Epoch 00143: val_loss did not improve
# Epoch 144/200
# 76/76 [==============================] - 66s 862ms/step - loss: 1.0013 - mean_iou: 0.9024 - mean_iou_marker: 0.7314 - val_loss: 1.0238 - val_mean_iou: 0.9024 - val_mean_iou_marker: 0.7315
#
# Epoch 00144: val_loss did not improve
# Epoch 145/200
# 76/76 [==============================] - 65s 851ms/step - loss: 1.0140 - mean_iou: 0.9025 - mean_iou_marker: 0.7316 - val_loss: 1.0275 - val_mean_iou: 0.9025 - val_mean_iou_marker: 0.7316
#
# Epoch 00145: val_loss did not improve
# Epoch 146/200
# 76/76 [==============================] - 65s 854ms/step - loss: 1.0113 - mean_iou: 0.9026 - mean_iou_marker: 0.7317 - val_loss: 1.0210 - val_mean_iou: 0.9026 - val_mean_iou_marker: 0.7318
#
# Epoch 00146: val_loss did not improve
# Epoch 147/200
# 76/76 [==============================] - 65s 855ms/step - loss: 1.0250 - mean_iou: 0.9026 - mean_iou_marker: 0.7319 - val_loss: 1.0346 - val_mean_iou: 0.9027 - val_mean_iou_marker: 0.7320
#
# Epoch 00147: val_loss did not improve
# Epoch 148/200
# 76/76 [==============================] - 66s 862ms/step - loss: 0.9862 - mean_iou: 0.9027 - mean_iou_marker: 0.7321 - val_loss: 1.0169 - val_mean_iou: 0.9028 - val_mean_iou_marker: 0.7322
#
# Epoch 00148: val_loss improved from 1.01924 to 1.01688, saving model to ./models/best.h5
# Epoch 149/200
# 76/76 [==============================] - 65s 854ms/step - loss: 1.0039 - mean_iou: 0.9028 - mean_iou_marker: 0.7323 - val_loss: 1.0134 - val_mean_iou: 0.9029 - val_mean_iou_marker: 0.7324
#
# Epoch 00149: val_loss improved from 1.01688 to 1.01343, saving model to ./models/best.h5
# Epoch 150/200
# 76/76 [==============================] - 66s 863ms/step - loss: 0.9913 - mean_iou: 0.9029 - mean_iou_marker: 0.7325 - val_loss: 1.0196 - val_mean_iou: 0.9030 - val_mean_iou_marker: 0.7326
#
# Epoch 00150: val_loss did not improve
# Epoch 151/200
# 76/76 [==============================] - 65s 855ms/step - loss: 1.0026 - mean_iou: 0.9030 - mean_iou_marker: 0.7327 - val_loss: 1.0360 - val_mean_iou: 0.9030 - val_mean_iou_marker: 0.7328
#
# Epoch 00151: val_loss did not improve
# Epoch 152/200
# 76/76 [==============================] - 65s 851ms/step - loss: 1.0306 - mean_iou: 0.9031 - mean_iou_marker: 0.7328 - val_loss: 1.0320 - val_mean_iou: 0.9031 - val_mean_iou_marker: 0.7328
#
# Epoch 00152: val_loss did not improve
# Epoch 153/200
# 76/76 [==============================] - 66s 864ms/step - loss: 0.9893 - mean_iou: 0.9031 - mean_iou_marker: 0.7329 - val_loss: 1.0205 - val_mean_iou: 0.9032 - val_mean_iou_marker: 0.7330
#
# Epoch 00153: val_loss did not improve
# Epoch 154/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0099 - mean_iou: 0.9032 - mean_iou_marker: 0.7331 - val_loss: 1.0241 - val_mean_iou: 0.9032 - val_mean_iou_marker: 0.7332
#
# Epoch 00154: val_loss did not improve
# Epoch 155/200
# 76/76 [==============================] - 65s 858ms/step - loss: 1.0034 - mean_iou: 0.9033 - mean_iou_marker: 0.7333 - val_loss: 1.0165 - val_mean_iou: 0.9033 - val_mean_iou_marker: 0.7333
#
# Epoch 00155: val_loss did not improve
# Epoch 156/200
# 76/76 [==============================] - 65s 855ms/step - loss: 1.0076 - mean_iou: 0.9034 - mean_iou_marker: 0.7334 - val_loss: 1.0257 - val_mean_iou: 0.9034 - val_mean_iou_marker: 0.7335
#
# Epoch 00156: val_loss did not improve
# Epoch 157/200
# 76/76 [==============================] - 65s 855ms/step - loss: 0.9953 - mean_iou: 0.9035 - mean_iou_marker: 0.7336 - val_loss: 1.0182 - val_mean_iou: 0.9035 - val_mean_iou_marker: 0.7337
#
# Epoch 00157: val_loss did not improve
# Epoch 158/200
# 76/76 [==============================] - 65s 861ms/step - loss: 0.9880 - mean_iou: 0.9035 - mean_iou_marker: 0.7338 - val_loss: 1.0309 - val_mean_iou: 0.9036 - val_mean_iou_marker: 0.7339
#
# Epoch 00158: val_loss did not improve
# Epoch 159/200
# 76/76 [==============================] - 65s 852ms/step - loss: 0.9927 - mean_iou: 0.9036 - mean_iou_marker: 0.7339 - val_loss: 1.0325 - val_mean_iou: 0.9037 - val_mean_iou_marker: 0.7340
#
# Epoch 00159: val_loss did not improve
# Epoch 160/200
# 76/76 [==============================] - 66s 866ms/step - loss: 1.0018 - mean_iou: 0.9037 - mean_iou_marker: 0.7341 - val_loss: 1.0301 - val_mean_iou: 0.9037 - val_mean_iou_marker: 0.7342
#
# Epoch 00160: val_loss did not improve
# Epoch 161/200
# 76/76 [==============================] - 65s 854ms/step - loss: 1.0061 - mean_iou: 0.9037 - mean_iou_marker: 0.7343 - val_loss: 1.0183 - val_mean_iou: 0.9038 - val_mean_iou_marker: 0.7343
#
# Epoch 00161: val_loss did not improve
# Epoch 162/200
# 76/76 [==============================] - 65s 850ms/step - loss: 1.0102 - mean_iou: 0.9038 - mean_iou_marker: 0.7344 - val_loss: 1.0221 - val_mean_iou: 0.9038 - val_mean_iou_marker: 0.7345
#
# Epoch 00162: val_loss did not improve
# Epoch 163/200
# 76/76 [==============================] - 65s 850ms/step - loss: 1.0047 - mean_iou: 0.9039 - mean_iou_marker: 0.7346 - val_loss: 1.0245 - val_mean_iou: 0.9039 - val_mean_iou_marker: 0.7346
#
# Epoch 00163: val_loss did not improve
# Epoch 164/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0017 - mean_iou: 0.9039 - mean_iou_marker: 0.7347 - val_loss: 1.0212 - val_mean_iou: 0.9040 - val_mean_iou_marker: 0.7348
#
# Epoch 00164: val_loss did not improve
# Epoch 165/200
# 76/76 [==============================] - 65s 852ms/step - loss: 1.0208 - mean_iou: 0.9040 - mean_iou_marker: 0.7348 - val_loss: 1.0305 - val_mean_iou: 0.9040 - val_mean_iou_marker: 0.7349
#
# Epoch 00165: val_loss did not improve
# Epoch 166/200
# 76/76 [==============================] - 65s 850ms/step - loss: 1.0024 - mean_iou: 0.9041 - mean_iou_marker: 0.7349 - val_loss: 1.0185 - val_mean_iou: 0.9041 - val_mean_iou_marker: 0.7350
#
# Epoch 00166: val_loss did not improve
# Epoch 167/200
# 76/76 [==============================] - 64s 848ms/step - loss: 1.0093 - mean_iou: 0.9041 - mean_iou_marker: 0.7350 - val_loss: 1.0201 - val_mean_iou: 0.9041 - val_mean_iou_marker: 0.7351
#
# Epoch 00167: val_loss did not improve
# Epoch 168/200
# 76/76 [==============================] - 65s 856ms/step - loss: 0.9906 - mean_iou: 0.9042 - mean_iou_marker: 0.7352 - val_loss: 1.0223 - val_mean_iou: 0.9042 - val_mean_iou_marker: 0.7353
#
# Epoch 00168: val_loss did not improve
# Epoch 169/200
# 76/76 [==============================] - 65s 849ms/step - loss: 1.0058 - mean_iou: 0.9042 - mean_iou_marker: 0.7354 - val_loss: 1.0362 - val_mean_iou: 0.9042 - val_mean_iou_marker: 0.7354
#
# Epoch 00169: val_loss did not improve
# Epoch 170/200
# 76/76 [==============================] - 65s 858ms/step - loss: 0.9958 - mean_iou: 0.9042 - mean_iou_marker: 0.7355 - val_loss: 1.0186 - val_mean_iou: 0.9043 - val_mean_iou_marker: 0.7356
#
# Epoch 00170: val_loss did not improve
# Epoch 171/200
# 76/76 [==============================] - 65s 855ms/step - loss: 0.9928 - mean_iou: 0.9043 - mean_iou_marker: 0.7357 - val_loss: 1.0213 - val_mean_iou: 0.9043 - val_mean_iou_marker: 0.7357
#
# Epoch 00171: val_loss did not improve
# Epoch 172/200
# 76/76 [==============================] - 64s 846ms/step - loss: 0.9830 - mean_iou: 0.9044 - mean_iou_marker: 0.7358 - val_loss: 1.0242 - val_mean_iou: 0.9044 - val_mean_iou_marker: 0.7359
#
# Epoch 00172: val_loss did not improve
# Epoch 173/200
# 76/76 [==============================] - 65s 852ms/step - loss: 1.0064 - mean_iou: 0.9045 - mean_iou_marker: 0.7360 - val_loss: 1.0277 - val_mean_iou: 0.9045 - val_mean_iou_marker: 0.7361
#
# Epoch 00173: val_loss did not improve
# Epoch 174/200
# 76/76 [==============================] - 65s 855ms/step - loss: 1.0022 - mean_iou: 0.9045 - mean_iou_marker: 0.7361 - val_loss: 1.0354 - val_mean_iou: 0.9046 - val_mean_iou_marker: 0.7362
#
# Epoch 00174: val_loss did not improve
# Epoch 175/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0081 - mean_iou: 0.9046 - mean_iou_marker: 0.7363 - val_loss: 1.0220 - val_mean_iou: 0.9046 - val_mean_iou_marker: 0.7363
#
# Epoch 00175: val_loss did not improve
# Epoch 176/200
# 76/76 [==============================] - 65s 860ms/step - loss: 1.0099 - mean_iou: 0.9047 - mean_iou_marker: 0.7364 - val_loss: 1.0283 - val_mean_iou: 0.9047 - val_mean_iou_marker: 0.7365
#
# Epoch 00176: val_loss did not improve
# Epoch 177/200
# 76/76 [==============================] - 66s 865ms/step - loss: 1.0072 - mean_iou: 0.9047 - mean_iou_marker: 0.7365 - val_loss: 1.0180 - val_mean_iou: 0.9047 - val_mean_iou_marker: 0.7366
#
# Epoch 00177: val_loss did not improve
# Epoch 178/200
# 76/76 [==============================] - 66s 864ms/step - loss: 1.0038 - mean_iou: 0.9048 - mean_iou_marker: 0.7367 - val_loss: 1.0241 - val_mean_iou: 0.9048 - val_mean_iou_marker: 0.7368
#
# Epoch 00178: val_loss did not improve
# Epoch 179/200
# 76/76 [==============================] - 64s 848ms/step - loss: 0.9929 - mean_iou: 0.9048 - mean_iou_marker: 0.7368 - val_loss: 1.0207 - val_mean_iou: 0.9048 - val_mean_iou_marker: 0.7369
#
# Epoch 00179: val_loss did not improve
# Epoch 180/200
# 76/76 [==============================] - 64s 848ms/step - loss: 1.0054 - mean_iou: 0.9049 - mean_iou_marker: 0.7369 - val_loss: 1.0204 - val_mean_iou: 0.9049 - val_mean_iou_marker: 0.7369
#
# Epoch 00180: val_loss did not improve
# Epoch 181/200
# 76/76 [==============================] - 65s 858ms/step - loss: 1.0042 - mean_iou: 0.9050 - mean_iou_marker: 0.7370 - val_loss: 1.0256 - val_mean_iou: 0.9050 - val_mean_iou_marker: 0.7371
#
# Epoch 00181: val_loss did not improve
# Epoch 182/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0002 - mean_iou: 0.9050 - mean_iou_marker: 0.7372 - val_loss: 1.0151 - val_mean_iou: 0.9050 - val_mean_iou_marker: 0.7372
#
# Epoch 00182: val_loss did not improve
# Epoch 183/200
# 76/76 [==============================] - 65s 850ms/step - loss: 1.0041 - mean_iou: 0.9051 - mean_iou_marker: 0.7373 - val_loss: 1.0133 - val_mean_iou: 0.9051 - val_mean_iou_marker: 0.7374
#
# Epoch 00183: val_loss improved from 1.01343 to 1.01335, saving model to ./models/best.h5
# Epoch 184/200
# 76/76 [==============================] - 65s 856ms/step - loss: 1.0153 - mean_iou: 0.9051 - mean_iou_marker: 0.7374 - val_loss: 1.0199 - val_mean_iou: 0.9052 - val_mean_iou_marker: 0.7374
#
# Epoch 00184: val_loss did not improve
# Epoch 185/200
# 76/76 [==============================] - 66s 866ms/step - loss: 1.0031 - mean_iou: 0.9052 - mean_iou_marker: 0.7375 - val_loss: 1.0201 - val_mean_iou: 0.9052 - val_mean_iou_marker: 0.7375
#
# Epoch 00185: val_loss did not improve
# Epoch 186/200
# 76/76 [==============================] - 65s 856ms/step - loss: 1.0043 - mean_iou: 0.9052 - mean_iou_marker: 0.7376 - val_loss: 1.0263 - val_mean_iou: 0.9053 - val_mean_iou_marker: 0.7376
#
# Epoch 00186: val_loss did not improve
# Epoch 187/200
# 76/76 [==============================] - 65s 849ms/step - loss: 1.0247 - mean_iou: 0.9053 - mean_iou_marker: 0.7377 - val_loss: 1.0343 - val_mean_iou: 0.9053 - val_mean_iou_marker: 0.7377
#
# Epoch 00187: val_loss did not improve
# Epoch 188/200
# 76/76 [==============================] - 64s 846ms/step - loss: 1.0052 - mean_iou: 0.9053 - mean_iou_marker: 0.7377 - val_loss: 1.0294 - val_mean_iou: 0.9054 - val_mean_iou_marker: 0.7378
#
# Epoch 00188: val_loss did not improve
# Epoch 189/200
# 76/76 [==============================] - 65s 852ms/step - loss: 0.9983 - mean_iou: 0.9054 - mean_iou_marker: 0.7378 - val_loss: 1.0264 - val_mean_iou: 0.9054 - val_mean_iou_marker: 0.7379
#
# Epoch 00189: val_loss did not improve
# Epoch 190/200
# 76/76 [==============================] - 64s 847ms/step - loss: 1.0053 - mean_iou: 0.9054 - mean_iou_marker: 0.7379 - val_loss: 1.0234 - val_mean_iou: 0.9055 - val_mean_iou_marker: 0.7379
#
# Epoch 00190: val_loss did not improve
# Epoch 191/200
# 76/76 [==============================] - 65s 857ms/step - loss: 1.0302 - mean_iou: 0.9055 - mean_iou_marker: 0.7379 - val_loss: 1.0273 - val_mean_iou: 0.9055 - val_mean_iou_marker: 0.7380
#
# Epoch 00191: val_loss did not improve
# Epoch 192/200
# 76/76 [==============================] - 65s 859ms/step - loss: 1.0076 - mean_iou: 0.9055 - mean_iou_marker: 0.7380 - val_loss: 1.0275 - val_mean_iou: 0.9055 - val_mean_iou_marker: 0.7380
#
# Epoch 00192: val_loss did not improve
# Epoch 193/200
# 76/76 [==============================] - 66s 862ms/step - loss: 1.0142 - mean_iou: 0.9055 - mean_iou_marker: 0.7381 - val_loss: 1.0228 - val_mean_iou: 0.9056 - val_mean_iou_marker: 0.7381
#
# Epoch 00193: val_loss did not improve
# Epoch 194/200
# 76/76 [==============================] - 65s 851ms/step - loss: 1.0099 - mean_iou: 0.9056 - mean_iou_marker: 0.7382 - val_loss: 1.0285 - val_mean_iou: 0.9056 - val_mean_iou_marker: 0.7382
#
# Epoch 00194: val_loss did not improve
# Epoch 195/200
# 76/76 [==============================] - 65s 852ms/step - loss: 1.0290 - mean_iou: 0.9056 - mean_iou_marker: 0.7382 - val_loss: 1.0210 - val_mean_iou: 0.9056 - val_mean_iou_marker: 0.7382
#
# Epoch 00195: val_loss did not improve
# Epoch 196/200
# 76/76 [==============================] - 65s 858ms/step - loss: 1.0019 - mean_iou: 0.9057 - mean_iou_marker: 0.7383 - val_loss: 1.0183 - val_mean_iou: 0.9057 - val_mean_iou_marker: 0.7383
#
# Epoch 00196: val_loss did not improve
# Epoch 197/200
# 76/76 [==============================] - 65s 860ms/step - loss: 0.9962 - mean_iou: 0.9057 - mean_iou_marker: 0.7383 - val_loss: 1.0158 - val_mean_iou: 0.9058 - val_mean_iou_marker: 0.7384
#
# Epoch 00197: val_loss did not improve
# Epoch 198/200
# 76/76 [==============================] - 65s 856ms/step - loss: 0.9977 - mean_iou: 0.9058 - mean_iou_marker: 0.7385 - val_loss: 1.0264 - val_mean_iou: 0.9058 - val_mean_iou_marker: 0.7385
#
# Epoch 00198: val_loss did not improve
# Epoch 199/200
# 76/76 [==============================] - 65s 855ms/step - loss: 0.9842 - mean_iou: 0.9058 - mean_iou_marker: 0.7386 - val_loss: 1.0225 - val_mean_iou: 0.9059 - val_mean_iou_marker: 0.7386
#
# Epoch 00199: val_loss did not improve
# Epoch 200/200
# 76/76 [==============================] - 64s 847ms/step - loss: 0.9879 - mean_iou: 0.9059 - mean_iou_marker: 0.7387 - val_loss: 1.0115 - val_mean_iou: 0.9059 - val_mean_iou_marker: 0.7388
#
# Epoch 00200: val_loss improved from 1.01335 to 1.01150, saving model to ./models/best.h5

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_marker'])
plt.plot(history.history['val_mean_iou_marker'])
plt.title('model mean_iou_marker')
plt.ylabel('mean_iou_marker')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
model = load_model('./models/best.h5', custom_objects={'mean_iou': mean_iou, 'custom_loss': custom_loss, 'mean_iou_marker': mean_iou_marker})
preds_train = model.predict_generator(train_generator, steps=len(train_generator), verbose=1)
preds_val = model.predict_generator(val_generator, steps=len(val_generator), verbose=1)
preds_test = model.predict(X_test, verbose=1, batch_size=BS)

preds_train, preds_train_marker, preds_train_dt = np.transpose(preds_train, (3,0,1,2))
preds_val, preds_val_marker, preds_val_dt = np.transpose(preds_val, (3,0,1,2))
preds_test, preds_test_marker, preds_test_dt = np.transpose(preds_test, (3,0,1,2))

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_train_marker_t = (preds_train_marker > 0.5).astype(np.uint8)
preds_val_marker_t = (preds_val_marker > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append((resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_marker[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_dt[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True)
                                ))
# Out:
# 76/76 [==============================] - 48s 629ms/step
# 9/9 [==============================] - 2s 203ms/step
# 65/65 [==============================] - 2s 25ms/step

# %%
from skimage.morphology import watershed

# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def lb(image, marker, distance):
    if np.sum(image) < np.sum(marker):
        image = marker
    else:
        marker = np.array((marker==1) & (image==1))
    # distance = ndi.distance_transform_edt(image) # old one
    markers = ndi.label(marker)[0]
    labels = watershed(-distance, markers, mask=image)
    if np.sum(labels) == 0:
        labels[0,0] = 1
    return labels

def prob_to_rles(x, marker, dt, cutoff=0.5, cutoff_marker=0.5):
    lab_img = lb(x > cutoff, marker > cutoff_marker, dt)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix][0].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_train[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_marker_t[ix]), shape))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_dt[ix]), shape), cmap='gray')
plt.show()
lab = lb(preds_train_t[ix], preds_train_marker_t[ix], preds_train_dt[ix])
plt.imshow(lab, cmap=plt.get_cmap('tab20'))
plt.show()
# Out:
# 543

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix][0].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_val[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_marker_t[ix]), shape))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_dt[ix]), shape))
plt.show()
lab = lb(preds_val_t[ix], preds_val_marker_t[ix], preds_val_dt[ix])
plt.imshow(lab, cmap=plt.get_cmap('tab20'))
plt.show()
# Out:
# 1

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(*preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      26         # to check the pydot/graphviz installation.
# ---> 27         pydot.Dot.create(pydot.Dot())
#      28     except Exception:
#
# AttributeError: 'NoneType' object has no attribute 'Dot'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-537f16390a4e> in <module>()
#       1 from keras.utils import plot_model
# ----> 2 plot_model(model, to_file='model.png', show_shapes=True)
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir)
#     133             'LR' creates a horizontal plot.
#     134     """
# --> 135     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir)
#     136     _, extension = os.path.splitext(to_file)
#     137     if not extension:
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      54     from ..models import Sequential
#      55
# ---> 56     _check_pydot()
#      57     dot = pydot.Dot()
#      58     dot.set('rankdir', rankdir)
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      29         # pydot raises a generic Exception here,
#      30         # so no specific class can be caught.
# ---> 31         raise ImportError('Failed to import pydot. You must install pydot'
#      32                           ' and graphviz for `pydotprint` to work.')
#      33
#
# ImportError: Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
