# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from scipy import ndimage as ndi

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
K.set_session(session)

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = '/home/peter/dataset/stage1_train/'
TEST_PATH = '/home/peter/dataset/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# Out:
# /home/peter/anaconda3/envs/dnn/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# train_ids = train_ids[:65]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
from skimage.draw import circle
from skimage.morphology import disk, binary_dilation
import math

# Get and resize train images and masks
X_train = []
Y_train = [] 

print('Getting train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    mark = np.zeros(img.shape[:2], dtype=np.float32)
    edge = np.zeros(img.shape[:2], dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)>0
        dt_   = ndi.distance_transform_edt(mask_).astype(np.float32)
        r = max( img.shape[0], img.shape[1] ) * .01
        cY, cX = np.unravel_index(np.argmax(dt_, axis=None), dt_.shape) # find local maximum of edt image
        cY = np.clip(cY, r, img.shape[0]-r)
        cX = np.clip(cX, r, img.shape[1]-r)
        rr, cc = circle(cY, cX, r, shape=img.shape[:2])
        mark[rr,cc] = 1
        edge_ = (binary_dilation(mask_, disk(2))).astype(np.bool) & ~mask_.astype(np.bool)
        edge  = edge | edge_
        mask = np.maximum(mask, mask_)
    Y_train.append([mask, mark, edge])

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append(img.shape[:2])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting train images and masks ...
# 100%|██████████| 670/670 [11:22<00:00,  1.02s/it]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:00<00:00, 95.25it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = np.random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]), cmap='gray')
plt.show()
x_copy = X_train[ix].copy()
x_copy[np.squeeze(Y_train[ix][1])>0, :] = 255, 0, 0
plt.imshow(x_copy)
plt.show()
plt.imshow(np.squeeze(Y_train[ix][2]), cmap='gray')
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
from keras.losses import mean_squared_error
# Define IoU metric
def mean_iou(y_true_, y_pred_):
    y_true = y_true_[...,0]
    y_pred = y_pred_[...,0]
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def mean_iou_marker(y_true_, y_pred_):
    y_true = y_true_[...,1]
    y_pred = y_pred_[...,1]
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def mean_iou_edge(y_true_, y_pred_):
    y_true = y_true_[...,2]
    y_pred = y_pred_[...,2]
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=None) # scaler

def custom_loss(y_true_, y_pred_):
    
    def dice_coef(y_true, y_pred): # (batch_size, h, w)
        intersection = y_true * y_pred
        return (2.*K.sum(intersection) + 1) / (K.sum(y_true) + K.sum(y_pred) + 1) # scaler
    
    y_true_hm = y_true_[...,0] # (batch_size, h, w)
    y_true_mk = y_true_[...,1] # (batch_size, h, w)
    y_true_bd = y_true_[...,2] # (batch_size, h, w)
    
    y_pred_hm = y_pred_[...,0] # (batch_size, h, w)
    y_pred_mk = y_pred_[...,1] # (batch_size, h, w)
    y_pred_bd = y_pred_[...,2] # (batch_size, h, w)
    
    s_marker_dice_coef = dice_coef(y_true_mk, y_pred_mk) # scaler
    s_heatmap_dice_coef= dice_coef(y_true_hm, y_pred_hm) # scaler
    
    s_marker_entropy   = K.mean(K.binary_crossentropy(y_true_mk, y_pred_mk))
    s_heatmap_entropy  = K.mean(K.binary_crossentropy(y_true_hm, y_pred_hm))
    s_edge_entropy     = K.mean(K.binary_crossentropy(y_true_bd, y_pred_bd))
    
    s_marker_loss = .5 * s_marker_entropy - s_marker_dice_coef + 1. # scaler [0, inf)
    s_heatmap_loss= .5 * s_heatmap_entropy - s_heatmap_dice_coef + 1. # scaler [0, inf)
    
    loss = s_marker_loss + s_heatmap_loss + s_edge_entropy # scaler [0, inf)
    loss = tf.Print(loss, [s_marker_dice_coef], message='\nMarker DC:\t', summarize=10)
    loss = tf.Print(loss, [s_marker_entropy], message='\nMarker ET:\t', summarize=10)
    loss = tf.Print(loss, [s_heatmap_dice_coef], message='\nHeatmap DC:\t', summarize=10)
    loss = tf.Print(loss, [s_heatmap_entropy], message='\nHeatmap ET:\t', summarize=10)
    loss = tf.Print(loss, [s_edge_entropy], message='\nEDGE ET:\t', summarize=10)
    
    return loss # scaler [0, inf)

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout
from keras.optimizers import Adam

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = concatenate()([inputs, last])
    
    c1 = _res_conv(c1, 32, 3)
    c1 = _res_conv(c1, 32, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 64, 3)
    c2 = _res_conv(c2, 64, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 128, 3)
    c3 = _res_conv(c3, 128, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 256, 3)
    c4 = _res_conv(c4, 256, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 512, 3)
    c5 = _res_conv(c5, 512, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3)
    c6 = _res_conv(c6, 512, 3)
    
    u7 = up (c6)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 512, 3)
    c7 = _res_conv(c7, 512, 3)
    
    u8 = up (c7)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 256, 3)
    c8 = _res_conv(c8, 256, 3)
    
    u9 = up (c8)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 128, 3)
    c9 = _res_conv(c9, 128, 3)
    
    u10 = up (c9)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 64, 3)
    c10 = _res_conv(c10, 64, 3)
    
    u11 = up (c10)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 32, 3)
    c11 = _res_conv(c11, 32, 3)
    
    outputs = Conv2D(3, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss=custom_loss, metrics=[mean_iou, mean_iou_marker, mean_iou_edge], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  32          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 17) 1241        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 8)  808         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 3)  12          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 128         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 8)  264         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 256, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 4)  132         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 17) 1241        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 8)  808         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 3)  99          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 32) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 256, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 32) 0           activation_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 528         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 8)  264         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32) 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 9)  297         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 6)  198         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 2112        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 128, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           conv2d_20[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 8)  520         activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 9)  585         activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 6)  390         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 64) 0           conv2d_21[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128, 128, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 64) 0           activation_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 64) 0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 32)   2080        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 16)   1040        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 19)   1235        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 12)   780         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_27[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  8320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 128)  0           conv2d_33[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   4128        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 16)   2064        activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 19)   2451        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 12)   1548        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 64, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           activation_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 128)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 38)   4902        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 25)   3225        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 256)  0           conv2d_40[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 256)  33024       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 256)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 256)  0           conv2d_46[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 32)   8224        activation_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 38)   9766        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 25)   6425        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 256)  0           conv2d_47[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 256)  0           activation_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 128)  32896       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 16, 16, 256)  0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 76)   19532       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 16, 16, 51)   13107       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 512)  0           conv2d_53[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 512)  131584      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 512)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 512)  0           conv2d_59[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 16, 16, 128)  65664       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 16, 16, 64)   32832       activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 16, 16, 512)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 16, 16, 76)   38988       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 512)  0           conv2d_60[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 512)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 512)  0           activation_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 8, 8, 512)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 8, 8, 128)    65664       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 8, 8, 76)     38988       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 512)    0           conv2d_66[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 512)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 512)    0           max_pooling2d_15[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 512)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 8, 8, 128)    65664       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 8, 8, 64)     32832       activation_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 8, 8, 512)    0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 8, 8, 76)     38988       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 512)    0           conv2d_72[0][0]
#                                                                  conv2d_75[0][0]
#                                                                  conv2d_76[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 512)    0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 512)    0           activation_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 512)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 16, 16, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 16, 16, 1024) 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 76)   77900       concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 51)   52275       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 16, 16, 512)  0           conv2d_78[0][0]
#                                                                  conv2d_81[0][0]
#                                                                  conv2d_82[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 512)  524800      concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 512)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 512)  0           conv2d_84[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 64)   32832       activation_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 512)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 76)   38988       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 51)   26163       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 16, 16, 512)  0           conv2d_85[0][0]
#                                                                  conv2d_88[0][0]
#                                                                  conv2d_89[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 512)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 512)  0           activation_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 512)  0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 768)  0           conv2d_transpose_2[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 32, 32, 64)   49216       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 32, 32, 768)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 32, 32, 38)   29222       concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 32, 32, 25)   19225       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 32, 256)  0           conv2d_91[0][0]
#                                                                  conv2d_94[0][0]
#                                                                  conv2d_95[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 32, 32, 256)  196864      concatenate_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 256)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 256)  0           conv2d_97[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 32, 32, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 32, 32, 32)   8224        activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 32, 32, 256)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 32, 32, 38)   9766        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 32, 32, 129)  74433       conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 32, 32, 64)   51264       conv2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 32, 32, 25)   6425        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 256)  0           conv2d_98[0][0]
#                                                                  conv2d_101[0][0]
#                                                                  conv2d_102[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 32, 32, 256)  0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 256)  0           activation_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 256)  262400      activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 384)  0           conv2d_transpose_3[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 32)   12320       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 64, 64, 16)   6160        concatenate_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 64, 64, 19)   7315        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_105[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 12)   4620        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 64, 64, 128)  0           conv2d_104[0][0]
#                                                                  conv2d_107[0][0]
#                                                                  conv2d_108[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 128)  49280       concatenate_19[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 128)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 128)  0           conv2d_110[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 128)  0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 64, 64, 32)   4128        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 64, 64, 16)   2064        activation_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 64, 64, 128)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 64, 64, 19)   2451        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 64, 64, 65)   18785       conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 64, 64, 32)   12832       conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 64, 64, 12)   1548        max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 64, 64, 128)  0           conv2d_111[0][0]
#                                                                  conv2d_114[0][0]
#                                                                  conv2d_115[0][0]
#                                                                  conv2d_116[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64, 64, 128)  0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 64, 128)  0           activation_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 128)  0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 128 65664       activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 192 0           conv2d_transpose_4[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 128, 128, 16) 3088        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 128, 8)  1544        concatenate_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 128, 128, 9)  1737        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 128, 128, 6)  1158        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 64) 0           conv2d_117[0][0]
#                                                                  conv2d_120[0][0]
#                                                                  conv2d_121[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 128, 64) 12352       concatenate_22[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 128, 128, 64) 0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 128, 128, 64) 0           conv2d_123[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 64) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 128, 128, 16) 1040        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 128, 128, 8)  520         activation_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 64) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 128, 128, 9)  585         activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 128, 128, 33) 4785        conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 128, 128, 16) 3216        conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 128, 128, 6)  390         max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 64) 0           conv2d_124[0][0]
#                                                                  conv2d_127[0][0]
#                                                                  conv2d_128[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 128, 128, 64) 0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 128, 64) 0           activation_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 64) 0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 64) 16448       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 96) 0           conv2d_transpose_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 256, 256, 8)  776         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 256, 256, 4)  388         concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 8)  808         conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 256, 256, 3)  291         max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 256, 256, 32) 0           conv2d_130[0][0]
#                                                                  conv2d_133[0][0]
#                                                                  conv2d_134[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 256, 256, 32) 3104        concatenate_25[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 256, 256, 32) 0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 256, 256, 32) 0           conv2d_136[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 32) 0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 256, 256, 8)  264         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 256, 256, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 4)  132         activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 256, 256, 17) 1241        conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 256, 256, 8)  808         conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 256, 256, 3)  99          max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 256, 256, 32) 0           conv2d_137[0][0]
#                                                                  conv2d_140[0][0]
#                                                                  conv2d_141[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 256, 256, 32) 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 256, 256, 32) 0           activation_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 256, 256, 32) 0           add_22[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 3)  99          activation_22[0][0]
# ==================================================================================================
# Total params: 8,442,348
# Trainable params: 8,442,348
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils import Sequence
import cv2
from sklearn.utils import shuffle
from skimage.transform import AffineTransform, warp
import copy

class data_generator(Sequence):
    def __init__(self, data, label, batch_size=4, training=True):
        self.data = data
        self.label= label
        self.batch_size = batch_size
        self.training = training
    def __len__(self):
        return int(np.ceil(float(len(self.data))/self.batch_size))
    def on_epoch_end(self):
        if self.training: self.data, self.label = shuffle(self.data, self.label)
    def __getitem__(self, i):
        l_bound =  i    * self.batch_size
        r_bound = (i+1) * self.batch_size
        if r_bound>len(self.data): # ensure every iteration has the same batch size
            r_bound = len(self.data)
            l_bound = r_bound - self.batch_size
        dat_que = np.empty((self.batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
        lab_que = np.empty((self.batch_size, IMG_HEIGHT, IMG_WIDTH, 3), dtype=np.float32)
        for n, index in enumerate(range(l_bound, r_bound)):
            img = copy.deepcopy(self.data[index]).astype(np.float32) / 255.
            lab = copy.deepcopy(self.label[index][0])
            marker = copy.deepcopy(self.label[index][1])
            edge = copy.deepcopy(self.label[index][2])
            if self.training:
                if np.random.rand() < .5: # flip vertical
                    img = np.flip(img, 0)
                    lab = np.flip(lab, 0)
                    marker = np.flip(marker, 0)
                    edge = np.flip(edge,0)
                if np.random.rand() < .5: # flip horizontal
                    img = np.flip(img, 1)
                    lab = np.flip(lab, 1)
                    marker = np.flip(marker, 1)
                    edge = np.flip(edge, 1)

                # rotation, shearing
                if np.random.rand() < 0.5:
                    y, x, _ = img.shape
                    h, w = y, x
                    img = np.pad(img, ((y//2, y//2), (x//2, x//2), (0, 0)), 'reflect')
                    lab = np.pad(lab, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    marker = np.pad(marker, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    edge = np.pad(edge, ((y//2, y//2), (x//2, x//2)), 'reflect')
                    
                    rotT = np.random.uniform(-45,45)
                    shearT = np.random.uniform(-5,5)
                    translationX = np.random.uniform(-w,w) * .1
                    translationY = np.random.uniform(-h,h) * .1
                    atmtx = AffineTransform(rotation=rotT, shear=shearT, translation=(translationX, translationY))

                    img = warp(img, atmtx)
                    lab = warp(lab, atmtx)
                    marker = warp(marker, atmtx)
                    edge = warp(edge, atmtx)

                    img = img[h//2:h//2+h,w//2:w//2+w,:]
                    lab = lab[h//2:h//2+h,w//2:w//2+w]
                    marker = marker[h//2:h//2+h,w//2:w//2+w]
                    edge = edge[h//2:h//2+h,w//2:w//2+w]

                # random amplify each channel
                a = .1 # amptitude
                t  = [np.random.uniform(-a,a)]
                t += [np.random.uniform(-a,a)]
                t += [np.random.uniform(-a,a)]
                t = np.array(t)

                img = np.clip(img * (1. + t), 0, 1) # channel wise amplify
                up = np.random.uniform(0.95, 1.05) # change gamma
                img = np.clip(img**up, 0, 1) # apply gamma and convert back to range [0,255]

            ### end of data augmentation ###

            img = (resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)*255.).astype(np.uint8)
            lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
            marker = resize(marker, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
            edge = resize(edge, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

            dat_que[n,:,:,:] = img
            lab_que[n,:,:,0] = lab > .5
            lab_que[n,:,:,1] = marker > .5
            lab_que[n,:,:,2] = edge > .5
        return dat_que, lab_que

# %%
from sklearn.model_selection import train_test_split
if not os.path.exists('./models'):
    os.makedirs('./models')

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# %%
BS=8
EPOCHS=300
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=True)
val_generator = data_generator(X_val, Y_val, batch_size=BS, training=False)

# earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('./models/model.{epoch:03d}.vl.{val_loss:.2f}.vi.{val_mean_iou:.2f}.vim.{val_mean_iou_marker:.2f}.vbd.{val_mean_iou_edge}.h5', verbose=0, save_best_only=False)
checkpointer_best = ModelCheckpoint('./models/best.h5', verbose=1, save_best_only=True)
history = model.fit_generator(train_generator,
                              steps_per_epoch=len(train_generator), epochs=EPOCHS, 
                              validation_data=val_generator, 
                              validation_steps=len(val_generator),
                              callbacks=[checkpointer, checkpointer_best],
                              workers=5,
                              use_multiprocessing=True
                              )
# Out:
# Epoch 1/300
# 76/76 [==============================] - 76s 995ms/step - loss: 1.6622 - mean_iou: 0.5138 - mean_iou_marker: 0.4910 - mean_iou_edge: 0.4704 - val_loss: 1.1614 - val_mean_iou: 0.6335 - val_mean_iou_marker: 0.5445 - val_mean_iou_edge: 0.4851
#
# Epoch 00001: val_loss improved from inf to 1.16145, saving model to ./models/best.h5
# Epoch 2/300
# 76/76 [==============================] - 69s 906ms/step - loss: 1.0927 - mean_iou: 0.6731 - mean_iou_marker: 0.5625 - mean_iou_edge: 0.4876 - val_loss: 1.2713 - val_mean_iou: 0.6982 - val_mean_iou_marker: 0.5771 - val_mean_iou_edge: 0.4889
#
# Epoch 00002: val_loss did not improve
# Epoch 3/300
# 76/76 [==============================] - 69s 914ms/step - loss: 1.1257 - mean_iou: 0.7079 - mean_iou_marker: 0.5849 - mean_iou_edge: 0.4898 - val_loss: 1.0238 - val_mean_iou: 0.7165 - val_mean_iou_marker: 0.5912 - val_mean_iou_edge: 0.4903
#
# Epoch 00003: val_loss improved from 1.16145 to 1.02375, saving model to ./models/best.h5
# Epoch 4/300
# 76/76 [==============================] - 69s 912ms/step - loss: 0.9713 - mean_iou: 0.7254 - mean_iou_marker: 0.5976 - mean_iou_edge: 0.4909 - val_loss: 0.9204 - val_mean_iou: 0.7368 - val_mean_iou_marker: 0.6046 - val_mean_iou_edge: 0.4920
#
# Epoch 00004: val_loss improved from 1.02375 to 0.92044, saving model to ./models/best.h5
# Epoch 5/300
# 76/76 [==============================] - 69s 909ms/step - loss: 0.9342 - mean_iou: 0.7434 - mean_iou_marker: 0.6092 - mean_iou_edge: 0.4929 - val_loss: 0.8484 - val_mean_iou: 0.7495 - val_mean_iou_marker: 0.6140 - val_mean_iou_edge: 0.4936
#
# Epoch 00005: val_loss improved from 0.92044 to 0.84840, saving model to ./models/best.h5
# Epoch 6/300
# 76/76 [==============================] - 69s 912ms/step - loss: 0.9519 - mean_iou: 0.7538 - mean_iou_marker: 0.6181 - mean_iou_edge: 0.4940 - val_loss: 0.8425 - val_mean_iou: 0.7596 - val_mean_iou_marker: 0.6216 - val_mean_iou_edge: 0.4943
#
# Epoch 00006: val_loss improved from 0.84840 to 0.84245, saving model to ./models/best.h5
# Epoch 7/300
# 76/76 [==============================] - 69s 911ms/step - loss: 0.9240 - mean_iou: 0.7635 - mean_iou_marker: 0.6241 - mean_iou_edge: 0.4948 - val_loss: 0.7959 - val_mean_iou: 0.7666 - val_mean_iou_marker: 0.6267 - val_mean_iou_edge: 0.4954
#
# Epoch 00007: val_loss improved from 0.84245 to 0.79585, saving model to ./models/best.h5
# Epoch 8/300
# 76/76 [==============================] - 70s 917ms/step - loss: 0.8873 - mean_iou: 0.7706 - mean_iou_marker: 0.6300 - mean_iou_edge: 0.4958 - val_loss: 0.7920 - val_mean_iou: 0.7741 - val_mean_iou_marker: 0.6329 - val_mean_iou_edge: 0.4963
#
# Epoch 00008: val_loss improved from 0.79585 to 0.79201, saving model to ./models/best.h5
# Epoch 9/300
# 76/76 [==============================] - 68s 901ms/step - loss: 0.8697 - mean_iou: 0.7777 - mean_iou_marker: 0.6360 - mean_iou_edge: 0.4967 - val_loss: 0.7908 - val_mean_iou: 0.7803 - val_mean_iou_marker: 0.6380 - val_mean_iou_edge: 0.4972
#
# Epoch 00009: val_loss improved from 0.79201 to 0.79078, saving model to ./models/best.h5
# Epoch 10/300
# 76/76 [==============================] - 68s 890ms/step - loss: 0.8569 - mean_iou: 0.7833 - mean_iou_marker: 0.6398 - mean_iou_edge: 0.4977 - val_loss: 0.8971 - val_mean_iou: 0.7842 - val_mean_iou_marker: 0.6416 - val_mean_iou_edge: 0.4980
#
# Epoch 00010: val_loss did not improve
# Epoch 11/300
# 76/76 [==============================] - 68s 894ms/step - loss: 0.7913 - mean_iou: 0.7860 - mean_iou_marker: 0.6442 - mean_iou_edge: 0.4982 - val_loss: 0.7692 - val_mean_iou: 0.7878 - val_mean_iou_marker: 0.6463 - val_mean_iou_edge: 0.4984
#
# Epoch 00011: val_loss improved from 0.79078 to 0.76916, saving model to ./models/best.h5
# Epoch 12/300
# 76/76 [==============================] - 69s 908ms/step - loss: 0.7928 - mean_iou: 0.7905 - mean_iou_marker: 0.6479 - mean_iou_edge: 0.4988 - val_loss: 0.7396 - val_mean_iou: 0.7934 - val_mean_iou_marker: 0.6494 - val_mean_iou_edge: 0.4994
#
# Epoch 00012: val_loss improved from 0.76916 to 0.73959, saving model to ./models/best.h5
# Epoch 13/300
# 76/76 [==============================] - 69s 909ms/step - loss: 0.7563 - mean_iou: 0.7953 - mean_iou_marker: 0.6506 - mean_iou_edge: 0.5000 - val_loss: 0.7373 - val_mean_iou: 0.7974 - val_mean_iou_marker: 0.6520 - val_mean_iou_edge: 0.5005
#
# Epoch 00013: val_loss improved from 0.73959 to 0.73728, saving model to ./models/best.h5
# Epoch 14/300
# 76/76 [==============================] - 69s 905ms/step - loss: 0.7757 - mean_iou: 0.7996 - mean_iou_marker: 0.6535 - mean_iou_edge: 0.5008 - val_loss: 0.7416 - val_mean_iou: 0.8015 - val_mean_iou_marker: 0.6547 - val_mean_iou_edge: 0.5011
#
# Epoch 00014: val_loss did not improve
# Epoch 15/300
# 76/76 [==============================] - 69s 906ms/step - loss: 0.7761 - mean_iou: 0.8032 - mean_iou_marker: 0.6567 - mean_iou_edge: 0.5015 - val_loss: 0.7137 - val_mean_iou: 0.8039 - val_mean_iou_marker: 0.6579 - val_mean_iou_edge: 0.5017
#
# Epoch 00015: val_loss improved from 0.73728 to 0.71372, saving model to ./models/best.h5
# Epoch 16/300
# 76/76 [==============================] - 70s 918ms/step - loss: 0.8001 - mean_iou: 0.8049 - mean_iou_marker: 0.6600 - mean_iou_edge: 0.5020 - val_loss: 0.6780 - val_mean_iou: 0.8056 - val_mean_iou_marker: 0.6614 - val_mean_iou_edge: 0.5024
#
# Epoch 00016: val_loss improved from 0.71372 to 0.67804, saving model to ./models/best.h5
# Epoch 17/300
# 76/76 [==============================] - 72s 944ms/step - loss: 0.7271 - mean_iou: 0.8076 - mean_iou_marker: 0.6627 - mean_iou_edge: 0.5030 - val_loss: 0.6926 - val_mean_iou: 0.8089 - val_mean_iou_marker: 0.6637 - val_mean_iou_edge: 0.5034
#
# Epoch 00017: val_loss did not improve
# Epoch 18/300
# 76/76 [==============================] - 72s 946ms/step - loss: 0.7572 - mean_iou: 0.8101 - mean_iou_marker: 0.6649 - mean_iou_edge: 0.5037 - val_loss: 0.6945 - val_mean_iou: 0.8114 - val_mean_iou_marker: 0.6661 - val_mean_iou_edge: 0.5040
#
# Epoch 00018: val_loss did not improve
# Epoch 19/300
# 76/76 [==============================] - 71s 938ms/step - loss: 0.7212 - mean_iou: 0.8127 - mean_iou_marker: 0.6671 - mean_iou_edge: 0.5045 - val_loss: 0.6813 - val_mean_iou: 0.8145 - val_mean_iou_marker: 0.6684 - val_mean_iou_edge: 0.5050
#
# Epoch 00019: val_loss did not improve
# Epoch 20/300
# 76/76 [==============================] - 70s 918ms/step - loss: 0.6939 - mean_iou: 0.8164 - mean_iou_marker: 0.6698 - mean_iou_edge: 0.5054 - val_loss: 0.6963 - val_mean_iou: 0.8176 - val_mean_iou_marker: 0.6706 - val_mean_iou_edge: 0.5059
#
# Epoch 00020: val_loss did not improve
# Epoch 21/300
# 76/76 [==============================] - 69s 902ms/step - loss: 0.7322 - mean_iou: 0.8186 - mean_iou_marker: 0.6715 - mean_iou_edge: 0.5062 - val_loss: 0.6920 - val_mean_iou: 0.8196 - val_mean_iou_marker: 0.6723 - val_mean_iou_edge: 0.5065
#
# Epoch 00021: val_loss did not improve
# Epoch 22/300
# 76/76 [==============================] - 69s 903ms/step - loss: 0.7243 - mean_iou: 0.8207 - mean_iou_marker: 0.6733 - mean_iou_edge: 0.5068 - val_loss: 0.6530 - val_mean_iou: 0.8215 - val_mean_iou_marker: 0.6743 - val_mean_iou_edge: 0.5071
#
# Epoch 00022: val_loss improved from 0.67804 to 0.65299, saving model to ./models/best.h5
# Epoch 23/300
# 76/76 [==============================] - 70s 927ms/step - loss: 0.7669 - mean_iou: 0.8224 - mean_iou_marker: 0.6753 - mean_iou_edge: 0.5077 - val_loss: 0.6869 - val_mean_iou: 0.8231 - val_mean_iou_marker: 0.6760 - val_mean_iou_edge: 0.5081
#
# Epoch 00023: val_loss did not improve
# Epoch 24/300
# 76/76 [==============================] - 75s 984ms/step - loss: 0.6932 - mean_iou: 0.8238 - mean_iou_marker: 0.6768 - mean_iou_edge: 0.5083 - val_loss: 0.6785 - val_mean_iou: 0.8248 - val_mean_iou_marker: 0.6777 - val_mean_iou_edge: 0.5087
#
# Epoch 00024: val_loss did not improve
# Epoch 25/300
# 76/76 [==============================] - 74s 979ms/step - loss: 0.6692 - mean_iou: 0.8260 - mean_iou_marker: 0.6786 - mean_iou_edge: 0.5089 - val_loss: 0.6633 - val_mean_iou: 0.8269 - val_mean_iou_marker: 0.6792 - val_mean_iou_edge: 0.5092
#
# Epoch 00025: val_loss did not improve
# Epoch 26/300
# 76/76 [==============================] - 72s 944ms/step - loss: 0.6943 - mean_iou: 0.8278 - mean_iou_marker: 0.6798 - mean_iou_edge: 0.5094 - val_loss: 0.6300 - val_mean_iou: 0.8286 - val_mean_iou_marker: 0.6807 - val_mean_iou_edge: 0.5098
# Epoch 00026: val_loss improved from 0.65299 to 0.63005, saving model to ./models/best.h5
# Epoch 27/300
# 76/76 [==============================] - 70s 927ms/step - loss: 0.7081 - mean_iou: 0.8295 - mean_iou_marker: 0.6812 - mean_iou_edge: 0.5100 - val_loss: 0.6640 - val_mean_iou: 0.8303 - val_mean_iou_marker: 0.6818 - val_mean_iou_edge: 0.5104
#
# Epoch 00027: val_loss did not improve
# Epoch 28/300
# 76/76 [==============================] - 70s 927ms/step - loss: 0.6926 - mean_iou: 0.8312 - mean_iou_marker: 0.6824 - mean_iou_edge: 0.5108 - val_loss: 0.6548 - val_mean_iou: 0.8319 - val_mean_iou_marker: 0.6830 - val_mean_iou_edge: 0.5110
#
# Epoch 00028: val_loss did not improve
# Epoch 29/300
# 76/76 [==============================] - 70s 928ms/step - loss: 0.8869 - mean_iou: 0.8322 - mean_iou_marker: 0.6832 - mean_iou_edge: 0.5111 - val_loss: 0.7544 - val_mean_iou: 0.8322 - val_mean_iou_marker: 0.6834 - val_mean_iou_edge: 0.5112
#
# Epoch 00029: val_loss did not improve
# Epoch 30/300
# 76/76 [==============================] - 74s 968ms/step - loss: 0.7227 - mean_iou: 0.8331 - mean_iou_marker: 0.6837 - mean_iou_edge: 0.5114 - val_loss: 0.6953 - val_mean_iou: 0.8337 - val_mean_iou_marker: 0.6840 - val_mean_iou_edge: 0.5116
#
# Epoch 00030: val_loss did not improve
# Epoch 31/300
# 76/76 [==============================] - 71s 938ms/step - loss: 0.6779 - mean_iou: 0.8345 - mean_iou_marker: 0.6843 - mean_iou_edge: 0.5119 - val_loss: 0.6302 - val_mean_iou: 0.8355 - val_mean_iou_marker: 0.6848 - val_mean_iou_edge: 0.5121
#
# Epoch 00031: val_loss did not improve
# Epoch 32/300
# 76/76 [==============================] - 68s 893ms/step - loss: 0.6571 - mean_iou: 0.8361 - mean_iou_marker: 0.6855 - mean_iou_edge: 0.5125 - val_loss: 0.6245 - val_mean_iou: 0.8367 - val_mean_iou_marker: 0.6861 - val_mean_iou_edge: 0.5127
#
# Epoch 00032: val_loss improved from 0.63005 to 0.62448, saving model to ./models/best.h5
# Epoch 33/300
# 76/76 [==============================] - 70s 923ms/step - loss: 0.6718 - mean_iou: 0.8376 - mean_iou_marker: 0.6867 - mean_iou_edge: 0.5131 - val_loss: 0.6165 - val_mean_iou: 0.8381 - val_mean_iou_marker: 0.6872 - val_mean_iou_edge: 0.5134
#
# Epoch 00033: val_loss improved from 0.62448 to 0.61653, saving model to ./models/best.h5
# Epoch 34/300
# 76/76 [==============================] - 70s 923ms/step - loss: 0.6673 - mean_iou: 0.8386 - mean_iou_marker: 0.6878 - mean_iou_edge: 0.5136 - val_loss: 0.6255 - val_mean_iou: 0.8391 - val_mean_iou_marker: 0.6883 - val_mean_iou_edge: 0.5139
#
# Epoch 00034: val_loss did not improve
# Epoch 35/300
# 76/76 [==============================] - 70s 921ms/step - loss: 0.7093 - mean_iou: 0.8393 - mean_iou_marker: 0.6888 - mean_iou_edge: 0.5141 - val_loss: 0.6358 - val_mean_iou: 0.8399 - val_mean_iou_marker: 0.6892 - val_mean_iou_edge: 0.5144
#
# Epoch 00035: val_loss did not improve
# Epoch 36/300
# 76/76 [==============================] - 70s 927ms/step - loss: 0.6795 - mean_iou: 0.8405 - mean_iou_marker: 0.6898 - mean_iou_edge: 0.5146 - val_loss: 0.6219 - val_mean_iou: 0.8411 - val_mean_iou_marker: 0.6902 - val_mean_iou_edge: 0.5148
#
# Epoch 00036: val_loss did not improve
# Epoch 37/300
# 76/76 [==============================] - 70s 921ms/step - loss: 0.6289 - mean_iou: 0.8417 - mean_iou_marker: 0.6907 - mean_iou_edge: 0.5151 - val_loss: 0.5989 - val_mean_iou: 0.8424 - val_mean_iou_marker: 0.6912 - val_mean_iou_edge: 0.5154
#
# Epoch 00037: val_loss improved from 0.61653 to 0.59887, saving model to ./models/best.h5
# Epoch 38/300
# 76/76 [==============================] - 70s 923ms/step - loss: 0.6552 - mean_iou: 0.8430 - mean_iou_marker: 0.6918 - mean_iou_edge: 0.5156 - val_loss: 0.6278 - val_mean_iou: 0.8432 - val_mean_iou_marker: 0.6924 - val_mean_iou_edge: 0.5157
#
# Epoch 00038: val_loss did not improve
# Epoch 39/300
# 76/76 [==============================] - 70s 919ms/step - loss: 0.6956 - mean_iou: 0.8435 - mean_iou_marker: 0.6929 - mean_iou_edge: 0.5159 - val_loss: 0.6118 - val_mean_iou: 0.8438 - val_mean_iou_marker: 0.6935 - val_mean_iou_edge: 0.5161
#
# Epoch 00039: val_loss did not improve
# Epoch 40/300
# 76/76 [==============================] - 69s 903ms/step - loss: 0.6973 - mean_iou: 0.8440 - mean_iou_marker: 0.6940 - mean_iou_edge: 0.5163 - val_loss: 0.6262 - val_mean_iou: 0.8444 - val_mean_iou_marker: 0.6943 - val_mean_iou_edge: 0.5164
#
# Epoch 00040: val_loss did not improve
# Epoch 41/300
# 76/76 [==============================] - 68s 889ms/step - loss: 0.7438 - mean_iou: 0.8444 - mean_iou_marker: 0.6947 - mean_iou_edge: 0.5165 - val_loss: 0.6635 - val_mean_iou: 0.8443 - val_mean_iou_marker: 0.6951 - val_mean_iou_edge: 0.5165
#
# Epoch 00041: val_loss did not improve
# Epoch 42/300
# 76/76 [==============================] - 68s 898ms/step - loss: 0.6826 - mean_iou: 0.8445 - mean_iou_marker: 0.6954 - mean_iou_edge: 0.5166 - val_loss: 0.6180 - val_mean_iou: 0.8450 - val_mean_iou_marker: 0.6957 - val_mean_iou_edge: 0.5167
#
# Epoch 00042: val_loss did not improve
# Epoch 43/300
# 76/76 [==============================] - 69s 913ms/step - loss: 0.6296 - mean_iou: 0.8453 - mean_iou_marker: 0.6961 - mean_iou_edge: 0.5169 - val_loss: 0.5967 - val_mean_iou: 0.8459 - val_mean_iou_marker: 0.6965 - val_mean_iou_edge: 0.5170
#
# Epoch 00043: val_loss improved from 0.59887 to 0.59666, saving model to ./models/best.h5
# Epoch 44/300
# 76/76 [==============================] - 68s 901ms/step - loss: 0.6417 - mean_iou: 0.8463 - mean_iou_marker: 0.6969 - mean_iou_edge: 0.5172 - val_loss: 0.6253 - val_mean_iou: 0.8467 - val_mean_iou_marker: 0.6972 - val_mean_iou_edge: 0.5173
#
# Epoch 00044: val_loss did not improve
# Epoch 45/300
# 76/76 [==============================] - 67s 887ms/step - loss: 0.6837 - mean_iou: 0.8469 - mean_iou_marker: 0.6975 - mean_iou_edge: 0.5175 - val_loss: 0.6392 - val_mean_iou: 0.8471 - val_mean_iou_marker: 0.6977 - val_mean_iou_edge: 0.5177
#
# Epoch 00045: val_loss did not improve
# Epoch 46/300
# 76/76 [==============================] - 66s 873ms/step - loss: 0.7116 - mean_iou: 0.8473 - mean_iou_marker: 0.6981 - mean_iou_edge: 0.5177 - val_loss: 0.6208 - val_mean_iou: 0.8473 - val_mean_iou_marker: 0.6983 - val_mean_iou_edge: 0.5178
#
# Epoch 00046: val_loss did not improve
# Epoch 47/300
# 76/76 [==============================] - 68s 888ms/step - loss: 0.6730 - mean_iou: 0.8477 - mean_iou_marker: 0.6987 - mean_iou_edge: 0.5180 - val_loss: 0.6305 - val_mean_iou: 0.8478 - val_mean_iou_marker: 0.6989 - val_mean_iou_edge: 0.5182
#
# Epoch 00047: val_loss did not improve
# Epoch 48/300
# 76/76 [==============================] - 67s 883ms/step - loss: 0.7593 - mean_iou: 0.8478 - mean_iou_marker: 0.6991 - mean_iou_edge: 0.5183 - val_loss: 0.6080 - val_mean_iou: 0.8480 - val_mean_iou_marker: 0.6993 - val_mean_iou_edge: 0.5184
#
# Epoch 00048: val_loss did not improve
# Epoch 49/300
# 76/76 [==============================] - 67s 886ms/step - loss: 0.6127 - mean_iou: 0.8483 - mean_iou_marker: 0.6996 - mean_iou_edge: 0.5186 - val_loss: 0.6387 - val_mean_iou: 0.8488 - val_mean_iou_marker: 0.6998 - val_mean_iou_edge: 0.5188
#
# Epoch 00049: val_loss did not improve
# Epoch 50/300
# 76/76 [==============================] - 67s 886ms/step - loss: 0.6943 - mean_iou: 0.8490 - mean_iou_marker: 0.7000 - mean_iou_edge: 0.5189 - val_loss: 0.5892 - val_mean_iou: 0.8492 - val_mean_iou_marker: 0.7002 - val_mean_iou_edge: 0.5191
#
# Epoch 00050: val_loss improved from 0.59666 to 0.58916, saving model to ./models/best.h5
# Epoch 51/300
# 76/76 [==============================] - 67s 885ms/step - loss: 0.7125 - mean_iou: 0.8494 - mean_iou_marker: 0.7005 - mean_iou_edge: 0.5192 - val_loss: 0.6188 - val_mean_iou: 0.8496 - val_mean_iou_marker: 0.7008 - val_mean_iou_edge: 0.5194
#
# Epoch 00051: val_loss did not improve
# Epoch 52/300
# 76/76 [==============================] - 68s 890ms/step - loss: 0.6873 - mean_iou: 0.8498 - mean_iou_marker: 0.7012 - mean_iou_edge: 0.5195 - val_loss: 0.6329 - val_mean_iou: 0.8501 - val_mean_iou_marker: 0.7015 - val_mean_iou_edge: 0.5197
#
# Epoch 00052: val_loss did not improve
# Epoch 53/300
# 76/76 [==============================] - 67s 881ms/step - loss: 0.6423 - mean_iou: 0.8503 - mean_iou_marker: 0.7018 - mean_iou_edge: 0.5198 - val_loss: 0.6333 - val_mean_iou: 0.8506 - val_mean_iou_marker: 0.7022 - val_mean_iou_edge: 0.5199
#
# Epoch 00053: val_loss did not improve
# Epoch 54/300
# 76/76 [==============================] - 67s 885ms/step - loss: 0.6205 - mean_iou: 0.8510 - mean_iou_marker: 0.7025 - mean_iou_edge: 0.5201 - val_loss: 0.5893 - val_mean_iou: 0.8515 - val_mean_iou_marker: 0.7029 - val_mean_iou_edge: 0.5202
#
# Epoch 00054: val_loss did not improve
# Epoch 55/300
# 76/76 [==============================] - 67s 885ms/step - loss: 0.6576 - mean_iou: 0.8517 - mean_iou_marker: 0.7034 - mean_iou_edge: 0.5204 - val_loss: 0.6293 - val_mean_iou: 0.8519 - val_mean_iou_marker: 0.7036 - val_mean_iou_edge: 0.5205
#
# Epoch 00055: val_loss did not improve
# Epoch 56/300
# 76/76 [==============================] - 66s 871ms/step - loss: 0.6613 - mean_iou: 0.8521 - mean_iou_marker: 0.7038 - mean_iou_edge: 0.5206 - val_loss: 0.6032 - val_mean_iou: 0.8523 - val_mean_iou_marker: 0.7040 - val_mean_iou_edge: 0.5208
#
# Epoch 00056: val_loss did not improve
# Epoch 57/300
# 76/76 [==============================] - 67s 883ms/step - loss: 0.6201 - mean_iou: 0.8527 - mean_iou_marker: 0.7044 - mean_iou_edge: 0.5209 - val_loss: 0.5893 - val_mean_iou: 0.8528 - val_mean_iou_marker: 0.7047 - val_mean_iou_edge: 0.5209
#
# Epoch 00057: val_loss did not improve
# Epoch 58/300
# 76/76 [==============================] - 67s 883ms/step - loss: 0.6068 - mean_iou: 0.8531 - mean_iou_marker: 0.7050 - mean_iou_edge: 0.5210 - val_loss: 0.5673 - val_mean_iou: 0.8535 - val_mean_iou_marker: 0.7054 - val_mean_iou_edge: 0.5211
#
# Epoch 00058: val_loss improved from 0.58916 to 0.56734, saving model to ./models/best.h5
# Epoch 59/300
# 76/76 [==============================] - 68s 889ms/step - loss: 0.6998 - mean_iou: 0.8539 - mean_iou_marker: 0.7056 - mean_iou_edge: 0.5213 - val_loss: 0.5921 - val_mean_iou: 0.8541 - val_mean_iou_marker: 0.7058 - val_mean_iou_edge: 0.5214
#
# Epoch 00059: val_loss did not improve
# Epoch 60/300
# 76/76 [==============================] - 67s 882ms/step - loss: 0.6119 - mean_iou: 0.8544 - mean_iou_marker: 0.7061 - mean_iou_edge: 0.5215 - val_loss: 0.5858 - val_mean_iou: 0.8548 - val_mean_iou_marker: 0.7063 - val_mean_iou_edge: 0.5216
#
# Epoch 00060: val_loss did not improve
# Epoch 61/300
# 76/76 [==============================] - 66s 872ms/step - loss: 0.6150 - mean_iou: 0.8551 - mean_iou_marker: 0.7066 - mean_iou_edge: 0.5218 - val_loss: 0.5861 - val_mean_iou: 0.8552 - val_mean_iou_marker: 0.7068 - val_mean_iou_edge: 0.5218
#
# Epoch 00061: val_loss did not improve
# Epoch 62/300
# 76/76 [==============================] - 67s 875ms/step - loss: 0.5756 - mean_iou: 0.8555 - mean_iou_marker: 0.7071 - mean_iou_edge: 0.5219 - val_loss: 0.5802 - val_mean_iou: 0.8559 - val_mean_iou_marker: 0.7074 - val_mean_iou_edge: 0.5221
#
# Epoch 00062: val_loss did not improve
# Epoch 63/300
# 76/76 [==============================] - 67s 888ms/step - loss: 0.6754 - mean_iou: 0.8559 - mean_iou_marker: 0.7076 - mean_iou_edge: 0.5222 - val_loss: 0.5943 - val_mean_iou: 0.8560 - val_mean_iou_marker: 0.7078 - val_mean_iou_edge: 0.5223
#
# Epoch 00063: val_loss did not improve
# Epoch 64/300
# 76/76 [==============================] - 67s 884ms/step - loss: 0.6394 - mean_iou: 0.8560 - mean_iou_marker: 0.7080 - mean_iou_edge: 0.5224 - val_loss: 0.5998 - val_mean_iou: 0.8563 - val_mean_iou_marker: 0.7084 - val_mean_iou_edge: 0.5225
#
# Epoch 00064: val_loss did not improve
# Epoch 65/300
# 76/76 [==============================] - 67s 881ms/step - loss: 0.6396 - mean_iou: 0.8565 - mean_iou_marker: 0.7086 - mean_iou_edge: 0.5227 - val_loss: 0.5900 - val_mean_iou: 0.8567 - val_mean_iou_marker: 0.7088 - val_mean_iou_edge: 0.5229
#
# Epoch 00065: val_loss did not improve
# Epoch 66/300
# 76/76 [==============================] - 67s 887ms/step - loss: 0.6721 - mean_iou: 0.8567 - mean_iou_marker: 0.7090 - mean_iou_edge: 0.5229 - val_loss: 0.6234 - val_mean_iou: 0.8567 - val_mean_iou_marker: 0.7093 - val_mean_iou_edge: 0.5230
#
# Epoch 00066: val_loss did not improve
# Epoch 67/300
# 76/76 [==============================] - 68s 895ms/step - loss: 0.6445 - mean_iou: 0.8570 - mean_iou_marker: 0.7095 - mean_iou_edge: 0.5230 - val_loss: 0.6303 - val_mean_iou: 0.8571 - val_mean_iou_marker: 0.7097 - val_mean_iou_edge: 0.5231
#
# Epoch 00067: val_loss did not improve
# Epoch 68/300
# 76/76 [==============================] - 67s 884ms/step - loss: 0.6670 - mean_iou: 0.8572 - mean_iou_marker: 0.7099 - mean_iou_edge: 0.5231 - val_loss: 0.5989 - val_mean_iou: 0.8573 - val_mean_iou_marker: 0.7100 - val_mean_iou_edge: 0.5232
#
# Epoch 00068: val_loss did not improve
# Epoch 69/300
# 76/76 [==============================] - 67s 882ms/step - loss: 0.6623 - mean_iou: 0.8575 - mean_iou_marker: 0.7102 - mean_iou_edge: 0.5233 - val_loss: 0.6374 - val_mean_iou: 0.8576 - val_mean_iou_marker: 0.7103 - val_mean_iou_edge: 0.5233
#
# Epoch 00069: val_loss did not improve
# Epoch 70/300
# 76/76 [==============================] - 67s 880ms/step - loss: 0.6323 - mean_iou: 0.8577 - mean_iou_marker: 0.7105 - mean_iou_edge: 0.5234 - val_loss: 0.5736 - val_mean_iou: 0.8579 - val_mean_iou_marker: 0.7108 - val_mean_iou_edge: 0.5235
#
# Epoch 00070: val_loss did not improve
# Epoch 71/300
# 76/76 [==============================] - 67s 883ms/step - loss: 0.6086 - mean_iou: 0.8582 - mean_iou_marker: 0.7109 - mean_iou_edge: 0.5236 - val_loss: 0.5914 - val_mean_iou: 0.8584 - val_mean_iou_marker: 0.7112 - val_mean_iou_edge: 0.5237
#
# Epoch 00071: val_loss did not improve
# Epoch 72/300
# 76/76 [==============================] - 70s 921ms/step - loss: 0.6513 - mean_iou: 0.8585 - mean_iou_marker: 0.7113 - mean_iou_edge: 0.5239 - val_loss: 0.6054 - val_mean_iou: 0.8586 - val_mean_iou_marker: 0.7114 - val_mean_iou_edge: 0.5239
#
# Epoch 00072: val_loss did not improve
# Epoch 73/300
# 76/76 [==============================] - 70s 919ms/step - loss: 0.6455 - mean_iou: 0.8587 - mean_iou_marker: 0.7117 - mean_iou_edge: 0.5240 - val_loss: 0.5790 - val_mean_iou: 0.8589 - val_mean_iou_marker: 0.7119 - val_mean_iou_edge: 0.5241
#
# Epoch 00073: val_loss did not improve
# Epoch 74/300
# 76/76 [==============================] - 69s 911ms/step - loss: 0.6794 - mean_iou: 0.8589 - mean_iou_marker: 0.7121 - mean_iou_edge: 0.5242 - val_loss: 0.6441 - val_mean_iou: 0.8589 - val_mean_iou_marker: 0.7122 - val_mean_iou_edge: 0.5243
#
# Epoch 00074: val_loss did not improve
# Epoch 75/300
# 76/76 [==============================] - 69s 908ms/step - loss: 0.6060 - mean_iou: 0.8592 - mean_iou_marker: 0.7124 - mean_iou_edge: 0.5244 - val_loss: 0.6058 - val_mean_iou: 0.8593 - val_mean_iou_marker: 0.7126 - val_mean_iou_edge: 0.5244
#
# Epoch 00075: val_loss did not improve
# Epoch 76/300
# 76/76 [==============================] - 69s 914ms/step - loss: 0.6431 - mean_iou: 0.8594 - mean_iou_marker: 0.7128 - mean_iou_edge: 0.5245 - val_loss: 0.5969 - val_mean_iou: 0.8595 - val_mean_iou_marker: 0.7130 - val_mean_iou_edge: 0.5246
#
# Epoch 00076: val_loss did not improve
# Epoch 77/300
# 76/76 [==============================] - 69s 911ms/step - loss: 0.6211 - mean_iou: 0.8596 - mean_iou_marker: 0.7131 - mean_iou_edge: 0.5247 - val_loss: 0.5814 - val_mean_iou: 0.8598 - val_mean_iou_marker: 0.7133 - val_mean_iou_edge: 0.5248
#
# Epoch 00077: val_loss did not improve
# Epoch 78/300
# 45/76 [================>.............] - ETA: 26s - loss: 0.6849 - mean_iou: 0.8599 - mean_iou_marker: 0.7134 - mean_iou_edge: 0.5249
# Process ForkPoolWorker-780:
# Process ForkPoolWorker-774:
# Process ForkPoolWorker-772:
# Process ForkPoolWorker-773:
# Process ForkPoolWorker-771:
# Process ForkPoolWorker-779:
# Process ForkPoolWorker-777:
# Traceback (most recent call last):
# Process ForkPoolWorker-775:
# Process ForkPoolWorker-778:
# Process ForkPoolWorker-776:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/utils/data_utils.py", line 390, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "<ipython-input-8-916a434e1c86>", line 57, in __getitem__
#     img = warp(img, atmtx)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/site-packages/skimage/transform/_warps.py", line 775, in warp
#     order=order, mode=mode, cval=cval))
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "skimage/transform/_warps_cy.pyx", line 131, in skimage.transform._warps_cy._warp_fast (skimage/transform/_warps_cy.c:2637)
#   File "/home/peter/anaconda3/envs/dnn/lib/python3.6/site-packages/numpy/core/numeric.py", line 424, in asarray
#     def asarray(a, dtype=None, order=None):
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-18d42e22db37> in <module>()
#      13                               callbacks=[checkpointer, checkpointer_best],
#      14                               workers=5,
# ---> 15                               use_multiprocessing=True
#      16                               )
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2242                     outs = self.train_on_batch(x, y,
#    2243                                                sample_weight=sample_weight,
# -> 2244                                                class_weight=class_weight)
#    2245
#    2246                     if not isinstance(outs, list):
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1888             ins = x + y + sample_weights
#    1889         self._make_train_function()
# -> 1890         outputs = self.train_function(ins)
#    1891         if len(outputs) == 1:
#    1892             return outputs[0]
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/dnn/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_marker'])
plt.plot(history.history['val_mean_iou_marker'])
plt.title('model mean_iou_marker')
plt.ylabel('mean_iou_marker')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_edge'])
plt.plot(history.history['val_mean_iou_edge'])
plt.title('model mean_iou_edge')
plt.ylabel('mean_iou_edge')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Reset generators
train_generator = data_generator(X_train, Y_train, batch_size=BS, training=False)
val_generator = data_generator(X_val, Y_val, batch_size=BS, training=False)

# Predict on train, val and test
model = load_model('./models/best.h5', custom_objects={'mean_iou': mean_iou, 'custom_loss': custom_loss, 'mean_iou_marker': mean_iou_marker, 'mean_iou_edge':mean_iou_edge})
preds_train = model.predict_generator(train_generator, steps=len(train_generator), verbose=1)
preds_val = model.predict_generator(val_generator, steps=len(val_generator), verbose=1)
preds_test = model.predict(X_test, verbose=1, batch_size=BS)

preds_train, preds_train_marker, preds_train_edge = np.transpose(preds_train, (3,0,1,2))
preds_val, preds_val_marker, preds_val_edge = np.transpose(preds_val, (3,0,1,2))
preds_test, preds_test_marker, preds_test_edge = np.transpose(preds_test, (3,0,1,2))

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_train_marker_t = (preds_train_marker > 0.5).astype(np.uint8)
preds_val_marker_t = (preds_val_marker > 0.5).astype(np.uint8)
preds_train_edge_t = (preds_train_edge > 0.5).astype(np.uint8)
preds_val_edge_t = (preds_val_edge > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append((resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_marker[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 (resize(np.squeeze(preds_test_edge[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True)>0.5).astype(np.bool)
                                ))

# %%
from skimage.morphology import watershed

# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def lb(image, marker, edges):
    if np.sum(image) < np.sum(marker):
        image = marker
    else:
        marker = np.array((marker==1) & (image==1))
    distance = ndi.distance_transform_edt(image) - np.squeeze(edges)
    markers = ndi.label(marker)[0]
    labels = watershed(-distance, markers, mask=image)
    if np.sum(labels) == 0:
        labels[0,0] = 1
    return labels

def prob_to_rles(x, marker, edges, cutoff=0.5, cutoff_marker=0.5, cutoff_edges=0.5):
    lab_img = lb((x > cutoff).astype(np.bool), (marker > cutoff_marker).astype(np.bool), (edges > cutoff_edges).astype(np.bool))
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
# Perform a sanity check on some random training samples
ix = np.random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix][0].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_train[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_marker_t[ix]), shape))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_edge_t[ix]), shape), cmap='gray')
plt.show()
lab = lb(preds_train_t[ix], preds_train_marker_t[ix], preds_train_edge_t[ix].astype(np.bool))
plt.imshow(lab, cmap=plt.get_cmap('tab20'))
plt.show()

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = np.random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix][0].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_val[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_marker_t[ix]), shape))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_edge_t[ix]), shape))
plt.show()
lab = lb(preds_val_t[ix], preds_val_marker_t[ix], preds_val_edge_t[ix].astype(np.bool))
plt.imshow(lab, cmap=plt.get_cmap('tab20'))
plt.show()

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(*preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB
